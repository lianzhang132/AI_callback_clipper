# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
from datetime import datetime
# # 设置 GPU 按需增长
# config = tf.ConfigProto()
# config.gpu_options.allow_growth = True
# sess = tf.Session(config=config)
 
# 首先导入数据，看一下数据的形式
mnist = input_data.read_data_sets('/root/code/MNIST_data/', one_hot=True)
print (mnist.train.images.shape)
 
##########################################################################设置模型超参数
 
lr = 1e-3
# 在训练和测试的时候，我们想用不同的 batch_size.所以采用占位符的方式
keep_prob = tf.placeholder(tf.float32, [])
batch_size = tf.placeholder(tf.int32, [])
 
# 每个时刻的输入特征是28维的，就是每个时刻输入一行，一行有 28 个像素
input_size = 28
# 时序持续长度为28，即每做一次预测，需要先输入28行
timestep_size = 28
# 每个隐含层的节点数
hidden_size = 256
# LSTM layer 的层数
layer_num = 2
# 最后输出分类类别数量，如果是回归预测的话应该是 1
class_num = 10
 
_X = tf.placeholder(tf.float32, [None, 784])
y = tf.placeholder(tf.float32, [None, class_num])
 
##########################################################################搭建LSTM模型
 
# 把784个点的字符信息还原成 28 * 28 的图片
# 下面几个步骤是实现 RNN / LSTM 的关键
####################################################################
# **步骤1：RNN 的输入shape = (batch_size, timestep_size, input_size)
X = tf.reshape(_X, [-1, 28, 28])
 
stacked_rnn = []
for iiLyr in range(layer_num):
    stacked_rnn.append(tf.nn.rnn_cell.LSTMCell(num_units=hidden_size, state_is_tuple=True))
mlstm_cell = tf.nn.rnn_cell.MultiRNNCell(cells=stacked_rnn, state_is_tuple=True)
init_state = mlstm_cell.zero_state(batch_size, dtype=tf.float32)
 
# **步骤6：方法一，调用 dynamic_rnn() 来让我们构建好的网络运行起来
# ** 当 time_major==False 时， outputs.shape = [batch_size, timestep_size, hidden_size]
# ** 所以，可以取 h_state = outputs[:, -1, :] 作为最后输出
# ** state.shape = [layer_num, 2, batch_size, hidden_size],
# ** 或者，可以取 h_state = state[-1][1] 作为最后输出
# ** 最后输出维度是 [batch_size, hidden_size]
# outputs, state = tf.nn.dynamic_rnn(mlstm_cell, inputs=X, initial_state=init_state, time_major=False)
# h_state = outputs[:, -1, :]  # 或者 h_state = state[-1][1]
 
# *************** 为了更好的理解 LSTM 工作原理，我们把上面 步骤6 中的函数自己来实现 ***************
# 通过查看文档你会发现， RNNCell 都提供了一个 __call__()函数（见最后附），我们可以用它来展开实现LSTM按时间步迭代。
# **步骤6：方法二，按时间步展开计算
outputs = list()
state = init_state
with tf.variable_scope('RNN'):
    for timestep in range(timestep_size):
        if timestep > 0:
            tf.get_variable_scope().reuse_variables()
        # 这里的state保存了每一层 LSTM 的状态
        (cell_output, state) = mlstm_cell(X[:, timestep, :], state)
        outputs.append(cell_output)
h_state = outputs[-1]
 
# 上面 LSTM 部分的输出会是一个 [hidden_size] 的tensor，我们要分类的话，还需要接一个 softmax 层
# 首先定义 softmax 的连接权重矩阵和偏置
# out_W = tf.placeholder(tf.float32, [hidden_size, class_num], name='out_Weights')
# out_bias = tf.placeholder(tf.float32, [class_num], name='out_bias')
# 开始训练和测试
W = tf.Variable(tf.truncated_normal([hidden_size, class_num], stddev=0.1), dtype=tf.float32)
bias = tf.Variable(tf.constant(0.1,shape=[class_num]), dtype=tf.float32)
y_pre = tf.nn.softmax(tf.matmul(h_state, W) + bias)
 
# 损失和评估函数
cross_entropy = -tf.reduce_mean(y * tf.log(y_pre))
train_op = tf.train.AdamOptimizer(lr).minimize(cross_entropy)
 
correct_prediction = tf.equal(tf.argmax(y_pre,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))

saver = tf.train.Saver() #定义saver

with tf.Session() as sess: 
    sess.run(tf.global_variables_initializer())
    start = datetime.now()
    for i in range(5001):
        _batch_size = 128
        batch = mnist.train.next_batch(_batch_size)
        sess.run(train_op, feed_dict={_X: batch[0], y: batch[1], keep_prob: 0.5, batch_size: _batch_size})
#         if (i+1)%200 == 0:
        train_accuracy = sess.run(accuracy, feed_dict={
            _X:batch[0], y: batch[1], keep_prob: 1.0, batch_size: _batch_size})
        # 已经迭代完成的 epoch 数: mnist.train.epochs_completed
        print("Iter%d, step %d, training accuracy %g" % ( mnist.train.epochs_completed, (i+1), train_accuracy))
    end = datetime.now()
    latency = (end - start).total_seconds()
    print('训练5000步总时长为 '+str(latency)+' 秒 ')

#         # 计算测试数据的准确率
#         print("test accuracy %g"% sess.run(accuracy, feed_dict={
#             _X: mnist.test.images, y: mnist.test.labels, keep_prob: 1.0, batch_size:mnist.test.images.shape[0]}))
    saver.save(sess, '/tmp/tf_rnn_2/model.ckpt') #模型储存位置
# Out:
# WARNING:tensorflow:From <ipython-input-1-811b50320b97>:10: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting /root/code/MNIST_data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting /root/code/MNIST_data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting /root/code/MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting /root/code/MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# (55000, 784)
# WARNING:tensorflow:From <ipython-input-1-811b50320b97>:44: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From <ipython-input-1-811b50320b97>:45: MultiRNNCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.StackedRNNCells, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow_core/python/ops/rnn_cell_impl.py:958: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow_core/python/ops/rnn_cell_impl.py:962: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Iter0, step 1, training accuracy 0.226562
# Iter0, step 2, training accuracy 0.28125
# Iter0, step 3, training accuracy 0.273438
# Iter0, step 4, training accuracy 0.257812
# Iter0, step 5, training accuracy 0.40625
# Iter0, step 6, training accuracy 0.320312
# Iter0, step 7, training accuracy 0.335938
# Iter0, step 8, training accuracy 0.414062
# Iter0, step 9, training accuracy 0.414062
# Iter0, step 10, training accuracy 0.398438
# Iter0, step 11, training accuracy 0.40625
# Iter0, step 12, training accuracy 0.414062
# Iter0, step 13, training accuracy 0.390625
# Iter0, step 14, training accuracy 0.507812
# Iter0, step 15, training accuracy 0.578125
# Iter0, step 16, training accuracy 0.601562
# Iter0, step 17, training accuracy 0.523438
# Iter0, step 18, training accuracy 0.5625
# Iter0, step 19, training accuracy 0.5625
# Iter0, step 20, training accuracy 0.53125
# Iter0, step 21, training accuracy 0.609375
# Iter0, step 22, training accuracy 0.601562
# Iter0, step 23, training accuracy 0.664062
# Iter0, step 24, training accuracy 0.601562
# Iter0, step 25, training accuracy 0.632812
# Iter0, step 26, training accuracy 0.664062
# Iter0, step 27, training accuracy 0.65625
# Iter0, step 28, training accuracy 0.671875
# Iter0, step 29, training accuracy 0.609375
# Iter0, step 30, training accuracy 0.640625
# Iter0, step 31, training accuracy 0.578125
# Iter0, step 32, training accuracy 0.664062
# Iter0, step 33, training accuracy 0.679688
# Iter0, step 34, training accuracy 0.695312
# Iter0, step 35, training accuracy 0.703125
# Iter0, step 36, training accuracy 0.671875
# Iter0, step 37, training accuracy 0.664062
# Iter0, step 38, training accuracy 0.71875
# Iter0, step 39, training accuracy 0.75
# Iter0, step 40, training accuracy 0.695312
# Iter0, step 41, training accuracy 0.726562
# Iter0, step 42, training accuracy 0.789062
# Iter0, step 43, training accuracy 0.664062
# Iter0, step 44, training accuracy 0.679688
# Iter0, step 45, training accuracy 0.789062
# Iter0, step 46, training accuracy 0.671875
# Iter0, step 47, training accuracy 0.804688
# Iter0, step 48, training accuracy 0.84375
# Iter0, step 49, training accuracy 0.796875
# Iter0, step 50, training accuracy 0.757812
# Iter0, step 51, training accuracy 0.742188
# Iter0, step 52, training accuracy 0.804688
# Iter0, step 53, training accuracy 0.765625
# Iter0, step 54, training accuracy 0.804688
# Iter0, step 55, training accuracy 0.78125
# Iter0, step 56, training accuracy 0.773438
# Iter0, step 57, training accuracy 0.796875
# Iter0, step 58, training accuracy 0.804688
# Iter0, step 59, training accuracy 0.78125
# Iter0, step 60, training accuracy 0.898438
# Iter0, step 61, training accuracy 0.789062
# Iter0, step 62, training accuracy 0.835938
# Iter0, step 63, training accuracy 0.84375
# Iter0, step 64, training accuracy 0.835938
# Iter0, step 65, training accuracy 0.828125
# Iter0, step 66, training accuracy 0.835938
# Iter0, step 67, training accuracy 0.851562
# Iter0, step 68, training accuracy 0.90625
# Iter0, step 69, training accuracy 0.757812
# Iter0, step 70, training accuracy 0.84375
# Iter0, step 71, training accuracy 0.789062
# Iter0, step 72, training accuracy 0.835938
# Iter0, step 73, training accuracy 0.875
# Iter0, step 74, training accuracy 0.8125
# Iter0, step 75, training accuracy 0.828125
# Iter0, step 76, training accuracy 0.882812
# Iter0, step 77, training accuracy 0.875
# Iter0, step 78, training accuracy 0.890625
# Iter0, step 79, training accuracy 0.867188
# Iter0, step 80, training accuracy 0.867188
# Iter0, step 81, training accuracy 0.78125
# Iter0, step 82, training accuracy 0.835938
# Iter0, step 83, training accuracy 0.914062
# Iter0, step 84, training accuracy 0.84375
# Iter0, step 85, training accuracy 0.851562
# Iter0, step 86, training accuracy 0.851562
# Iter0, step 87, training accuracy 0.851562
# Iter0, step 88, training accuracy 0.890625
# Iter0, step 89, training accuracy 0.890625
# Iter0, step 90, training accuracy 0.84375
# Iter0, step 91, training accuracy 0.882812
# Iter0, step 92, training accuracy 0.875
# Iter0, step 93, training accuracy 0.867188
# Iter0, step 94, training accuracy 0.875
# Iter0, step 95, training accuracy 0.929688
# Iter0, step 96, training accuracy 0.875
# Iter0, step 97, training accuracy 0.84375
# Iter0, step 98, training accuracy 0.859375
# Iter0, step 99, training accuracy 0.851562
# Iter0, step 100, training accuracy 0.90625
# Iter0, step 101, training accuracy 0.84375
# Iter0, step 102, training accuracy 0.890625
# Iter0, step 103, training accuracy 0.867188
# Iter0, step 104, training accuracy 0.875
# Iter0, step 105, training accuracy 0.9375
# Iter0, step 106, training accuracy 0.90625
# Iter0, step 107, training accuracy 0.898438
# Iter0, step 108, training accuracy 0.875
# Iter0, step 109, training accuracy 0.90625
# Iter0, step 110, training accuracy 0.898438
# Iter0, step 111, training accuracy 0.875
# Iter0, step 112, training accuracy 0.90625
# Iter0, step 113, training accuracy 0.929688
# Iter0, step 114, training accuracy 0.890625
# Iter0, step 115, training accuracy 0.953125
# Iter0, step 116, training accuracy 0.921875
# Iter0, step 117, training accuracy 0.90625
# Iter0, step 118, training accuracy 0.9375
# Iter0, step 119, training accuracy 0.898438
# Iter0, step 120, training accuracy 0.890625
# Iter0, step 121, training accuracy 0.90625
# Iter0, step 122, training accuracy 0.898438
# Iter0, step 123, training accuracy 0.945312
# Iter0, step 124, training accuracy 0.960938
# Iter0, step 125, training accuracy 0.914062
# Iter0, step 126, training accuracy 0.914062
# Iter0, step 127, training accuracy 0.882812
# Iter0, step 128, training accuracy 0.929688
# Iter0, step 129, training accuracy 0.867188
# Iter0, step 130, training accuracy 0.953125
# Iter0, step 131, training accuracy 0.929688
# Iter0, step 132, training accuracy 0.90625
# Iter0, step 133, training accuracy 0.9375
# Iter0, step 134, training accuracy 0.921875
# Iter0, step 135, training accuracy 0.9375
# Iter0, step 136, training accuracy 0.875
# Iter0, step 137, training accuracy 0.9375
# Iter0, step 138, training accuracy 0.921875
# Iter0, step 139, training accuracy 0.953125
# Iter0, step 140, training accuracy 0.898438
# Iter0, step 141, training accuracy 0.90625
# Iter0, step 142, training accuracy 0.890625
# Iter0, step 143, training accuracy 0.882812
# Iter0, step 144, training accuracy 0.898438
# Iter0, step 145, training accuracy 0.882812
# Iter0, step 146, training accuracy 0.898438
# Iter0, step 147, training accuracy 0.921875
# Iter0, step 148, training accuracy 0.875
# Iter0, step 149, training accuracy 0.898438
# Iter0, step 150, training accuracy 0.875
# Iter0, step 151, training accuracy 0.875
# Iter0, step 152, training accuracy 0.890625
# Iter0, step 153, training accuracy 0.945312
# Iter0, step 154, training accuracy 0.945312
# Iter0, step 155, training accuracy 0.945312
# Iter0, step 156, training accuracy 0.890625
# Iter0, step 157, training accuracy 0.929688
# Iter0, step 158, training accuracy 0.945312
# Iter0, step 159, training accuracy 0.914062
# Iter0, step 160, training accuracy 0.90625
# Iter0, step 161, training accuracy 0.929688
# Iter0, step 162, training accuracy 0.90625
# Iter0, step 163, training accuracy 0.921875
# Iter0, step 164, training accuracy 0.914062
# Iter0, step 165, training accuracy 0.90625
# Iter0, step 166, training accuracy 0.953125
# Iter0, step 167, training accuracy 0.9375
# Iter0, step 168, training accuracy 0.929688
# Iter0, step 169, training accuracy 0.914062
# Iter0, step 170, training accuracy 0.882812
# Iter0, step 171, training accuracy 0.929688
# Iter0, step 172, training accuracy 0.953125
# Iter0, step 173, training accuracy 0.914062
# Iter0, step 174, training accuracy 0.898438
# Iter0, step 175, training accuracy 0.882812
# Iter0, step 176, training accuracy 0.929688
# Iter0, step 177, training accuracy 0.929688
# Iter0, step 178, training accuracy 0.960938
# Iter0, step 179, training accuracy 0.929688
# Iter0, step 180, training accuracy 0.976562
# Iter0, step 181, training accuracy 0.90625
# Iter0, step 182, training accuracy 0.929688
# Iter0, step 183, training accuracy 0.921875
# Iter0, step 184, training accuracy 0.984375
# Iter0, step 185, training accuracy 0.90625
# Iter0, step 186, training accuracy 0.960938
# Iter0, step 187, training accuracy 0.90625
# Iter0, step 188, training accuracy 0.929688
# Iter0, step 189, training accuracy 0.921875
# Iter0, step 190, training accuracy 0.929688
# Iter0, step 191, training accuracy 0.921875
# Iter0, step 192, training accuracy 0.914062
# Iter0, step 193, training accuracy 0.960938
# Iter0, step 194, training accuracy 0.960938
# Iter0, step 195, training accuracy 0.945312
# Iter0, step 196, training accuracy 0.953125
# Iter0, step 197, training accuracy 0.945312
# Iter0, step 198, training accuracy 0.945312
# Iter0, step 199, training accuracy 0.9375
# Iter0, step 200, training accuracy 0.953125
# Iter0, step 201, training accuracy 0.960938
# Iter0, step 202, training accuracy 0.921875
# Iter0, step 203, training accuracy 0.945312
# Iter0, step 204, training accuracy 0.921875
# Iter0, step 205, training accuracy 0.882812
# Iter0, step 206, training accuracy 0.960938
# Iter0, step 207, training accuracy 0.90625
# Iter0, step 208, training accuracy 0.914062
# Iter0, step 209, training accuracy 0.953125
# Iter0, step 210, training accuracy 0.921875
# Iter0, step 211, training accuracy 0.960938
# Iter0, step 212, training accuracy 0.914062
# Iter0, step 213, training accuracy 0.9375
# Iter0, step 214, training accuracy 0.929688
# Iter0, step 215, training accuracy 0.921875
# Iter0, step 216, training accuracy 0.898438
# Iter0, step 217, training accuracy 0.929688
# Iter0, step 218, training accuracy 0.960938
# Iter0, step 219, training accuracy 0.9375
# Iter0, step 220, training accuracy 0.914062
# Iter0, step 221, training accuracy 0.921875
# Iter0, step 222, training accuracy 0.9375
# Iter0, step 223, training accuracy 0.9375
# Iter0, step 224, training accuracy 0.9375
# Iter0, step 225, training accuracy 0.96875
# Iter0, step 226, training accuracy 0.9375
# Iter0, step 227, training accuracy 0.96875
# Iter0, step 228, training accuracy 0.921875
# Iter0, step 229, training accuracy 0.9375
# Iter0, step 230, training accuracy 0.90625
# Iter0, step 231, training accuracy 0.929688
# Iter0, step 232, training accuracy 0.960938
# Iter0, step 233, training accuracy 0.96875
# Iter0, step 234, training accuracy 0.945312
# Iter0, step 235, training accuracy 0.96875
# Iter0, step 236, training accuracy 0.921875
# Iter0, step 237, training accuracy 0.953125
# Iter0, step 238, training accuracy 0.96875
# Iter0, step 239, training accuracy 0.960938
# Iter0, step 240, training accuracy 0.953125
# Iter0, step 241, training accuracy 0.945312
# Iter0, step 242, training accuracy 0.953125
# Iter0, step 243, training accuracy 0.960938
# Iter0, step 244, training accuracy 0.96875
# Iter0, step 245, training accuracy 0.960938
# Iter0, step 246, training accuracy 0.976562
# Iter0, step 247, training accuracy 0.953125
# Iter0, step 248, training accuracy 0.96875
# Iter0, step 249, training accuracy 0.9375
# Iter0, step 250, training accuracy 0.9375
# Iter0, step 251, training accuracy 0.945312
# Iter0, step 252, training accuracy 0.945312
# Iter0, step 253, training accuracy 0.945312
# Iter0, step 254, training accuracy 0.945312
# Iter0, step 255, training accuracy 0.914062
# Iter0, step 256, training accuracy 0.96875
# Iter0, step 257, training accuracy 0.984375
# Iter0, step 258, training accuracy 0.96875
# Iter0, step 259, training accuracy 0.945312
# Iter0, step 260, training accuracy 0.945312
# Iter0, step 261, training accuracy 0.945312
# Iter0, step 262, training accuracy 0.960938
# Iter0, step 263, training accuracy 0.953125
# Iter0, step 264, training accuracy 0.96875
# Iter0, step 265, training accuracy 0.9375
# Iter0, step 266, training accuracy 0.953125
# Iter0, step 267, training accuracy 0.945312
# Iter0, step 268, training accuracy 0.953125
# Iter0, step 269, training accuracy 0.929688
# Iter0, step 270, training accuracy 0.976562
# Iter0, step 271, training accuracy 0.9375
# Iter0, step 272, training accuracy 0.914062
# Iter0, step 273, training accuracy 0.9375
# Iter0, step 274, training accuracy 0.953125
# Iter0, step 275, training accuracy 0.984375
# Iter0, step 276, training accuracy 0.929688
# Iter0, step 277, training accuracy 0.960938
# Iter0, step 278, training accuracy 0.90625
# Iter0, step 279, training accuracy 0.929688
# Iter0, step 280, training accuracy 0.921875
# Iter0, step 281, training accuracy 0.984375
# Iter0, step 282, training accuracy 0.960938
# Iter0, step 283, training accuracy 0.914062
# Iter0, step 284, training accuracy 0.9375
# Iter0, step 285, training accuracy 0.945312
# Iter0, step 286, training accuracy 0.945312
# Iter0, step 287, training accuracy 0.921875
# Iter0, step 288, training accuracy 0.929688
# Iter0, step 289, training accuracy 0.929688
# Iter0, step 290, training accuracy 0.921875
# Iter0, step 291, training accuracy 0.960938
# Iter0, step 292, training accuracy 0.953125
# Iter0, step 293, training accuracy 0.9375
# Iter0, step 294, training accuracy 0.984375
# Iter0, step 295, training accuracy 0.9375
# Iter0, step 296, training accuracy 0.960938
# Iter0, step 297, training accuracy 0.953125
# Iter0, step 298, training accuracy 0.921875
# Iter0, step 299, training accuracy 0.960938
# Iter0, step 300, training accuracy 0.96875
# Iter0, step 301, training accuracy 0.929688
# Iter0, step 302, training accuracy 0.976562
# Iter0, step 303, training accuracy 0.984375
# Iter0, step 304, training accuracy 0.96875
# Iter0, step 305, training accuracy 0.976562
# Iter0, step 306, training accuracy 0.960938
# Iter0, step 307, training accuracy 0.976562
# Iter0, step 308, training accuracy 0.960938
# Iter0, step 309, training accuracy 0.96875
# Iter0, step 310, training accuracy 0.9375
# Iter0, step 311, training accuracy 0.953125
# Iter0, step 312, training accuracy 0.976562
# Iter0, step 313, training accuracy 0.96875
# Iter0, step 314, training accuracy 0.976562
# Iter0, step 315, training accuracy 0.984375
# Iter0, step 316, training accuracy 0.976562
# Iter0, step 317, training accuracy 0.9375
# Iter0, step 318, training accuracy 0.953125
# Iter0, step 319, training accuracy 0.945312
# Iter0, step 320, training accuracy 0.96875
# Iter0, step 321, training accuracy 0.992188
# Iter0, step 322, training accuracy 0.976562
# Iter0, step 323, training accuracy 0.945312
# Iter0, step 324, training accuracy 0.96875
# Iter0, step 325, training accuracy 0.953125
# Iter0, step 326, training accuracy 0.960938
# Iter0, step 327, training accuracy 0.960938
# Iter0, step 328, training accuracy 0.953125
# Iter0, step 329, training accuracy 0.96875
# Iter0, step 330, training accuracy 0.945312
# Iter0, step 331, training accuracy 0.96875
# Iter0, step 332, training accuracy 0.96875
# Iter0, step 333, training accuracy 0.960938
# Iter0, step 334, training accuracy 0.96875
# Iter0, step 335, training accuracy 0.960938
# Iter0, step 336, training accuracy 0.984375
# Iter0, step 337, training accuracy 0.960938
# Iter0, step 338, training accuracy 0.929688
# Iter0, step 339, training accuracy 0.921875
# Iter0, step 340, training accuracy 0.929688
# Iter0, step 341, training accuracy 0.960938
# Iter0, step 342, training accuracy 0.960938
# Iter0, step 343, training accuracy 0.9375
# Iter0, step 344, training accuracy 0.9375
# Iter0, step 345, training accuracy 0.96875
# Iter0, step 346, training accuracy 0.976562
# Iter0, step 347, training accuracy 0.945312
# Iter0, step 348, training accuracy 0.929688
# Iter0, step 349, training accuracy 0.976562
# Iter0, step 350, training accuracy 0.976562
# Iter0, step 351, training accuracy 0.953125
# Iter0, step 352, training accuracy 0.953125
# Iter0, step 353, training accuracy 0.945312
# Iter0, step 354, training accuracy 0.992188
# Iter0, step 355, training accuracy 0.976562
# Iter0, step 356, training accuracy 0.921875
# Iter0, step 357, training accuracy 0.960938
# Iter0, step 358, training accuracy 0.960938
# Iter0, step 359, training accuracy 0.953125
# Iter0, step 360, training accuracy 0.945312
# Iter0, step 361, training accuracy 0.96875
# Iter0, step 362, training accuracy 0.96875
# Iter0, step 363, training accuracy 0.984375
# Iter0, step 364, training accuracy 0.96875
# Iter0, step 365, training accuracy 0.96875
# Iter0, step 366, training accuracy 0.9375
# Iter0, step 367, training accuracy 0.992188
# Iter0, step 368, training accuracy 0.9375
# Iter0, step 369, training accuracy 0.96875
# Iter0, step 370, training accuracy 0.984375
# Iter0, step 371, training accuracy 0.96875
# Iter0, step 372, training accuracy 0.984375
# Iter0, step 373, training accuracy 0.945312
# Iter0, step 374, training accuracy 0.992188
# Iter0, step 375, training accuracy 0.960938
# Iter0, step 376, training accuracy 0.9375
# Iter0, step 377, training accuracy 0.984375
# Iter0, step 378, training accuracy 0.96875
# Iter0, step 379, training accuracy 0.96875
# Iter0, step 380, training accuracy 0.953125
# Iter0, step 381, training accuracy 0.96875
# Iter0, step 382, training accuracy 0.96875
# Iter0, step 383, training accuracy 0.960938
# Iter0, step 384, training accuracy 0.945312
# Iter0, step 385, training accuracy 0.992188
# Iter0, step 386, training accuracy 0.953125
# Iter0, step 387, training accuracy 0.992188
# Iter0, step 388, training accuracy 0.984375
# Iter0, step 389, training accuracy 0.984375
# Iter0, step 390, training accuracy 0.953125
# Iter0, step 391, training accuracy 0.960938
# Iter0, step 392, training accuracy 0.976562
# Iter0, step 393, training accuracy 0.960938
# Iter0, step 394, training accuracy 0.90625
# Iter0, step 395, training accuracy 0.945312
# Iter0, step 396, training accuracy 0.976562
# Iter0, step 397, training accuracy 0.960938
# Iter0, step 398, training accuracy 0.984375
# Iter0, step 399, training accuracy 0.953125
# Iter0, step 400, training accuracy 0.992188
# Iter0, step 401, training accuracy 0.960938
# Iter0, step 402, training accuracy 0.96875
# Iter0, step 403, training accuracy 0.9375
# Iter0, step 404, training accuracy 0.984375
# Iter0, step 405, training accuracy 0.992188
# Iter0, step 406, training accuracy 0.9375
# Iter0, step 407, training accuracy 0.945312
# Iter0, step 408, training accuracy 1
# Iter0, step 409, training accuracy 0.96875
# Iter0, step 410, training accuracy 0.96875
# Iter0, step 411, training accuracy 0.96875
# Iter0, step 412, training accuracy 0.984375
# Iter0, step 413, training accuracy 0.960938
# Iter0, step 414, training accuracy 0.976562
# Iter0, step 415, training accuracy 1
# Iter0, step 416, training accuracy 0.960938
# Iter0, step 417, training accuracy 1
# Iter0, step 418, training accuracy 0.984375
# Iter0, step 419, training accuracy 0.96875
# Iter0, step 420, training accuracy 0.976562
# Iter0, step 421, training accuracy 0.953125
# Iter0, step 422, training accuracy 0.984375
# Iter0, step 423, training accuracy 0.976562
# Iter0, step 424, training accuracy 0.945312
# Iter0, step 425, training accuracy 0.992188
# Iter0, step 426, training accuracy 0.992188
# Iter0, step 427, training accuracy 0.992188
# Iter0, step 428, training accuracy 0.929688
# Iter0, step 429, training accuracy 0.96875
# Iter1, step 430, training accuracy 0.960938
# Iter1, step 431, training accuracy 0.976562
# Iter1, step 432, training accuracy 0.976562
# Iter1, step 433, training accuracy 0.984375
# Iter1, step 434, training accuracy 0.96875
# Iter1, step 435, training accuracy 1
# Iter1, step 436, training accuracy 0.992188
# Iter1, step 437, training accuracy 0.984375
# Iter1, step 438, training accuracy 0.992188
# Iter1, step 439, training accuracy 0.984375
# Iter1, step 440, training accuracy 0.9375
# Iter1, step 441, training accuracy 0.976562
# Iter1, step 442, training accuracy 0.992188
# Iter1, step 443, training accuracy 0.984375
# Iter1, step 444, training accuracy 0.960938
# Iter1, step 445, training accuracy 0.976562
# Iter1, step 446, training accuracy 0.984375
# Iter1, step 447, training accuracy 0.953125
# Iter1, step 448, training accuracy 0.976562
# Iter1, step 449, training accuracy 0.976562
# Iter1, step 450, training accuracy 0.992188
# Iter1, step 451, training accuracy 1
# Iter1, step 452, training accuracy 0.984375
# Iter1, step 453, training accuracy 0.960938
# Iter1, step 454, training accuracy 0.984375
# Iter1, step 455, training accuracy 0.953125
# Iter1, step 456, training accuracy 0.984375
# Iter1, step 457, training accuracy 0.953125
# Iter1, step 458, training accuracy 0.976562
# Iter1, step 459, training accuracy 0.953125
# Iter1, step 460, training accuracy 0.976562
# Iter1, step 461, training accuracy 0.984375
# Iter1, step 462, training accuracy 0.984375
# Iter1, step 463, training accuracy 0.960938
# Iter1, step 464, training accuracy 0.984375
# Iter1, step 465, training accuracy 0.992188
# Iter1, step 466, training accuracy 0.96875
# Iter1, step 467, training accuracy 0.96875
# Iter1, step 468, training accuracy 0.992188
# Iter1, step 469, training accuracy 0.960938
# Iter1, step 470, training accuracy 0.992188
# Iter1, step 471, training accuracy 0.976562
# Iter1, step 472, training accuracy 0.96875
# Iter1, step 473, training accuracy 0.976562
# Iter1, step 474, training accuracy 0.96875
# Iter1, step 475, training accuracy 0.96875
# Iter1, step 476, training accuracy 0.96875
# Iter1, step 477, training accuracy 0.960938
# Iter1, step 478, training accuracy 0.96875
# Iter1, step 479, training accuracy 0.953125
# Iter1, step 480, training accuracy 0.96875
# Iter1, step 481, training accuracy 0.992188
# Iter1, step 482, training accuracy 0.960938
# Iter1, step 483, training accuracy 0.960938
# Iter1, step 484, training accuracy 0.984375
# Iter1, step 485, training accuracy 0.992188
# Iter1, step 486, training accuracy 0.953125
# Iter1, step 487, training accuracy 0.953125
# Iter1, step 488, training accuracy 0.976562
# Iter1, step 489, training accuracy 0.984375
# Iter1, step 490, training accuracy 0.976562
# Iter1, step 491, training accuracy 0.960938
# Iter1, step 492, training accuracy 0.984375
# Iter1, step 493, training accuracy 0.960938
# Iter1, step 494, training accuracy 0.96875
# Iter1, step 495, training accuracy 0.960938
# Iter1, step 496, training accuracy 0.976562
# Iter1, step 497, training accuracy 0.953125
# Iter1, step 498, training accuracy 0.960938
# Iter1, step 499, training accuracy 0.976562
# Iter1, step 500, training accuracy 0.976562
# Iter1, step 501, training accuracy 0.976562
# Iter1, step 502, training accuracy 0.953125
# Iter1, step 503, training accuracy 0.96875
# Iter1, step 504, training accuracy 0.960938
# Iter1, step 505, training accuracy 0.992188
# Iter1, step 506, training accuracy 0.9375
# Iter1, step 507, training accuracy 0.984375
# Iter1, step 508, training accuracy 0.945312
# Iter1, step 509, training accuracy 0.992188
# Iter1, step 510, training accuracy 0.984375
# Iter1, step 511, training accuracy 0.976562
# Iter1, step 512, training accuracy 0.976562
# Iter1, step 513, training accuracy 0.96875
# Iter1, step 514, training accuracy 0.9375
# Iter1, step 515, training accuracy 0.992188
# Iter1, step 516, training accuracy 0.960938
# Iter1, step 517, training accuracy 0.96875
# Iter1, step 518, training accuracy 0.976562
# Iter1, step 519, training accuracy 0.992188
# Iter1, step 520, training accuracy 0.976562
# Iter1, step 521, training accuracy 0.96875
# Iter1, step 522, training accuracy 0.984375
# Iter1, step 523, training accuracy 0.96875
# Iter1, step 524, training accuracy 0.976562
# Iter1, step 525, training accuracy 0.984375
# Iter1, step 526, training accuracy 0.984375
# Iter1, step 527, training accuracy 0.960938
# Iter1, step 528, training accuracy 0.96875
# Iter1, step 529, training accuracy 0.96875
# Iter1, step 530, training accuracy 0.96875
# Iter1, step 531, training accuracy 0.992188
# Iter1, step 532, training accuracy 0.945312
# Iter1, step 533, training accuracy 0.976562
# Iter1, step 534, training accuracy 0.960938
# Iter1, step 535, training accuracy 0.984375
# Iter1, step 536, training accuracy 0.953125
# Iter1, step 537, training accuracy 0.992188
# Iter1, step 538, training accuracy 0.96875
# Iter1, step 539, training accuracy 0.96875
# Iter1, step 540, training accuracy 0.976562
# Iter1, step 541, training accuracy 0.960938
# Iter1, step 542, training accuracy 0.992188
# Iter1, step 543, training accuracy 0.945312
# Iter1, step 544, training accuracy 0.96875
# Iter1, step 545, training accuracy 0.9375
# Iter1, step 546, training accuracy 0.96875
# Iter1, step 547, training accuracy 0.96875
# Iter1, step 548, training accuracy 0.960938
# Iter1, step 549, training accuracy 0.96875
# Iter1, step 550, training accuracy 0.945312
# Iter1, step 551, training accuracy 0.960938
# Iter1, step 552, training accuracy 0.976562
# Iter1, step 553, training accuracy 0.992188
# Iter1, step 554, training accuracy 0.953125
# Iter1, step 555, training accuracy 0.976562
# Iter1, step 556, training accuracy 0.9375
# Iter1, step 557, training accuracy 0.976562
# Iter1, step 558, training accuracy 0.96875
# Iter1, step 559, training accuracy 0.960938
# Iter1, step 560, training accuracy 0.984375
# Iter1, step 561, training accuracy 0.945312
# Iter1, step 562, training accuracy 0.960938
# Iter1, step 563, training accuracy 0.945312
# Iter1, step 564, training accuracy 0.9375
# Iter1, step 565, training accuracy 0.992188
# Iter1, step 566, training accuracy 0.984375
# Iter1, step 567, training accuracy 1
# Iter1, step 568, training accuracy 0.992188
# Iter1, step 569, training accuracy 0.945312
# Iter1, step 570, training accuracy 0.992188
# Iter1, step 571, training accuracy 0.984375
# Iter1, step 572, training accuracy 0.953125
# Iter1, step 573, training accuracy 0.960938
# Iter1, step 574, training accuracy 0.992188
# Iter1, step 575, training accuracy 0.976562
# Iter1, step 576, training accuracy 0.984375
# Iter1, step 577, training accuracy 0.984375
# Iter1, step 578, training accuracy 0.976562
# Iter1, step 579, training accuracy 0.984375
# Iter1, step 580, training accuracy 0.96875
# Iter1, step 581, training accuracy 0.992188
# Iter1, step 582, training accuracy 0.992188
# Iter1, step 583, training accuracy 0.992188
# Iter1, step 584, training accuracy 0.960938
# Iter1, step 585, training accuracy 0.976562
# Iter1, step 586, training accuracy 0.992188
# Iter1, step 587, training accuracy 0.96875
# Iter1, step 588, training accuracy 0.992188
# Iter1, step 589, training accuracy 0.960938
# Iter1, step 590, training accuracy 0.976562
# Iter1, step 591, training accuracy 0.976562
# Iter1, step 592, training accuracy 0.984375
# Iter1, step 593, training accuracy 0.976562
# Iter1, step 594, training accuracy 0.976562
# Iter1, step 595, training accuracy 0.976562
# Iter1, step 596, training accuracy 0.960938
# Iter1, step 597, training accuracy 0.992188
# Iter1, step 598, training accuracy 0.984375
# Iter1, step 599, training accuracy 0.960938
# Iter1, step 600, training accuracy 0.953125
# Iter1, step 601, training accuracy 0.984375
# Iter1, step 602, training accuracy 0.976562
# Iter1, step 603, training accuracy 0.96875
# Iter1, step 604, training accuracy 0.992188
# Iter1, step 605, training accuracy 0.976562
# Iter1, step 606, training accuracy 0.96875
# Iter1, step 607, training accuracy 0.976562
# Iter1, step 608, training accuracy 0.96875
# Iter1, step 609, training accuracy 0.984375
# Iter1, step 610, training accuracy 0.9375
# Iter1, step 611, training accuracy 0.96875
# Iter1, step 612, training accuracy 0.96875
# Iter1, step 613, training accuracy 0.992188
# Iter1, step 614, training accuracy 0.945312
# Iter1, step 615, training accuracy 0.992188
# Iter1, step 616, training accuracy 1
# Iter1, step 617, training accuracy 0.992188
# Iter1, step 618, training accuracy 0.953125
# Iter1, step 619, training accuracy 0.984375
# Iter1, step 620, training accuracy 0.976562
# Iter1, step 621, training accuracy 0.976562
# Iter1, step 622, training accuracy 0.96875
# Iter1, step 623, training accuracy 0.984375
# Iter1, step 624, training accuracy 0.984375
# Iter1, step 625, training accuracy 0.984375
# Iter1, step 626, training accuracy 0.976562
# Iter1, step 627, training accuracy 0.992188
# Iter1, step 628, training accuracy 0.96875
# Iter1, step 629, training accuracy 0.96875
# Iter1, step 630, training accuracy 0.960938
# Iter1, step 631, training accuracy 0.984375
# Iter1, step 632, training accuracy 0.960938
# Iter1, step 633, training accuracy 0.984375
# Iter1, step 634, training accuracy 0.960938
# Iter1, step 635, training accuracy 0.960938
# Iter1, step 636, training accuracy 0.984375
# Iter1, step 637, training accuracy 0.96875
# Iter1, step 638, training accuracy 0.976562
# Iter1, step 639, training accuracy 0.96875
# Iter1, step 640, training accuracy 0.976562
# Iter1, step 641, training accuracy 0.976562
# Iter1, step 642, training accuracy 0.96875
# Iter1, step 643, training accuracy 0.960938
# Iter1, step 644, training accuracy 0.960938
# Iter1, step 645, training accuracy 0.960938
# Iter1, step 646, training accuracy 0.96875
# Iter1, step 647, training accuracy 0.976562
# Iter1, step 648, training accuracy 0.960938
# Iter1, step 649, training accuracy 0.976562
# Iter1, step 650, training accuracy 0.960938
# Iter1, step 651, training accuracy 0.929688
# Iter1, step 652, training accuracy 0.976562
# Iter1, step 653, training accuracy 0.984375
# Iter1, step 654, training accuracy 0.960938
# Iter1, step 655, training accuracy 0.976562
# Iter1, step 656, training accuracy 0.9375
# Iter1, step 657, training accuracy 0.976562
# Iter1, step 658, training accuracy 0.976562
# Iter1, step 659, training accuracy 0.96875
# Iter1, step 660, training accuracy 0.96875
# Iter1, step 661, training accuracy 0.96875
# Iter1, step 662, training accuracy 0.984375
# Iter1, step 663, training accuracy 0.976562
# Iter1, step 664, training accuracy 0.984375
# Iter1, step 665, training accuracy 0.976562
# Iter1, step 666, training accuracy 0.96875
# Iter1, step 667, training accuracy 0.984375
# Iter1, step 668, training accuracy 0.992188
# Iter1, step 669, training accuracy 0.96875
# Iter1, step 670, training accuracy 0.976562
# Iter1, step 671, training accuracy 0.945312
# Iter1, step 672, training accuracy 0.976562
# Iter1, step 673, training accuracy 0.953125
# Iter1, step 674, training accuracy 0.953125
# Iter1, step 675, training accuracy 0.96875
# Iter1, step 676, training accuracy 0.976562
# Iter1, step 677, training accuracy 0.984375
# Iter1, step 678, training accuracy 0.953125
# Iter1, step 679, training accuracy 0.976562
# Iter1, step 680, training accuracy 0.96875
# Iter1, step 681, training accuracy 0.976562
# Iter1, step 682, training accuracy 0.960938
# Iter1, step 683, training accuracy 0.96875
# Iter1, step 684, training accuracy 1
# Iter1, step 685, training accuracy 0.96875
# Iter1, step 686, training accuracy 0.984375
# Iter1, step 687, training accuracy 0.9375
# Iter1, step 688, training accuracy 0.960938
# Iter1, step 689, training accuracy 1
# Iter1, step 690, training accuracy 0.992188
# Iter1, step 691, training accuracy 0.96875
# Iter1, step 692, training accuracy 0.960938
# Iter1, step 693, training accuracy 0.953125
# Iter1, step 694, training accuracy 0.960938
# Iter1, step 695, training accuracy 0.953125
# Iter1, step 696, training accuracy 0.96875
# Iter1, step 697, training accuracy 0.984375
# Iter1, step 698, training accuracy 0.984375
# Iter1, step 699, training accuracy 0.984375
# Iter1, step 700, training accuracy 0.984375
# Iter1, step 701, training accuracy 0.984375
# Iter1, step 702, training accuracy 0.984375
# Iter1, step 703, training accuracy 0.984375
# Iter1, step 704, training accuracy 0.9375
# Iter1, step 705, training accuracy 0.984375
# Iter1, step 706, training accuracy 0.96875
# Iter1, step 707, training accuracy 0.984375
# Iter1, step 708, training accuracy 0.992188
# Iter1, step 709, training accuracy 0.976562
# Iter1, step 710, training accuracy 0.96875
# Iter1, step 711, training accuracy 0.945312
# Iter1, step 712, training accuracy 0.953125
# Iter1, step 713, training accuracy 0.960938
# Iter1, step 714, training accuracy 0.984375
# Iter1, step 715, training accuracy 0.953125
# Iter1, step 716, training accuracy 0.984375
# Iter1, step 717, training accuracy 0.992188
# Iter1, step 718, training accuracy 0.96875
# Iter1, step 719, training accuracy 0.953125
# Iter1, step 720, training accuracy 0.992188
# Iter1, step 721, training accuracy 1
# Iter1, step 722, training accuracy 0.96875
# Iter1, step 723, training accuracy 0.992188
# Iter1, step 724, training accuracy 0.96875
# Iter1, step 725, training accuracy 1
# Iter1, step 726, training accuracy 0.976562
# Iter1, step 727, training accuracy 0.984375
# Iter1, step 728, training accuracy 0.992188
# Iter1, step 729, training accuracy 1
# Iter1, step 730, training accuracy 0.96875
# Iter1, step 731, training accuracy 0.96875
# Iter1, step 732, training accuracy 0.992188
# Iter1, step 733, training accuracy 1
# Iter1, step 734, training accuracy 0.984375
# Iter1, step 735, training accuracy 0.992188
# Iter1, step 736, training accuracy 0.976562
# Iter1, step 737, training accuracy 0.976562
# Iter1, step 738, training accuracy 0.976562
# Iter1, step 739, training accuracy 0.992188
# Iter1, step 740, training accuracy 0.984375
# Iter1, step 741, training accuracy 0.984375
# Iter1, step 742, training accuracy 0.96875
# Iter1, step 743, training accuracy 0.992188
# Iter1, step 744, training accuracy 0.976562
# Iter1, step 745, training accuracy 0.976562
# Iter1, step 746, training accuracy 0.960938
# Iter1, step 747, training accuracy 0.984375
# Iter1, step 748, training accuracy 0.984375
# Iter1, step 749, training accuracy 0.976562
# Iter1, step 750, training accuracy 0.96875
# Iter1, step 751, training accuracy 1
# Iter1, step 752, training accuracy 1
# Iter1, step 753, training accuracy 0.96875
# Iter1, step 754, training accuracy 0.984375
# Iter1, step 755, training accuracy 0.984375
# Iter1, step 756, training accuracy 0.96875
# Iter1, step 757, training accuracy 0.96875
# Iter1, step 758, training accuracy 0.976562
# Iter1, step 759, training accuracy 0.960938
# Iter1, step 760, training accuracy 0.992188
# Iter1, step 761, training accuracy 0.953125
# Iter1, step 762, training accuracy 0.992188
# Iter1, step 763, training accuracy 0.976562
# Iter1, step 764, training accuracy 0.992188
# Iter1, step 765, training accuracy 0.992188
# Iter1, step 766, training accuracy 0.96875
# Iter1, step 767, training accuracy 0.992188
# Iter1, step 768, training accuracy 0.992188
# Iter1, step 769, training accuracy 0.976562
# Iter1, step 770, training accuracy 0.96875
# Iter1, step 771, training accuracy 0.992188
# Iter1, step 772, training accuracy 0.976562
# Iter1, step 773, training accuracy 1
# Iter1, step 774, training accuracy 0.992188
# Iter1, step 775, training accuracy 0.96875
# Iter1, step 776, training accuracy 0.992188
# Iter1, step 777, training accuracy 0.984375
# Iter1, step 778, training accuracy 0.992188
# Iter1, step 779, training accuracy 0.992188
# Iter1, step 780, training accuracy 0.96875
# Iter1, step 781, training accuracy 0.976562
# Iter1, step 782, training accuracy 0.992188
# Iter1, step 783, training accuracy 0.984375
# Iter1, step 784, training accuracy 0.96875
# Iter1, step 785, training accuracy 0.976562
# Iter1, step 786, training accuracy 0.992188
# Iter1, step 787, training accuracy 0.976562
# Iter1, step 788, training accuracy 0.976562
# Iter1, step 789, training accuracy 0.960938
# Iter1, step 790, training accuracy 0.992188
# Iter1, step 791, training accuracy 0.976562
# Iter1, step 792, training accuracy 1
# Iter1, step 793, training accuracy 0.984375
# Iter1, step 794, training accuracy 0.976562
# Iter1, step 795, training accuracy 0.984375
# Iter1, step 796, training accuracy 0.976562
# Iter1, step 797, training accuracy 0.984375
# Iter1, step 798, training accuracy 0.984375
# Iter1, step 799, training accuracy 0.992188
# Iter1, step 800, training accuracy 0.984375
# Iter1, step 801, training accuracy 0.984375
# Iter1, step 802, training accuracy 1
# Iter1, step 803, training accuracy 0.992188
# Iter1, step 804, training accuracy 1
# Iter1, step 805, training accuracy 0.96875
# Iter1, step 806, training accuracy 0.96875
# Iter1, step 807, training accuracy 0.992188
# Iter1, step 808, training accuracy 0.984375
# Iter1, step 809, training accuracy 0.984375
# Iter1, step 810, training accuracy 0.976562
# Iter1, step 811, training accuracy 1
# Iter1, step 812, training accuracy 0.976562
# Iter1, step 813, training accuracy 0.984375
# Iter1, step 814, training accuracy 0.96875
# Iter1, step 815, training accuracy 0.992188
# Iter1, step 816, training accuracy 0.976562
# Iter1, step 817, training accuracy 0.960938
# Iter1, step 818, training accuracy 0.984375
# Iter1, step 819, training accuracy 1
# Iter1, step 820, training accuracy 0.984375
# Iter1, step 821, training accuracy 0.96875
# Iter1, step 822, training accuracy 0.992188
# Iter1, step 823, training accuracy 0.976562
# Iter1, step 824, training accuracy 0.992188
# Iter1, step 825, training accuracy 0.992188
# Iter1, step 826, training accuracy 0.976562
# Iter1, step 827, training accuracy 0.960938
# Iter1, step 828, training accuracy 0.992188
# Iter1, step 829, training accuracy 0.976562
# Iter1, step 830, training accuracy 0.976562
# Iter1, step 831, training accuracy 0.976562
# Iter1, step 832, training accuracy 0.96875
# Iter1, step 833, training accuracy 0.96875
# Iter1, step 834, training accuracy 0.984375
# Iter1, step 835, training accuracy 0.992188
# Iter1, step 836, training accuracy 0.992188
# Iter1, step 837, training accuracy 0.953125
# Iter1, step 838, training accuracy 0.984375
# Iter1, step 839, training accuracy 0.984375
# Iter1, step 840, training accuracy 0.984375
# Iter1, step 841, training accuracy 1
# Iter1, step 842, training accuracy 0.984375
# Iter1, step 843, training accuracy 0.976562
# Iter1, step 844, training accuracy 0.976562
# Iter1, step 845, training accuracy 0.976562
# Iter1, step 846, training accuracy 0.953125
# Iter1, step 847, training accuracy 0.96875
# Iter1, step 848, training accuracy 0.984375
# Iter1, step 849, training accuracy 0.976562
# Iter1, step 850, training accuracy 0.976562
# Iter1, step 851, training accuracy 0.976562
# Iter1, step 852, training accuracy 0.984375
# Iter1, step 853, training accuracy 0.984375
# Iter1, step 854, training accuracy 0.953125
# Iter1, step 855, training accuracy 1
# Iter1, step 856, training accuracy 0.976562
# Iter1, step 857, training accuracy 0.96875
# Iter1, step 858, training accuracy 0.960938
# Iter1, step 859, training accuracy 0.96875
# Iter2, step 860, training accuracy 0.992188
# Iter2, step 861, training accuracy 0.96875
# Iter2, step 862, training accuracy 0.976562
# Iter2, step 863, training accuracy 0.976562
# Iter2, step 864, training accuracy 0.984375
# Iter2, step 865, training accuracy 0.992188
# Iter2, step 866, training accuracy 0.984375
# Iter2, step 867, training accuracy 0.984375
# Iter2, step 868, training accuracy 0.992188
# Iter2, step 869, training accuracy 0.984375
# Iter2, step 870, training accuracy 0.96875
# Iter2, step 871, training accuracy 0.984375
# Iter2, step 872, training accuracy 0.976562
# Iter2, step 873, training accuracy 1
# Iter2, step 874, training accuracy 0.96875
# Iter2, step 875, training accuracy 1
# Iter2, step 876, training accuracy 0.984375
# Iter2, step 877, training accuracy 0.992188
# Iter2, step 878, training accuracy 0.96875
# Iter2, step 879, training accuracy 0.984375
# Iter2, step 880, training accuracy 0.992188
# Iter2, step 881, training accuracy 0.992188
# Iter2, step 882, training accuracy 0.984375
# Iter2, step 883, training accuracy 0.96875
# Iter2, step 884, training accuracy 0.976562
# Iter2, step 885, training accuracy 0.976562
# Iter2, step 886, training accuracy 1
# Iter2, step 887, training accuracy 0.992188
# Iter2, step 888, training accuracy 0.992188
# Iter2, step 889, training accuracy 0.96875
# Iter2, step 890, training accuracy 0.984375
# Iter2, step 891, training accuracy 0.96875
# Iter2, step 892, training accuracy 0.976562
# Iter2, step 893, training accuracy 0.984375
# Iter2, step 894, training accuracy 0.992188
# Iter2, step 895, training accuracy 0.984375
# Iter2, step 896, training accuracy 0.984375
# Iter2, step 897, training accuracy 0.984375
# Iter2, step 898, training accuracy 1
# Iter2, step 899, training accuracy 0.992188
# Iter2, step 900, training accuracy 1
# Iter2, step 901, training accuracy 0.992188
# Iter2, step 902, training accuracy 0.976562
# Iter2, step 903, training accuracy 0.984375
# Iter2, step 904, training accuracy 0.96875
# Iter2, step 905, training accuracy 1
# Iter2, step 906, training accuracy 1
# Iter2, step 907, training accuracy 0.96875
# Iter2, step 908, training accuracy 0.984375
# Iter2, step 909, training accuracy 0.976562
# Iter2, step 910, training accuracy 1
# Iter2, step 911, training accuracy 0.992188
# Iter2, step 912, training accuracy 0.984375
# Iter2, step 913, training accuracy 0.984375
# Iter2, step 914, training accuracy 0.992188
# Iter2, step 915, training accuracy 0.976562
# Iter2, step 916, training accuracy 0.984375
# Iter2, step 917, training accuracy 0.96875
# Iter2, step 918, training accuracy 0.96875
# Iter2, step 919, training accuracy 0.960938
# Iter2, step 920, training accuracy 0.992188
# Iter2, step 921, training accuracy 0.984375
# Iter2, step 922, training accuracy 0.976562
# Iter2, step 923, training accuracy 0.992188
# Iter2, step 924, training accuracy 0.984375
# Iter2, step 925, training accuracy 0.984375
# Iter2, step 926, training accuracy 0.984375
# Iter2, step 927, training accuracy 0.992188
# Iter2, step 928, training accuracy 0.984375
# Iter2, step 929, training accuracy 0.96875
# Iter2, step 930, training accuracy 0.953125
# Iter2, step 931, training accuracy 0.960938
# Iter2, step 932, training accuracy 0.96875
# Iter2, step 933, training accuracy 0.992188
# Iter2, step 934, training accuracy 1
# Iter2, step 935, training accuracy 1
# Iter2, step 936, training accuracy 0.976562
# Iter2, step 937, training accuracy 0.984375
# Iter2, step 938, training accuracy 0.984375
# Iter2, step 939, training accuracy 1
# Iter2, step 940, training accuracy 0.992188
# Iter2, step 941, training accuracy 0.96875
# Iter2, step 942, training accuracy 0.992188
# Iter2, step 943, training accuracy 0.992188
# Iter2, step 944, training accuracy 0.984375
# Iter2, step 945, training accuracy 0.984375
# Iter2, step 946, training accuracy 0.96875
# Iter2, step 947, training accuracy 0.976562
# Iter2, step 948, training accuracy 0.984375
# Iter2, step 949, training accuracy 0.984375
# Iter2, step 950, training accuracy 0.984375
# Iter2, step 951, training accuracy 0.984375
# Iter2, step 952, training accuracy 0.984375
# Iter2, step 953, training accuracy 0.976562
# Iter2, step 954, training accuracy 0.992188
# Iter2, step 955, training accuracy 0.976562
# Iter2, step 956, training accuracy 0.984375
# Iter2, step 957, training accuracy 0.984375
# Iter2, step 958, training accuracy 0.984375
# Iter2, step 959, training accuracy 0.96875
# Iter2, step 960, training accuracy 1
# Iter2, step 961, training accuracy 0.984375
# Iter2, step 962, training accuracy 0.992188
# Iter2, step 963, training accuracy 0.992188
# Iter2, step 964, training accuracy 0.960938
# Iter2, step 965, training accuracy 0.976562
# Iter2, step 966, training accuracy 0.984375
# Iter2, step 967, training accuracy 1
# Iter2, step 968, training accuracy 0.992188
# Iter2, step 969, training accuracy 0.992188
# Iter2, step 970, training accuracy 0.976562
# Iter2, step 971, training accuracy 0.96875
# Iter2, step 972, training accuracy 0.976562
# Iter2, step 973, training accuracy 0.992188
# Iter2, step 974, training accuracy 0.992188
# Iter2, step 975, training accuracy 0.984375
# Iter2, step 976, training accuracy 0.984375
# Iter2, step 977, training accuracy 0.976562
# Iter2, step 978, training accuracy 0.984375
# Iter2, step 979, training accuracy 0.960938
# Iter2, step 980, training accuracy 1
# Iter2, step 981, training accuracy 0.976562
# Iter2, step 982, training accuracy 0.984375
# Iter2, step 983, training accuracy 0.96875
# Iter2, step 984, training accuracy 1
# Iter2, step 985, training accuracy 0.984375
# Iter2, step 986, training accuracy 0.992188
# Iter2, step 987, training accuracy 0.96875
# Iter2, step 988, training accuracy 0.992188
# Iter2, step 989, training accuracy 0.976562
# Iter2, step 990, training accuracy 0.96875
# Iter2, step 991, training accuracy 0.992188
# Iter2, step 992, training accuracy 0.960938
# Iter2, step 993, training accuracy 1
# Iter2, step 994, training accuracy 0.992188
# Iter2, step 995, training accuracy 0.992188
# Iter2, step 996, training accuracy 0.976562
# Iter2, step 997, training accuracy 0.976562
# Iter2, step 998, training accuracy 0.96875
# Iter2, step 999, training accuracy 0.992188
# Iter2, step 1000, training accuracy 0.992188
# Iter2, step 1001, training accuracy 0.976562
# Iter2, step 1002, training accuracy 0.992188
# Iter2, step 1003, training accuracy 0.992188
# Iter2, step 1004, training accuracy 0.984375
# Iter2, step 1005, training accuracy 0.976562
# Iter2, step 1006, training accuracy 0.992188
# Iter2, step 1007, training accuracy 0.984375
# Iter2, step 1008, training accuracy 0.992188
# Iter2, step 1009, training accuracy 0.984375
# Iter2, step 1010, training accuracy 1
# Iter2, step 1011, training accuracy 1
# Iter2, step 1012, training accuracy 0.96875
# Iter2, step 1013, training accuracy 0.984375
# Iter2, step 1014, training accuracy 0.984375
# Iter2, step 1015, training accuracy 0.976562
# Iter2, step 1016, training accuracy 0.992188
# Iter2, step 1017, training accuracy 0.976562
# Iter2, step 1018, training accuracy 0.96875
# Iter2, step 1019, training accuracy 0.976562
# Iter2, step 1020, training accuracy 0.984375
# Iter2, step 1021, training accuracy 0.976562
# Iter2, step 1022, training accuracy 1
# Iter2, step 1023, training accuracy 0.984375
# Iter2, step 1024, training accuracy 0.992188
# Iter2, step 1025, training accuracy 0.984375
# Iter2, step 1026, training accuracy 0.992188
# ...
# Iter10, step 4612, training accuracy 1
# Iter10, step 4613, training accuracy 1
# Iter10, step 4614, training accuracy 1
# Iter10, step 4615, training accuracy 1
# Iter10, step 4616, training accuracy 1
# Iter10, step 4617, training accuracy 0.992188
# Iter10, step 4618, training accuracy 1
# Iter10, step 4619, training accuracy 1
# Iter10, step 4620, training accuracy 1
# Iter10, step 4621, training accuracy 1
# Iter10, step 4622, training accuracy 1
# Iter10, step 4623, training accuracy 1
# Iter10, step 4624, training accuracy 1
# Iter10, step 4625, training accuracy 1
# Iter10, step 4626, training accuracy 1
# Iter10, step 4627, training accuracy 1
# Iter10, step 4628, training accuracy 1
# Iter10, step 4629, training accuracy 1
# Iter10, step 4630, training accuracy 1
# Iter10, step 4631, training accuracy 1
# Iter10, step 4632, training accuracy 1
# Iter10, step 4633, training accuracy 0.992188
# Iter10, step 4634, training accuracy 0.984375
# Iter10, step 4635, training accuracy 0.984375
# Iter10, step 4636, training accuracy 0.992188
# Iter10, step 4637, training accuracy 1
# Iter10, step 4638, training accuracy 0.992188
# Iter10, step 4639, training accuracy 0.984375
# Iter10, step 4640, training accuracy 1
# Iter10, step 4641, training accuracy 0.984375
# Iter10, step 4642, training accuracy 1
# Iter10, step 4643, training accuracy 0.992188
# Iter10, step 4644, training accuracy 1
# Iter10, step 4645, training accuracy 1
# Iter10, step 4646, training accuracy 1
# Iter10, step 4647, training accuracy 1
# Iter10, step 4648, training accuracy 0.992188
# Iter10, step 4649, training accuracy 0.984375
# Iter10, step 4650, training accuracy 1
# Iter10, step 4651, training accuracy 0.992188
# Iter10, step 4652, training accuracy 0.992188
# Iter10, step 4653, training accuracy 0.984375
# Iter10, step 4654, training accuracy 1
# Iter10, step 4655, training accuracy 1
# Iter10, step 4656, training accuracy 1
# Iter10, step 4657, training accuracy 1
# Iter10, step 4658, training accuracy 1
# Iter10, step 4659, training accuracy 0.992188
# Iter10, step 4660, training accuracy 1
# Iter10, step 4661, training accuracy 1
# Iter10, step 4662, training accuracy 0.992188
# Iter10, step 4663, training accuracy 1
# Iter10, step 4664, training accuracy 1
# Iter10, step 4665, training accuracy 1
# Iter10, step 4666, training accuracy 1
# Iter10, step 4667, training accuracy 1
# Iter10, step 4668, training accuracy 1
# Iter10, step 4669, training accuracy 1
# Iter10, step 4670, training accuracy 1
# Iter10, step 4671, training accuracy 0.992188
# Iter10, step 4672, training accuracy 0.992188
# Iter10, step 4673, training accuracy 1
# Iter10, step 4674, training accuracy 1
# Iter10, step 4675, training accuracy 0.992188
# Iter10, step 4676, training accuracy 1
# Iter10, step 4677, training accuracy 1
# Iter10, step 4678, training accuracy 0.992188
# Iter10, step 4679, training accuracy 1
# Iter10, step 4680, training accuracy 1
# Iter10, step 4681, training accuracy 0.992188
# Iter10, step 4682, training accuracy 1
# Iter10, step 4683, training accuracy 0.992188
# Iter10, step 4684, training accuracy 0.992188
# Iter10, step 4685, training accuracy 1
# Iter10, step 4686, training accuracy 0.984375
# Iter10, step 4687, training accuracy 1
# Iter10, step 4688, training accuracy 1
# Iter10, step 4689, training accuracy 0.992188
# Iter10, step 4690, training accuracy 1
# Iter10, step 4691, training accuracy 0.992188
# Iter10, step 4692, training accuracy 1
# Iter10, step 4693, training accuracy 1
# Iter10, step 4694, training accuracy 0.992188
# Iter10, step 4695, training accuracy 1
# Iter10, step 4696, training accuracy 1
# Iter10, step 4697, training accuracy 1
# Iter10, step 4698, training accuracy 0.992188
# Iter10, step 4699, training accuracy 0.992188
# Iter10, step 4700, training accuracy 0.984375
# Iter10, step 4701, training accuracy 1
# Iter10, step 4702, training accuracy 0.992188
# Iter10, step 4703, training accuracy 0.976562
# Iter10, step 4704, training accuracy 0.992188
# Iter10, step 4705, training accuracy 0.992188
# Iter10, step 4706, training accuracy 1
# Iter10, step 4707, training accuracy 0.992188
# Iter10, step 4708, training accuracy 1
# Iter10, step 4709, training accuracy 0.984375
# Iter10, step 4710, training accuracy 1
# Iter10, step 4711, training accuracy 1
# Iter10, step 4712, training accuracy 1
# Iter10, step 4713, training accuracy 1
# Iter10, step 4714, training accuracy 0.976562
# Iter10, step 4715, training accuracy 0.992188
# Iter10, step 4716, training accuracy 1
# Iter10, step 4717, training accuracy 0.992188
# Iter10, step 4718, training accuracy 1
# Iter10, step 4719, training accuracy 1
# Iter10, step 4720, training accuracy 1
# Iter10, step 4721, training accuracy 1
# Iter10, step 4722, training accuracy 1
# Iter10, step 4723, training accuracy 0.992188
# Iter10, step 4724, training accuracy 1
# Iter10, step 4725, training accuracy 1
# Iter10, step 4726, training accuracy 1
# Iter11, step 4727, training accuracy 1
# Iter11, step 4728, training accuracy 0.992188
# Iter11, step 4729, training accuracy 1
# Iter11, step 4730, training accuracy 1
# Iter11, step 4731, training accuracy 1
# Iter11, step 4732, training accuracy 1
# Iter11, step 4733, training accuracy 0.992188
# Iter11, step 4734, training accuracy 1
# Iter11, step 4735, training accuracy 1
# Iter11, step 4736, training accuracy 0.992188
# Iter11, step 4737, training accuracy 1
# Iter11, step 4738, training accuracy 1
# Iter11, step 4739, training accuracy 1
# Iter11, step 4740, training accuracy 1
# Iter11, step 4741, training accuracy 0.992188
# Iter11, step 4742, training accuracy 0.992188
# Iter11, step 4743, training accuracy 1
# Iter11, step 4744, training accuracy 1
# Iter11, step 4745, training accuracy 0.992188
# Iter11, step 4746, training accuracy 1
# Iter11, step 4747, training accuracy 1
# Iter11, step 4748, training accuracy 1
# Iter11, step 4749, training accuracy 1
# Iter11, step 4750, training accuracy 1
# Iter11, step 4751, training accuracy 1
# Iter11, step 4752, training accuracy 1
# Iter11, step 4753, training accuracy 0.992188
# Iter11, step 4754, training accuracy 1
# Iter11, step 4755, training accuracy 1
# Iter11, step 4756, training accuracy 0.992188
# Iter11, step 4757, training accuracy 1
# Iter11, step 4758, training accuracy 1
# Iter11, step 4759, training accuracy 1
# Iter11, step 4760, training accuracy 0.992188
# Iter11, step 4761, training accuracy 1
# Iter11, step 4762, training accuracy 1
# Iter11, step 4763, training accuracy 1
# Iter11, step 4764, training accuracy 1
# Iter11, step 4765, training accuracy 1
# Iter11, step 4766, training accuracy 1
# Iter11, step 4767, training accuracy 1
# Iter11, step 4768, training accuracy 1
# Iter11, step 4769, training accuracy 0.992188
# Iter11, step 4770, training accuracy 1
# Iter11, step 4771, training accuracy 1
# Iter11, step 4772, training accuracy 1
# Iter11, step 4773, training accuracy 1
# Iter11, step 4774, training accuracy 1
# Iter11, step 4775, training accuracy 0.992188
# Iter11, step 4776, training accuracy 1
# Iter11, step 4777, training accuracy 1
# Iter11, step 4778, training accuracy 1
# Iter11, step 4779, training accuracy 0.992188
# Iter11, step 4780, training accuracy 0.992188
# Iter11, step 4781, training accuracy 1
# Iter11, step 4782, training accuracy 0.984375
# Iter11, step 4783, training accuracy 1
# Iter11, step 4784, training accuracy 1
# Iter11, step 4785, training accuracy 1
# Iter11, step 4786, training accuracy 1
# Iter11, step 4787, training accuracy 1
# Iter11, step 4788, training accuracy 1
# Iter11, step 4789, training accuracy 1
# Iter11, step 4790, training accuracy 1
# Iter11, step 4791, training accuracy 0.992188
# Iter11, step 4792, training accuracy 1
# Iter11, step 4793, training accuracy 1
# Iter11, step 4794, training accuracy 0.992188
# Iter11, step 4795, training accuracy 1
# Iter11, step 4796, training accuracy 1
# Iter11, step 4797, training accuracy 1
# Iter11, step 4798, training accuracy 0.984375
# Iter11, step 4799, training accuracy 0.992188
# Iter11, step 4800, training accuracy 1
# Iter11, step 4801, training accuracy 1
# Iter11, step 4802, training accuracy 0.992188
# Iter11, step 4803, training accuracy 1
# Iter11, step 4804, training accuracy 1
# Iter11, step 4805, training accuracy 1
# Iter11, step 4806, training accuracy 1
# Iter11, step 4807, training accuracy 1
# Iter11, step 4808, training accuracy 1
# Iter11, step 4809, training accuracy 0.992188
# Iter11, step 4810, training accuracy 0.992188
# Iter11, step 4811, training accuracy 1
# Iter11, step 4812, training accuracy 1
# Iter11, step 4813, training accuracy 0.992188
# Iter11, step 4814, training accuracy 1
# Iter11, step 4815, training accuracy 1
# Iter11, step 4816, training accuracy 1
# Iter11, step 4817, training accuracy 1
# Iter11, step 4818, training accuracy 1
# Iter11, step 4819, training accuracy 1
# Iter11, step 4820, training accuracy 1
# Iter11, step 4821, training accuracy 1
# Iter11, step 4822, training accuracy 1
# Iter11, step 4823, training accuracy 1
# Iter11, step 4824, training accuracy 0.992188
# Iter11, step 4825, training accuracy 1
# Iter11, step 4826, training accuracy 1
# Iter11, step 4827, training accuracy 1
# Iter11, step 4828, training accuracy 1
# Iter11, step 4829, training accuracy 1
# Iter11, step 4830, training accuracy 0.992188
# Iter11, step 4831, training accuracy 1
# Iter11, step 4832, training accuracy 1
# Iter11, step 4833, training accuracy 1
# Iter11, step 4834, training accuracy 1
# Iter11, step 4835, training accuracy 1
# Iter11, step 4836, training accuracy 1
# Iter11, step 4837, training accuracy 1
# Iter11, step 4838, training accuracy 0.992188
# Iter11, step 4839, training accuracy 1
# Iter11, step 4840, training accuracy 1
# Iter11, step 4841, training accuracy 1
# Iter11, step 4842, training accuracy 0.984375
# Iter11, step 4843, training accuracy 1
# Iter11, step 4844, training accuracy 0.992188
# Iter11, step 4845, training accuracy 1
# Iter11, step 4846, training accuracy 1
# Iter11, step 4847, training accuracy 1
# Iter11, step 4848, training accuracy 0.992188
# Iter11, step 4849, training accuracy 0.992188
# Iter11, step 4850, training accuracy 1
# Iter11, step 4851, training accuracy 0.992188
# Iter11, step 4852, training accuracy 0.984375
# Iter11, step 4853, training accuracy 1
# Iter11, step 4854, training accuracy 1
# Iter11, step 4855, training accuracy 1
# Iter11, step 4856, training accuracy 1
# Iter11, step 4857, training accuracy 1
# Iter11, step 4858, training accuracy 1
# Iter11, step 4859, training accuracy 1
# Iter11, step 4860, training accuracy 1
# Iter11, step 4861, training accuracy 1
# Iter11, step 4862, training accuracy 1
# Iter11, step 4863, training accuracy 1
# Iter11, step 4864, training accuracy 1
# Iter11, step 4865, training accuracy 0.992188
# Iter11, step 4866, training accuracy 0.984375
# Iter11, step 4867, training accuracy 1
# Iter11, step 4868, training accuracy 0.992188
# Iter11, step 4869, training accuracy 1
# Iter11, step 4870, training accuracy 1
# Iter11, step 4871, training accuracy 1
# Iter11, step 4872, training accuracy 1
# Iter11, step 4873, training accuracy 1
# Iter11, step 4874, training accuracy 1
# Iter11, step 4875, training accuracy 0.984375
# Iter11, step 4876, training accuracy 1
# Iter11, step 4877, training accuracy 0.992188
# Iter11, step 4878, training accuracy 1
# Iter11, step 4879, training accuracy 1
# Iter11, step 4880, training accuracy 1
# Iter11, step 4881, training accuracy 1
# Iter11, step 4882, training accuracy 0.992188
# Iter11, step 4883, training accuracy 1
# Iter11, step 4884, training accuracy 1
# Iter11, step 4885, training accuracy 1
# Iter11, step 4886, training accuracy 1
# Iter11, step 4887, training accuracy 1
# Iter11, step 4888, training accuracy 0.992188
# Iter11, step 4889, training accuracy 1
# Iter11, step 4890, training accuracy 1
# Iter11, step 4891, training accuracy 1
# Iter11, step 4892, training accuracy 1
# Iter11, step 4893, training accuracy 1
# Iter11, step 4894, training accuracy 1
# Iter11, step 4895, training accuracy 1
# Iter11, step 4896, training accuracy 1
# Iter11, step 4897, training accuracy 0.992188
# Iter11, step 4898, training accuracy 1
# Iter11, step 4899, training accuracy 1
# Iter11, step 4900, training accuracy 1
# Iter11, step 4901, training accuracy 1
# Iter11, step 4902, training accuracy 0.984375
# Iter11, step 4903, training accuracy 0.992188
# Iter11, step 4904, training accuracy 1
# Iter11, step 4905, training accuracy 0.992188
# Iter11, step 4906, training accuracy 1
# Iter11, step 4907, training accuracy 1
# Iter11, step 4908, training accuracy 1
# Iter11, step 4909, training accuracy 1
# Iter11, step 4910, training accuracy 1
# Iter11, step 4911, training accuracy 0.992188
# Iter11, step 4912, training accuracy 1
# Iter11, step 4913, training accuracy 1
# Iter11, step 4914, training accuracy 0.992188
# Iter11, step 4915, training accuracy 0.992188
# Iter11, step 4916, training accuracy 1
# Iter11, step 4917, training accuracy 0.976562
# Iter11, step 4918, training accuracy 0.992188
# Iter11, step 4919, training accuracy 1
# Iter11, step 4920, training accuracy 1
# Iter11, step 4921, training accuracy 1
# Iter11, step 4922, training accuracy 1
# Iter11, step 4923, training accuracy 0.992188
# Iter11, step 4924, training accuracy 1
# Iter11, step 4925, training accuracy 0.992188
# Iter11, step 4926, training accuracy 1
# Iter11, step 4927, training accuracy 1
# Iter11, step 4928, training accuracy 1
# Iter11, step 4929, training accuracy 1
# Iter11, step 4930, training accuracy 1
# Iter11, step 4931, training accuracy 1
# Iter11, step 4932, training accuracy 1
# Iter11, step 4933, training accuracy 1
# Iter11, step 4934, training accuracy 1
# Iter11, step 4935, training accuracy 0.992188
# Iter11, step 4936, training accuracy 0.992188
# Iter11, step 4937, training accuracy 1
# Iter11, step 4938, training accuracy 1
# Iter11, step 4939, training accuracy 1
# Iter11, step 4940, training accuracy 1
# Iter11, step 4941, training accuracy 1
# Iter11, step 4942, training accuracy 1
# Iter11, step 4943, training accuracy 0.992188
# Iter11, step 4944, training accuracy 0.992188
# Iter11, step 4945, training accuracy 1
# Iter11, step 4946, training accuracy 0.992188
# Iter11, step 4947, training accuracy 1
# Iter11, step 4948, training accuracy 1
# Iter11, step 4949, training accuracy 0.992188
# Iter11, step 4950, training accuracy 0.992188
# Iter11, step 4951, training accuracy 0.992188
# Iter11, step 4952, training accuracy 1
# Iter11, step 4953, training accuracy 1
# Iter11, step 4954, training accuracy 1
# Iter11, step 4955, training accuracy 1
# Iter11, step 4956, training accuracy 1
# Iter11, step 4957, training accuracy 1
# Iter11, step 4958, training accuracy 1
# Iter11, step 4959, training accuracy 1
# Iter11, step 4960, training accuracy 1
# Iter11, step 4961, training accuracy 1
# Iter11, step 4962, training accuracy 1
# Iter11, step 4963, training accuracy 1
# Iter11, step 4964, training accuracy 1
# Iter11, step 4965, training accuracy 1
# Iter11, step 4966, training accuracy 1
# Iter11, step 4967, training accuracy 1
# Iter11, step 4968, training accuracy 1
# Iter11, step 4969, training accuracy 1
# Iter11, step 4970, training accuracy 1
# Iter11, step 4971, training accuracy 1
# Iter11, step 4972, training accuracy 1
# Iter11, step 4973, training accuracy 1
# Iter11, step 4974, training accuracy 1
# Iter11, step 4975, training accuracy 1
# Iter11, step 4976, training accuracy 1
# Iter11, step 4977, training accuracy 1
# Iter11, step 4978, training accuracy 1
# Iter11, step 4979, training accuracy 1
# Iter11, step 4980, training accuracy 0.992188
# Iter11, step 4981, training accuracy 1
# Iter11, step 4982, training accuracy 1
# Iter11, step 4983, training accuracy 0.992188
# Iter11, step 4984, training accuracy 0.992188
# Iter11, step 4985, training accuracy 1
# Iter11, step 4986, training accuracy 0.992188
# Iter11, step 4987, training accuracy 1
# Iter11, step 4988, training accuracy 1
# Iter11, step 4989, training accuracy 0.984375
# Iter11, step 4990, training accuracy 1
# Iter11, step 4991, training accuracy 1
# Iter11, step 4992, training accuracy 1
# Iter11, step 4993, training accuracy 1
# Iter11, step 4994, training accuracy 1
# Iter11, step 4995, training accuracy 1
# Iter11, step 4996, training accuracy 0.992188
# Iter11, step 4997, training accuracy 0.992188
# Iter11, step 4998, training accuracy 1
# Iter11, step 4999, training accuracy 1
# Iter11, step 5000, training accuracy 0.992188
# Iter11, step 5001, training accuracy 1
# 训练5000步总时长为 2173.818154 秒
