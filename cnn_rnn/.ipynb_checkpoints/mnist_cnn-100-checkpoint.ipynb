# %%
from tensorflow.examples.tutorials.mnist import input_data

import tensorflow as tf
from datetime import datetime
mnist = input_data.read_data_sets('/root/code/MNIST_data/', one_hot=True) 
#MNIST数据集所在路径

x = tf.placeholder(tf.float32, [None, 784])

y_ = tf.placeholder(tf.float32, [None, 10])
lr = tf.Variable(0.001,dtype=tf.float32)

def weight_variable(shape):
    initial = tf.truncated_normal(shape,stddev = 0.1)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0.1,shape = shape)
    return tf.Variable(initial)

def conv2d(x,W):
    return tf.nn.conv2d(x, W, strides = [1,1,1,1], padding = 'SAME')

def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME')

W_conv1 = weight_variable([5, 5, 1, 32])
b_conv1 = bias_variable([32])

x_image = tf.reshape(x,[-1,28,28,1])

h_conv1 = tf.nn.relu(conv2d(x_image,W_conv1) + b_conv1)
h_pool1 = max_pool_2x2(h_conv1)

W_conv2 = weight_variable([5, 5, 32, 64])
b_conv2 = bias_variable([64])

h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2) + b_conv2)
h_pool2 = max_pool_2x2(h_conv2)

W_fc1 = weight_variable([7 * 7 * 64, 1024])
b_fc1 = bias_variable([1024])

h_pool2_flat = tf.reshape(h_pool2, [-1, 7*7*64])
h_fc1 = tf.nn.relu(tf.matmul(h_pool2_flat, W_fc1) + b_fc1)

keep_prob = tf.placeholder("float")
h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)

W_fc2 = weight_variable([1024, 10])
b_fc2 = bias_variable([10])

y_conv=tf.nn.softmax(tf.matmul(h_fc1_drop, W_fc2) + b_fc2)

cross_entropy = -tf.reduce_sum(y_*tf.log(y_conv))
train_step = tf.train.AdamOptimizer(1e-4).minimize(cross_entropy)
correct_prediction = tf.equal(tf.argmax(y_conv,1), tf.argmax(y_,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))

saver = tf.train.Saver() #定义saver

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    start = datetime.now()
    for i in range(5001):
        
        batch = mnist.train.next_batch(50)


#         train_step.run(feed_dict={x: batch[0], y_: batch[1], keep_prob: 0.5})
        sess.run(train_step, 
                     feed_dict={x: batch[0], y_: batch[1],keep_prob: 0.5})
        train_accuracy = accuracy.eval(feed_dict={
                    x: batch[0], y_: batch[1], keep_prob: 1.0})
        print('step %d, training accuracy %g' % (i, train_accuracy))
    end = datetime.now()
    latency = (end - start).total_seconds()
    print('训练5000步总时长为 '+str(latency)+' 秒 ')
    saver.save(sess, '/tmp/tf_cnn2/model.ckpt') #模型储存位置

    print('test accuracy %g' % accuracy.eval(feed_dict={
        x: mnist.test.images, y_: mnist.test.labels, keep_prob: 1.0}))
# Out:
# WARNING:tensorflow:From <ipython-input-1-d80a027e5a77>:5: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting /root/code/MNIST_data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting /root/code/MNIST_data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting /root/code/MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting /root/code/MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From <ipython-input-1-d80a027e5a77>:48: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# step 0, training accuracy 0.16
# step 1, training accuracy 0.14
# step 2, training accuracy 0.14
# step 3, training accuracy 0.18
# step 4, training accuracy 0.2
# step 5, training accuracy 0.4
# step 6, training accuracy 0.24
# step 7, training accuracy 0.24
# step 8, training accuracy 0.26
# step 9, training accuracy 0.36
# step 10, training accuracy 0.26
# step 11, training accuracy 0.46
# step 12, training accuracy 0.2
# step 13, training accuracy 0.32
# step 14, training accuracy 0.38
# step 15, training accuracy 0.38
# step 16, training accuracy 0.32
# step 17, training accuracy 0.42
# step 18, training accuracy 0.44
# step 19, training accuracy 0.42
# step 20, training accuracy 0.48
# step 21, training accuracy 0.38
# step 22, training accuracy 0.46
# step 23, training accuracy 0.36
# step 24, training accuracy 0.46
# step 25, training accuracy 0.54
# step 26, training accuracy 0.44
# step 27, training accuracy 0.62
# step 28, training accuracy 0.54
# step 29, training accuracy 0.62
# step 30, training accuracy 0.68
# step 31, training accuracy 0.66
# step 32, training accuracy 0.36
# step 33, training accuracy 0.48
# step 34, training accuracy 0.66
# step 35, training accuracy 0.46
# step 36, training accuracy 0.58
# step 37, training accuracy 0.56
# step 38, training accuracy 0.6
# step 39, training accuracy 0.58
# step 40, training accuracy 0.64
# step 41, training accuracy 0.64
# step 42, training accuracy 0.7
# step 43, training accuracy 0.7
# step 44, training accuracy 0.66
# step 45, training accuracy 0.64
# step 46, training accuracy 0.7
# step 47, training accuracy 0.7
# step 48, training accuracy 0.68
# step 49, training accuracy 0.68
# step 50, training accuracy 0.68
# step 51, training accuracy 0.6
# step 52, training accuracy 0.82
# step 53, training accuracy 0.82
# step 54, training accuracy 0.74
# step 55, training accuracy 0.76
# step 56, training accuracy 0.76
# step 57, training accuracy 0.7
# step 58, training accuracy 0.78
# step 59, training accuracy 0.78
# step 60, training accuracy 0.62
# step 61, training accuracy 0.8
# step 62, training accuracy 0.68
# step 63, training accuracy 0.82
# step 64, training accuracy 0.76
# step 65, training accuracy 0.86
# step 66, training accuracy 0.86
# step 67, training accuracy 0.64
# step 68, training accuracy 0.86
# step 69, training accuracy 0.84
# step 70, training accuracy 0.8
# step 71, training accuracy 0.72
# step 72, training accuracy 0.8
# step 73, training accuracy 0.7
# step 74, training accuracy 0.86
# step 75, training accuracy 0.82
# step 76, training accuracy 0.74
# step 77, training accuracy 0.74
# step 78, training accuracy 0.82
# step 79, training accuracy 0.8
# step 80, training accuracy 0.86
# step 81, training accuracy 0.8
# step 82, training accuracy 0.86
# step 83, training accuracy 0.8
# step 84, training accuracy 0.84
# step 85, training accuracy 0.74
# step 86, training accuracy 0.8
# step 87, training accuracy 0.8
# step 88, training accuracy 0.84
# step 89, training accuracy 0.78
# step 90, training accuracy 0.82
# step 91, training accuracy 0.86
# step 92, training accuracy 0.88
# step 93, training accuracy 0.82
# step 94, training accuracy 0.86
# step 95, training accuracy 0.82
# step 96, training accuracy 0.84
# step 97, training accuracy 0.92
# step 98, training accuracy 0.88
# step 99, training accuracy 0.82
# step 100, training accuracy 0.86
# step 101, training accuracy 0.88
# step 102, training accuracy 0.74
# step 103, training accuracy 0.74
# step 104, training accuracy 0.86
# step 105, training accuracy 0.82
# step 106, training accuracy 0.88
# step 107, training accuracy 0.84
# step 108, training accuracy 0.84
# step 109, training accuracy 0.88
# step 110, training accuracy 0.84
# step 111, training accuracy 0.82
# step 112, training accuracy 0.88
# step 113, training accuracy 0.8
# step 114, training accuracy 0.94
# step 115, training accuracy 0.84
# step 116, training accuracy 0.92
# step 117, training accuracy 0.96
# step 118, training accuracy 0.92
# step 119, training accuracy 0.9
# step 120, training accuracy 0.88
# step 121, training accuracy 0.88
# step 122, training accuracy 0.78
# step 123, training accuracy 0.88
# step 124, training accuracy 0.88
# step 125, training accuracy 0.82
# step 126, training accuracy 0.94
# step 127, training accuracy 0.82
# step 128, training accuracy 0.9
# step 129, training accuracy 0.86
# step 130, training accuracy 0.84
# step 131, training accuracy 0.9
# step 132, training accuracy 0.84
# step 133, training accuracy 0.94
# step 134, training accuracy 0.9
# step 135, training accuracy 0.8
# step 136, training accuracy 0.82
# step 137, training accuracy 0.84
# step 138, training accuracy 0.88
# step 139, training accuracy 0.88
# step 140, training accuracy 0.8
# step 141, training accuracy 0.88
# step 142, training accuracy 0.88
# step 143, training accuracy 0.88
# step 144, training accuracy 0.88
# step 145, training accuracy 0.94
# step 146, training accuracy 0.94
# step 147, training accuracy 0.88
# step 148, training accuracy 0.92
# step 149, training accuracy 0.92
# step 150, training accuracy 0.78
# step 151, training accuracy 0.96
# step 152, training accuracy 0.92
# step 153, training accuracy 0.92
# step 154, training accuracy 0.92
# step 155, training accuracy 0.9
# step 156, training accuracy 0.94
# step 157, training accuracy 0.8
# step 158, training accuracy 0.84
# step 159, training accuracy 0.86
# step 160, training accuracy 0.8
# step 161, training accuracy 0.96
# step 162, training accuracy 0.9
# step 163, training accuracy 0.82
# step 164, training accuracy 0.86
# step 165, training accuracy 0.88
# step 166, training accuracy 0.88
# step 167, training accuracy 0.9
# step 168, training accuracy 0.88
# step 169, training accuracy 0.92
# step 170, training accuracy 0.76
# step 171, training accuracy 0.9
# step 172, training accuracy 0.88
# step 173, training accuracy 0.86
# step 174, training accuracy 0.86
# step 175, training accuracy 0.94
# step 176, training accuracy 0.92
# step 177, training accuracy 0.88
# step 178, training accuracy 0.92
# step 179, training accuracy 0.88
# step 180, training accuracy 0.92
# step 181, training accuracy 0.88
# step 182, training accuracy 0.92
# step 183, training accuracy 0.94
# step 184, training accuracy 0.9
# step 185, training accuracy 0.92
# step 186, training accuracy 0.94
# step 187, training accuracy 0.9
# step 188, training accuracy 0.88
# step 189, training accuracy 0.86
# step 190, training accuracy 0.86
# step 191, training accuracy 0.9
# step 192, training accuracy 0.94
# step 193, training accuracy 0.92
# step 194, training accuracy 0.88
# step 195, training accuracy 0.94
# step 196, training accuracy 0.88
# step 197, training accuracy 0.88
# step 198, training accuracy 0.92
# step 199, training accuracy 0.86
# step 200, training accuracy 0.88
# step 201, training accuracy 0.94
# step 202, training accuracy 0.92
# step 203, training accuracy 0.84
# step 204, training accuracy 0.94
# step 205, training accuracy 0.94
# step 206, training accuracy 0.88
# step 207, training accuracy 0.9
# step 208, training accuracy 0.84
# step 209, training accuracy 0.86
# step 210, training accuracy 0.88
# step 211, training accuracy 0.9
# step 212, training accuracy 0.86
# step 213, training accuracy 0.94
# step 214, training accuracy 0.92
# step 215, training accuracy 0.86
# step 216, training accuracy 0.9
# step 217, training accuracy 0.92
# step 218, training accuracy 0.9
# step 219, training accuracy 0.92
# step 220, training accuracy 0.9
# step 221, training accuracy 0.86
# step 222, training accuracy 0.86
# step 223, training accuracy 0.92
# step 224, training accuracy 0.9
# step 225, training accuracy 0.92
# step 226, training accuracy 0.94
# step 227, training accuracy 0.96
# step 228, training accuracy 0.82
# step 229, training accuracy 0.92
# step 230, training accuracy 0.98
# step 231, training accuracy 0.9
# step 232, training accuracy 0.84
# step 233, training accuracy 0.94
# step 234, training accuracy 0.86
# step 235, training accuracy 0.96
# step 236, training accuracy 0.98
# step 237, training accuracy 0.96
# step 238, training accuracy 0.98
# step 239, training accuracy 0.94
# step 240, training accuracy 0.94
# step 241, training accuracy 0.88
# step 242, training accuracy 0.9
# step 243, training accuracy 0.9
# step 244, training accuracy 0.94
# step 245, training accuracy 0.86
# step 246, training accuracy 0.9
# step 247, training accuracy 0.88
# step 248, training accuracy 0.94
# step 249, training accuracy 0.88
# step 250, training accuracy 0.88
# step 251, training accuracy 0.9
# step 252, training accuracy 0.98
# step 253, training accuracy 0.9
# step 254, training accuracy 0.88
# step 255, training accuracy 0.98
# step 256, training accuracy 0.94
# step 257, training accuracy 0.94
# step 258, training accuracy 0.9
# step 259, training accuracy 0.88
# step 260, training accuracy 0.96
# step 261, training accuracy 0.94
# step 262, training accuracy 0.88
# step 263, training accuracy 0.96
# step 264, training accuracy 0.94
# step 265, training accuracy 0.92
# step 266, training accuracy 0.86
# step 267, training accuracy 0.92
# step 268, training accuracy 0.9
# step 269, training accuracy 0.92
# step 270, training accuracy 0.88
# step 271, training accuracy 0.94
# step 272, training accuracy 0.88
# step 273, training accuracy 0.84
# step 274, training accuracy 0.92
# step 275, training accuracy 0.92
# step 276, training accuracy 0.96
# step 277, training accuracy 0.88
# step 278, training accuracy 0.94
# step 279, training accuracy 0.9
# step 280, training accuracy 0.94
# step 281, training accuracy 0.94
# step 282, training accuracy 0.88
# step 283, training accuracy 0.9
# step 284, training accuracy 0.94
# step 285, training accuracy 0.94
# step 286, training accuracy 0.88
# step 287, training accuracy 0.98
# step 288, training accuracy 0.96
# step 289, training accuracy 0.96
# step 290, training accuracy 0.92
# step 291, training accuracy 0.92
# step 292, training accuracy 0.88
# step 293, training accuracy 0.86
# step 294, training accuracy 0.9
# step 295, training accuracy 0.92
# step 296, training accuracy 0.96
# step 297, training accuracy 1
# step 298, training accuracy 0.94
# step 299, training accuracy 0.98
# step 300, training accuracy 0.94
# step 301, training accuracy 0.84
# step 302, training accuracy 0.92
# step 303, training accuracy 0.9
# step 304, training accuracy 0.92
# step 305, training accuracy 0.9
# step 306, training accuracy 0.92
# step 307, training accuracy 0.94
# step 308, training accuracy 0.88
# step 309, training accuracy 0.92
# step 310, training accuracy 0.9
# step 311, training accuracy 0.96
# step 312, training accuracy 0.9
# step 313, training accuracy 0.98
# step 314, training accuracy 0.92
# step 315, training accuracy 0.94
# step 316, training accuracy 0.94
# step 317, training accuracy 0.92
# step 318, training accuracy 0.92
# step 319, training accuracy 0.84
# step 320, training accuracy 0.88
# step 321, training accuracy 0.92
# step 322, training accuracy 0.9
# step 323, training accuracy 0.92
# step 324, training accuracy 0.94
# step 325, training accuracy 0.98
# step 326, training accuracy 0.88
# step 327, training accuracy 0.9
# step 328, training accuracy 0.94
# step 329, training accuracy 0.98
# step 330, training accuracy 0.86
# step 331, training accuracy 0.94
# step 332, training accuracy 0.94
# step 333, training accuracy 0.9
# step 334, training accuracy 0.88
# step 335, training accuracy 0.94
# step 336, training accuracy 0.96
# step 337, training accuracy 0.86
# step 338, training accuracy 0.9
# step 339, training accuracy 0.94
# step 340, training accuracy 0.94
# step 341, training accuracy 0.94
# step 342, training accuracy 0.92
# step 343, training accuracy 0.88
# step 344, training accuracy 0.94
# step 345, training accuracy 0.9
# step 346, training accuracy 0.96
# step 347, training accuracy 0.88
# step 348, training accuracy 0.9
# step 349, training accuracy 0.98
# step 350, training accuracy 0.9
# step 351, training accuracy 0.94
# step 352, training accuracy 0.94
# step 353, training accuracy 0.92
# step 354, training accuracy 0.94
# step 355, training accuracy 0.94
# step 356, training accuracy 0.96
# step 357, training accuracy 0.96
# step 358, training accuracy 0.88
# step 359, training accuracy 0.9
# step 360, training accuracy 0.94
# step 361, training accuracy 0.94
# step 362, training accuracy 0.94
# step 363, training accuracy 0.84
# step 364, training accuracy 0.86
# step 365, training accuracy 0.94
# step 366, training accuracy 0.9
# step 367, training accuracy 0.98
# step 368, training accuracy 0.94
# step 369, training accuracy 0.94
# step 370, training accuracy 0.9
# step 371, training accuracy 0.92
# step 372, training accuracy 0.96
# step 373, training accuracy 0.9
# step 374, training accuracy 0.92
# step 375, training accuracy 0.96
# step 376, training accuracy 0.92
# step 377, training accuracy 0.88
# step 378, training accuracy 0.96
# step 379, training accuracy 0.94
# step 380, training accuracy 0.9
# step 381, training accuracy 0.88
# step 382, training accuracy 1
# step 383, training accuracy 0.9
# step 384, training accuracy 0.88
# step 385, training accuracy 0.94
# step 386, training accuracy 0.98
# step 387, training accuracy 0.94
# step 388, training accuracy 0.92
# step 389, training accuracy 0.96
# step 390, training accuracy 0.96
# step 391, training accuracy 0.94
# step 392, training accuracy 0.86
# step 393, training accuracy 0.9
# step 394, training accuracy 0.96
# step 395, training accuracy 0.94
# step 396, training accuracy 0.98
# step 397, training accuracy 0.92
# step 398, training accuracy 0.86
# step 399, training accuracy 0.86
# step 400, training accuracy 0.92
# step 401, training accuracy 0.94
# step 402, training accuracy 0.94
# step 403, training accuracy 1
# step 404, training accuracy 0.94
# step 405, training accuracy 0.96
# step 406, training accuracy 0.92
# step 407, training accuracy 0.94
# step 408, training accuracy 0.94
# step 409, training accuracy 0.9
# step 410, training accuracy 0.9
# step 411, training accuracy 0.94
# step 412, training accuracy 0.94
# step 413, training accuracy 0.94
# step 414, training accuracy 0.94
# step 415, training accuracy 0.9
# step 416, training accuracy 0.98
# step 417, training accuracy 0.94
# step 418, training accuracy 0.9
# step 419, training accuracy 0.98
# step 420, training accuracy 0.98
# step 421, training accuracy 0.94
# step 422, training accuracy 0.86
# step 423, training accuracy 0.92
# step 424, training accuracy 0.9
# step 425, training accuracy 0.92
# step 426, training accuracy 0.96
# step 427, training accuracy 0.94
# step 428, training accuracy 0.94
# step 429, training accuracy 0.98
# step 430, training accuracy 0.92
# step 431, training accuracy 0.96
# step 432, training accuracy 0.96
# step 433, training accuracy 0.96
# step 434, training accuracy 0.96
# step 435, training accuracy 0.98
# step 436, training accuracy 0.94
# step 437, training accuracy 0.96
# step 438, training accuracy 0.92
# step 439, training accuracy 0.92
# step 440, training accuracy 0.86
# step 441, training accuracy 0.92
# step 442, training accuracy 0.9
# step 443, training accuracy 0.94
# step 444, training accuracy 0.92
# step 445, training accuracy 0.88
# step 446, training accuracy 0.9
# step 447, training accuracy 0.9
# step 448, training accuracy 0.94
# step 449, training accuracy 0.94
# step 450, training accuracy 1
# step 451, training accuracy 0.9
# step 452, training accuracy 0.98
# step 453, training accuracy 0.98
# step 454, training accuracy 0.94
# step 455, training accuracy 0.96
# step 456, training accuracy 0.94
# step 457, training accuracy 0.96
# step 458, training accuracy 0.96
# step 459, training accuracy 0.94
# step 460, training accuracy 1
# step 461, training accuracy 0.96
# step 462, training accuracy 0.94
# step 463, training accuracy 0.9
# step 464, training accuracy 0.96
# step 465, training accuracy 0.96
# step 466, training accuracy 0.96
# step 467, training accuracy 0.84
# step 468, training accuracy 0.92
# step 469, training accuracy 0.96
# step 470, training accuracy 0.9
# step 471, training accuracy 0.94
# step 472, training accuracy 0.92
# step 473, training accuracy 0.96
# step 474, training accuracy 0.94
# step 475, training accuracy 0.9
# step 476, training accuracy 0.96
# step 477, training accuracy 0.92
# step 478, training accuracy 0.88
# step 479, training accuracy 0.9
# step 480, training accuracy 0.9
# step 481, training accuracy 0.96
# step 482, training accuracy 0.94
# step 483, training accuracy 0.94
# step 484, training accuracy 1
# step 485, training accuracy 0.88
# step 486, training accuracy 0.92
# step 487, training accuracy 0.94
# step 488, training accuracy 0.88
# step 489, training accuracy 0.84
# step 490, training accuracy 0.98
# step 491, training accuracy 0.96
# step 492, training accuracy 0.92
# step 493, training accuracy 0.86
# step 494, training accuracy 0.9
# step 495, training accuracy 0.96
# step 496, training accuracy 0.92
# step 497, training accuracy 0.9
# step 498, training accuracy 0.94
# step 499, training accuracy 0.94
# step 500, training accuracy 0.94
# step 501, training accuracy 0.92
# step 502, training accuracy 0.94
# step 503, training accuracy 0.96
# step 504, training accuracy 0.9
# step 505, training accuracy 0.94
# step 506, training accuracy 0.98
# step 507, training accuracy 0.96
# step 508, training accuracy 0.94
# step 509, training accuracy 0.96
# step 510, training accuracy 0.92
# step 511, training accuracy 0.9
# step 512, training accuracy 0.96
# step 513, training accuracy 0.92
# step 514, training accuracy 0.94
# step 515, training accuracy 0.92
# step 516, training accuracy 0.92
# step 517, training accuracy 0.9
# step 518, training accuracy 0.94
# step 519, training accuracy 0.9
# step 520, training accuracy 0.92
# step 521, training accuracy 0.96
# step 522, training accuracy 0.94
# step 523, training accuracy 1
# step 524, training accuracy 0.94
# step 525, training accuracy 1
# step 526, training accuracy 0.96
# step 527, training accuracy 0.94
# step 528, training accuracy 0.98
# step 529, training accuracy 0.94
# step 530, training accuracy 0.96
# step 531, training accuracy 0.94
# step 532, training accuracy 0.94
# step 533, training accuracy 0.96
# step 534, training accuracy 0.9
# step 535, training accuracy 0.98
# step 536, training accuracy 0.9
# step 537, training accuracy 0.94
# step 538, training accuracy 0.98
# step 539, training accuracy 0.98
# step 540, training accuracy 0.96
# step 541, training accuracy 0.96
# step 542, training accuracy 0.96
# step 543, training accuracy 0.92
# step 544, training accuracy 0.94
# step 545, training accuracy 0.9
# step 546, training accuracy 0.92
# step 547, training accuracy 0.94
# step 548, training accuracy 0.94
# step 549, training accuracy 0.92
# step 550, training accuracy 0.88
# step 551, training accuracy 0.98
# step 552, training accuracy 0.92
# step 553, training accuracy 0.94
# step 554, training accuracy 0.96
# step 555, training accuracy 0.96
# step 556, training accuracy 0.9
# step 557, training accuracy 0.86
# step 558, training accuracy 0.9
# step 559, training accuracy 0.9
# step 560, training accuracy 0.92
# step 561, training accuracy 0.94
# step 562, training accuracy 0.92
# step 563, training accuracy 0.88
# step 564, training accuracy 0.92
# step 565, training accuracy 0.94
# step 566, training accuracy 0.94
# step 567, training accuracy 0.96
# step 568, training accuracy 1
# step 569, training accuracy 0.94
# step 570, training accuracy 0.98
# step 571, training accuracy 0.98
# step 572, training accuracy 0.94
# step 573, training accuracy 0.94
# step 574, training accuracy 0.96
# step 575, training accuracy 0.98
# step 576, training accuracy 0.94
# step 577, training accuracy 0.94
# step 578, training accuracy 0.98
# step 579, training accuracy 0.94
# step 580, training accuracy 0.96
# step 581, training accuracy 0.9
# step 582, training accuracy 0.88
# step 583, training accuracy 0.98
# step 584, training accuracy 0.94
# step 585, training accuracy 0.96
# step 586, training accuracy 0.96
# step 587, training accuracy 0.98
# step 588, training accuracy 0.96
# step 589, training accuracy 0.94
# step 590, training accuracy 0.96
# step 591, training accuracy 0.9
# step 592, training accuracy 0.88
# step 593, training accuracy 0.94
# step 594, training accuracy 0.92
# step 595, training accuracy 0.94
# step 596, training accuracy 0.96
# step 597, training accuracy 0.92
# step 598, training accuracy 1
# step 599, training accuracy 0.88
# step 600, training accuracy 0.96
# step 601, training accuracy 0.88
# step 602, training accuracy 0.96
# step 603, training accuracy 0.92
# step 604, training accuracy 1
# step 605, training accuracy 0.96
# step 606, training accuracy 0.92
# step 607, training accuracy 0.98
# step 608, training accuracy 0.96
# step 609, training accuracy 0.96
# step 610, training accuracy 0.92
# step 611, training accuracy 0.98
# step 612, training accuracy 1
# step 613, training accuracy 0.94
# step 614, training accuracy 0.96
# step 615, training accuracy 0.94
# step 616, training accuracy 0.98
# step 617, training accuracy 0.92
# step 618, training accuracy 0.94
# step 619, training accuracy 0.88
# step 620, training accuracy 0.94
# step 621, training accuracy 0.94
# step 622, training accuracy 0.98
# step 623, training accuracy 0.96
# step 624, training accuracy 0.98
# step 625, training accuracy 0.98
# step 626, training accuracy 0.92
# step 627, training accuracy 0.92
# step 628, training accuracy 0.96
# step 629, training accuracy 1
# step 630, training accuracy 0.92
# step 631, training accuracy 0.98
# step 632, training accuracy 0.98
# step 633, training accuracy 1
# step 634, training accuracy 0.96
# step 635, training accuracy 0.96
# step 636, training accuracy 0.88
# step 637, training accuracy 1
# step 638, training accuracy 0.9
# step 639, training accuracy 0.96
# step 640, training accuracy 0.92
# step 641, training accuracy 0.94
# step 642, training accuracy 0.94
# step 643, training accuracy 0.92
# step 644, training accuracy 0.94
# step 645, training accuracy 0.96
# step 646, training accuracy 0.98
# step 647, training accuracy 0.94
# step 648, training accuracy 0.92
# step 649, training accuracy 0.96
# step 650, training accuracy 0.98
# step 651, training accuracy 0.98
# step 652, training accuracy 0.9
# step 653, training accuracy 0.92
# step 654, training accuracy 0.92
# step 655, training accuracy 0.98
# step 656, training accuracy 0.98
# step 657, training accuracy 0.94
# step 658, training accuracy 0.92
# step 659, training accuracy 0.86
# step 660, training accuracy 0.94
# step 661, training accuracy 0.92
# step 662, training accuracy 0.92
# step 663, training accuracy 0.92
# step 664, training accuracy 0.92
# step 665, training accuracy 0.94
# step 666, training accuracy 0.96
# step 667, training accuracy 0.96
# step 668, training accuracy 0.98
# step 669, training accuracy 0.96
# step 670, training accuracy 0.94
# step 671, training accuracy 1
# step 672, training accuracy 0.94
# step 673, training accuracy 0.98
# step 674, training accuracy 0.98
# step 675, training accuracy 0.96
# step 676, training accuracy 0.98
# step 677, training accuracy 0.94
# step 678, training accuracy 0.92
# step 679, training accuracy 1
# step 680, training accuracy 0.98
# step 681, training accuracy 0.94
# step 682, training accuracy 0.94
# step 683, training accuracy 0.94
# step 684, training accuracy 0.96
# step 685, training accuracy 0.98
# step 686, training accuracy 0.92
# step 687, training accuracy 0.94
# step 688, training accuracy 0.9
# step 689, training accuracy 0.98
# step 690, training accuracy 0.98
# step 691, training accuracy 0.92
# step 692, training accuracy 0.96
# step 693, training accuracy 0.96
# step 694, training accuracy 0.96
# step 695, training accuracy 0.94
# step 696, training accuracy 0.98
# step 697, training accuracy 0.94
# step 698, training accuracy 0.9
# step 699, training accuracy 0.98
# step 700, training accuracy 0.94
# step 701, training accuracy 0.92
# step 702, training accuracy 0.96
# step 703, training accuracy 0.92
# step 704, training accuracy 0.88
# step 705, training accuracy 1
# step 706, training accuracy 0.94
# step 707, training accuracy 0.96
# step 708, training accuracy 0.86
# step 709, training accuracy 0.92
# step 710, training accuracy 0.92
# step 711, training accuracy 0.94
# step 712, training accuracy 0.88
# step 713, training accuracy 0.88
# step 714, training accuracy 0.96
# step 715, training accuracy 0.88
# step 716, training accuracy 0.96
# step 717, training accuracy 0.9
# step 718, training accuracy 1
# step 719, training accuracy 0.9
# step 720, training accuracy 0.96
# step 721, training accuracy 1
# step 722, training accuracy 0.96
# step 723, training accuracy 1
# step 724, training accuracy 0.9
# step 725, training accuracy 0.96
# step 726, training accuracy 0.94
# step 727, training accuracy 0.92
# step 728, training accuracy 0.96
# step 729, training accuracy 0.98
# step 730, training accuracy 0.98
# step 731, training accuracy 0.98
# step 732, training accuracy 0.9
# step 733, training accuracy 0.98
# step 734, training accuracy 0.96
# step 735, training accuracy 1
# step 736, training accuracy 0.98
# step 737, training accuracy 0.96
# step 738, training accuracy 0.92
# step 739, training accuracy 0.98
# step 740, training accuracy 1
# step 741, training accuracy 1
# step 742, training accuracy 0.92
# step 743, training accuracy 0.94
# step 744, training accuracy 0.98
# step 745, training accuracy 0.92
# step 746, training accuracy 0.94
# step 747, training accuracy 0.9
# step 748, training accuracy 0.96
# step 749, training accuracy 0.98
# step 750, training accuracy 0.98
# step 751, training accuracy 0.94
# step 752, training accuracy 0.96
# step 753, training accuracy 1
# step 754, training accuracy 0.96
# step 755, training accuracy 0.94
# step 756, training accuracy 0.92
# step 757, training accuracy 0.98
# step 758, training accuracy 0.98
# step 759, training accuracy 0.92
# step 760, training accuracy 0.96
# step 761, training accuracy 0.94
# step 762, training accuracy 0.96
# step 763, training accuracy 1
# step 764, training accuracy 0.92
# step 765, training accuracy 0.98
# step 766, training accuracy 0.96
# step 767, training accuracy 0.92
# step 768, training accuracy 0.98
# step 769, training accuracy 0.96
# step 770, training accuracy 0.94
# step 771, training accuracy 0.96
# step 772, training accuracy 0.96
# step 773, training accuracy 0.96
# step 774, training accuracy 0.96
# step 775, training accuracy 0.94
# step 776, training accuracy 0.94
# step 777, training accuracy 0.94
# step 778, training accuracy 0.92
# step 779, training accuracy 0.96
# step 780, training accuracy 0.98
# step 781, training accuracy 0.92
# step 782, training accuracy 0.9
# step 783, training accuracy 0.9
# step 784, training accuracy 0.94
# step 785, training accuracy 0.94
# step 786, training accuracy 1
# step 787, training accuracy 0.92
# step 788, training accuracy 1
# step 789, training accuracy 0.94
# step 790, training accuracy 1
# step 791, training accuracy 0.94
# step 792, training accuracy 0.92
# step 793, training accuracy 0.94
# step 794, training accuracy 0.96
# step 795, training accuracy 0.96
# step 796, training accuracy 0.94
# step 797, training accuracy 0.94
# step 798, training accuracy 0.96
# step 799, training accuracy 0.94
# step 800, training accuracy 0.94
# step 801, training accuracy 0.96
# step 802, training accuracy 0.92
# step 803, training accuracy 0.94
# step 804, training accuracy 0.94
# step 805, training accuracy 0.88
# step 806, training accuracy 0.98
# step 807, training accuracy 0.88
# step 808, training accuracy 0.96
# step 809, training accuracy 0.96
# step 810, training accuracy 0.96
# step 811, training accuracy 0.96
# step 812, training accuracy 0.96
# step 813, training accuracy 0.94
# step 814, training accuracy 0.96
# step 815, training accuracy 0.98
# step 816, training accuracy 1
# step 817, training accuracy 0.92
# step 818, training accuracy 0.98
# step 819, training accuracy 0.96
# step 820, training accuracy 0.96
# step 821, training accuracy 1
# step 822, training accuracy 0.94
# step 823, training accuracy 0.94
# step 824, training accuracy 0.94
# step 825, training accuracy 0.98
# step 826, training accuracy 0.96
# step 827, training accuracy 0.94
# step 828, training accuracy 0.96
# step 829, training accuracy 0.98
# step 830, training accuracy 0.98
# step 831, training accuracy 0.98
# step 832, training accuracy 0.98
# step 833, training accuracy 1
# step 834, training accuracy 1
# step 835, training accuracy 0.98
# step 836, training accuracy 0.94
# step 837, training accuracy 0.96
# step 838, training accuracy 0.92
# step 839, training accuracy 0.92
# step 840, training accuracy 0.96
# step 841, training accuracy 0.94
# step 842, training accuracy 0.94
# step 843, training accuracy 1
# step 844, training accuracy 0.98
# step 845, training accuracy 0.98
# step 846, training accuracy 0.96
# step 847, training accuracy 0.96
# step 848, training accuracy 0.94
# step 849, training accuracy 0.94
# step 850, training accuracy 0.98
# step 851, training accuracy 0.98
# step 852, training accuracy 0.96
# step 853, training accuracy 0.96
# step 854, training accuracy 0.9
# step 855, training accuracy 1
# step 856, training accuracy 0.98
# step 857, training accuracy 0.96
# step 858, training accuracy 0.98
# step 859, training accuracy 0.96
# step 860, training accuracy 0.88
# step 861, training accuracy 1
# step 862, training accuracy 0.98
# step 863, training accuracy 0.96
# step 864, training accuracy 0.96
# step 865, training accuracy 0.96
# step 866, training accuracy 0.98
# step 867, training accuracy 0.96
# step 868, training accuracy 0.96
# step 869, training accuracy 0.96
# step 870, training accuracy 0.94
# step 871, training accuracy 0.96
# step 872, training accuracy 0.96
# step 873, training accuracy 0.9
# step 874, training accuracy 0.96
# step 875, training accuracy 0.94
# step 876, training accuracy 0.94
# step 877, training accuracy 0.96
# step 878, training accuracy 0.98
# step 879, training accuracy 0.9
# step 880, training accuracy 0.96
# step 881, training accuracy 0.94
# step 882, training accuracy 0.98
# step 883, training accuracy 0.98
# step 884, training accuracy 0.9
# step 885, training accuracy 0.94
# step 886, training accuracy 0.98
# step 887, training accuracy 0.96
# step 888, training accuracy 0.98
# step 889, training accuracy 0.92
# step 890, training accuracy 0.96
# step 891, training accuracy 0.94
# step 892, training accuracy 0.98
# step 893, training accuracy 0.98
# step 894, training accuracy 0.96
# step 895, training accuracy 0.96
# step 896, training accuracy 0.96
# step 897, training accuracy 0.96
# step 898, training accuracy 0.94
# step 899, training accuracy 0.94
# step 900, training accuracy 0.94
# step 901, training accuracy 0.9
# step 902, training accuracy 0.88
# step 903, training accuracy 1
# step 904, training accuracy 1
# step 905, training accuracy 0.92
# step 906, training accuracy 0.9
# step 907, training accuracy 0.94
# step 908, training accuracy 1
# step 909, training accuracy 0.98
# step 910, training accuracy 0.9
# step 911, training accuracy 0.98
# step 912, training accuracy 0.96
# step 913, training accuracy 0.96
# step 914, training accuracy 0.92
# step 915, training accuracy 0.94
# step 916, training accuracy 0.92
# step 917, training accuracy 0.92
# step 918, training accuracy 0.92
# step 919, training accuracy 0.96
# step 920, training accuracy 0.98
# step 921, training accuracy 0.98
# step 922, training accuracy 0.94
# step 923, training accuracy 0.98
# step 924, training accuracy 0.98
# step 925, training accuracy 0.94
# step 926, training accuracy 0.9
# step 927, training accuracy 0.98
# step 928, training accuracy 0.9
# step 929, training accuracy 0.94
# step 930, training accuracy 0.94
# step 931, training accuracy 0.98
# step 932, training accuracy 0.94
# step 933, training accuracy 0.94
# step 934, training accuracy 0.96
# step 935, training accuracy 0.96
# step 936, training accuracy 0.96
# step 937, training accuracy 1
# step 938, training accuracy 0.98
# step 939, training accuracy 0.98
# step 940, training accuracy 0.96
# step 941, training accuracy 1
# step 942, training accuracy 0.94
# step 943, training accuracy 0.96
# step 944, training accuracy 1
# step 945, training accuracy 0.96
# step 946, training accuracy 0.92
# step 947, training accuracy 1
# step 948, training accuracy 0.96
# step 949, training accuracy 1
# step 950, training accuracy 1
# step 951, training accuracy 0.98
# step 952, training accuracy 0.94
# step 953, training accuracy 0.96
# step 954, training accuracy 0.98
# step 955, training accuracy 0.94
# step 956, training accuracy 1
# step 957, training accuracy 0.94
# step 958, training accuracy 1
# step 959, training accuracy 0.92
# step 960, training accuracy 0.92
# step 961, training accuracy 0.98
# step 962, training accuracy 0.96
# step 963, training accuracy 0.94
# step 964, training accuracy 0.98
# step 965, training accuracy 0.94
# step 966, training accuracy 0.96
# step 967, training accuracy 0.96
# step 968, training accuracy 0.96
# step 969, training accuracy 1
# step 970, training accuracy 0.98
# step 971, training accuracy 0.98
# step 972, training accuracy 0.98
# step 973, training accuracy 0.98
# step 974, training accuracy 1
# step 975, training accuracy 0.94
# step 976, training accuracy 1
# step 977, training accuracy 1
# step 978, training accuracy 1
# step 979, training accuracy 0.94
# step 980, training accuracy 0.98
# step 981, training accuracy 0.96
# step 982, training accuracy 0.96
# step 983, training accuracy 0.98
# step 984, training accuracy 1
# step 985, training accuracy 0.94
# step 986, training accuracy 0.9
# step 987, training accuracy 0.92
# step 988, training accuracy 0.96
# step 989, training accuracy 0.94
# step 990, training accuracy 0.96
# step 991, training accuracy 0.96
# step 992, training accuracy 0.96
# step 993, training accuracy 0.98
# step 994, training accuracy 0.96
# step 995, training accuracy 0.92
# step 996, training accuracy 0.98
# step 997, training accuracy 0.94
# step 998, training accuracy 0.96
# step 999, training accuracy 0.98
# step 1000, training accuracy 0.98
# step 1001, training accuracy 0.86
# step 1002, training accuracy 0.98
# step 1003, training accuracy 0.92
# step 1004, training accuracy 0.96
# step 1005, training accuracy 0.98
# step 1006, training accuracy 0.98
# step 1007, training accuracy 0.96
# step 1008, training accuracy 0.92
# step 1009, training accuracy 0.96
# step 1010, training accuracy 0.94
# step 1011, training accuracy 0.96
# step 1012, training accuracy 0.96
# step 1013, training accuracy 0.94
# step 1014, training accuracy 0.96
# step 1015, training accuracy 0.98
# step 1016, training accuracy 0.92
# step 1017, training accuracy 1
# step 1018, training accuracy 0.96
# step 1019, training accuracy 0.98
# step 1020, training accuracy 0.98
# step 1021, training accuracy 0.98
# step 1022, training accuracy 0.92
# step 1023, training accuracy 0.98
# step 1024, training accuracy 0.88
# step 1025, training accuracy 0.94
# step 1026, training accuracy 0.94
# step 1027, training accuracy 0.98
# step 1028, training accuracy 0.94
# step 1029, training accuracy 0.94
# step 1030, training accuracy 0.96
# step 1031, training accuracy 0.94
# step 1032, training accuracy 0.88
# step 1033, training accuracy 0.98
# step 1034, training accuracy 0.96
# step 1035, training accuracy 0.94
# step 1036, training accuracy 0.96
# step 1037, training accuracy 0.98
# step 1038, training accuracy 1
# step 1039, training accuracy 0.98
# step 1040, training accuracy 0.94
# step 1041, training accuracy 0.98
# step 1042, training accuracy 0.94
# step 1043, training accuracy 0.92
# step 1044, training accuracy 0.96
# step 1045, training accuracy 0.94
# step 1046, training accuracy 1
# step 1047, training accuracy 0.96
# step 1048, training accuracy 0.98
# step 1049, training accuracy 0.96
# step 1050, training accuracy 0.96
# step 1051, training accuracy 0.94
# step 1052, training accuracy 0.96
# step 1053, training accuracy 0.88
# step 1054, training accuracy 0.98
# step 1055, training accuracy 0.98
# step 1056, training accuracy 0.94
# step 1057, training accuracy 0.94
# step 1058, training accuracy 0.94
# step 1059, training accuracy 1
# step 1060, training accuracy 0.94
# step 1061, training accuracy 0.98
# step 1062, training accuracy 0.98
# step 1063, training accuracy 1
# step 1064, training accuracy 0.98
# step 1065, training accuracy 0.9
# step 1066, training accuracy 0.94
# step 1067, training accuracy 0.98
# step 1068, training accuracy 0.96
# step 1069, training accuracy 0.94
# step 1070, training accuracy 0.98
# step 1071, training accuracy 0.98
# step 1072, training accuracy 1
# step 1073, training accuracy 0.94
# step 1074, training accuracy 1
# step 1075, training accuracy 1
# step 1076, training accuracy 0.98
# step 1077, training accuracy 0.92
# step 1078, training accuracy 0.96
# step 1079, training accuracy 0.92
# step 1080, training accuracy 0.96
# step 1081, training accuracy 0.96
# step 1082, training accuracy 0.96
# step 1083, training accuracy 0.98
# step 1084, training accuracy 0.98
# step 1085, training accuracy 0.98
# step 1086, training accuracy 0.94
# step 1087, training accuracy 1
# step 1088, training accuracy 0.98
# step 1089, training accuracy 0.96
# step 1090, training accuracy 0.94
# step 1091, training accuracy 0.98
# step 1092, training accuracy 0.96
# step 1093, training accuracy 0.96
# step 1094, training accuracy 0.94
# step 1095, training accuracy 0.98
# step 1096, training accuracy 0.94
# step 1097, training accuracy 0.96
# step 1098, training accuracy 0.94
# step 1099, training accuracy 1
# step 1100, training accuracy 0.98
# step 1101, training accuracy 0.96
# step 1102, training accuracy 0.96
# step 1103, training accuracy 0.96
# step 1104, training accuracy 0.94
# step 1105, training accuracy 1
# step 1106, training accuracy 0.98
# step 1107, training accuracy 0.98
# step 1108, training accuracy 0.94
# step 1109, training accuracy 0.98
# step 1110, training accuracy 0.96
# step 1111, training accuracy 0.96
# step 1112, training accuracy 0.98
# step 1113, training accuracy 0.96
# step 1114, training accuracy 0.98
# step 1115, training accuracy 1
# step 1116, training accuracy 0.96
# step 1117, training accuracy 0.96
# step 1118, training accuracy 0.98
# step 1119, training accuracy 0.98
# step 1120, training accuracy 0.94
# step 1121, training accuracy 0.98
# step 1122, training accuracy 0.96
# step 1123, training accuracy 0.98
# step 1124, training accuracy 0.98
# step 1125, training accuracy 0.96
# step 1126, training accuracy 0.98
# step 1127, training accuracy 0.98
# step 1128, training accuracy 0.96
# step 1129, training accuracy 1
# step 1130, training accuracy 0.94
# step 1131, training accuracy 0.96
# step 1132, training accuracy 0.92
# step 1133, training accuracy 1
# step 1134, training accuracy 0.96
# step 1135, training accuracy 1
# step 1136, training accuracy 0.96
# step 1137, training accuracy 0.92
# step 1138, training accuracy 0.98
# step 1139, training accuracy 0.98
# step 1140, training accuracy 0.98
# step 1141, training accuracy 0.88
# step 1142, training accuracy 1
# step 1143, training accuracy 0.98
# step 1144, training accuracy 0.96
# step 1145, training accuracy 0.98
# step 1146, training accuracy 0.98
# step 1147, training accuracy 0.96
# step 1148, training accuracy 0.96
# step 1149, training accuracy 0.94
# step 1150, training accuracy 0.98
# step 1151, training accuracy 1
# step 1152, training accuracy 0.96
# step 1153, training accuracy 0.98
# step 1154, training accuracy 1
# step 1155, training accuracy 0.98
# step 1156, training accuracy 0.98
# step 1157, training accuracy 0.94
# step 1158, training accuracy 1
# step 1159, training accuracy 0.96
# step 1160, training accuracy 1
# step 1161, training accuracy 0.98
# step 1162, training accuracy 0.98
# step 1163, training accuracy 0.96
# step 1164, training accuracy 1
# step 1165, training accuracy 0.94
# step 1166, training accuracy 1
# step 1167, training accuracy 0.94
# step 1168, training accuracy 0.96
# step 1169, training accuracy 0.98
# step 1170, training accuracy 0.98
# step 1171, training accuracy 1
# step 1172, training accuracy 0.94
# step 1173, training accuracy 0.96
# step 1174, training accuracy 1
# step 1175, training accuracy 1
# step 1176, training accuracy 0.9
# step 1177, training accuracy 1
# step 1178, training accuracy 1
# step 1179, training accuracy 0.92
# step 1180, training accuracy 0.98
# step 1181, training accuracy 0.96
# step 1182, training accuracy 1
# step 1183, training accuracy 0.98
# step 1184, training accuracy 0.98
# step 1185, training accuracy 0.98
# step 1186, training accuracy 0.98
# step 1187, training accuracy 0.92
# step 1188, training accuracy 0.98
# step 1189, training accuracy 0.98
# step 1190, training accuracy 0.94
# step 1191, training accuracy 0.98
# step 1192, training accuracy 0.94
# step 1193, training accuracy 0.98
# step 1194, training accuracy 0.96
# step 1195, training accuracy 0.94
# step 1196, training accuracy 0.98
# step 1197, training accuracy 0.96
# step 1198, training accuracy 0.92
# step 1199, training accuracy 0.98
# step 1200, training accuracy 0.98
# step 1201, training accuracy 0.96
# step 1202, training accuracy 0.94
# step 1203, training accuracy 1
# step 1204, training accuracy 0.96
# step 1205, training accuracy 1
# step 1206, training accuracy 0.96
# step 1207, training accuracy 0.96
# step 1208, training accuracy 0.98
# step 1209, training accuracy 0.98
# step 1210, training accuracy 0.98
# step 1211, training accuracy 0.94
# step 1212, training accuracy 0.96
# step 1213, training accuracy 0.96
# step 1214, training accuracy 0.98
# step 1215, training accuracy 1
# step 1216, training accuracy 0.98
# step 1217, training accuracy 0.94
# step 1218, training accuracy 0.96
# step 1219, training accuracy 0.94
# step 1220, training accuracy 0.98
# step 1221, training accuracy 1
# step 1222, training accuracy 0.98
# step 1223, training accuracy 0.98
# step 1224, training accuracy 0.98
# step 1225, training accuracy 0.96
# step 1226, training accuracy 0.96
# step 1227, training accuracy 0.96
# step 1228, training accuracy 1
# step 1229, training accuracy 0.92
# step 1230, training accuracy 0.98
# step 1231, training accuracy 0.98
# step 1232, training accuracy 0.88
# step 1233, training accuracy 0.96
# step 1234, training accuracy 0.98
# step 1235, training accuracy 0.96
# step 1236, training accuracy 1
# step 1237, training accuracy 0.98
# step 1238, training accuracy 1
# step 1239, training accuracy 0.98
# step 1240, training accuracy 0.94
# step 1241, training accuracy 0.98
# step 1242, training accuracy 0.96
# step 1243, training accuracy 1
# step 1244, training accuracy 1
# step 1245, training accuracy 0.9
# step 1246, training accuracy 0.98
# step 1247, training accuracy 0.88
# step 1248, training accuracy 0.94
# step 1249, training accuracy 0.94
# step 1250, training accuracy 1
# step 1251, training accuracy 0.94
# step 1252, training accuracy 0.96
# step 1253, training accuracy 0.98
# step 1254, training accuracy 1
# step 1255, training accuracy 0.98
# step 1256, training accuracy 1
# step 1257, training accuracy 0.94
# step 1258, training accuracy 0.96
# step 1259, training accuracy 0.96
# step 1260, training accuracy 1
# step 1261, training accuracy 0.94
# step 1262, training accuracy 0.94
# step 1263, training accuracy 0.94
# step 1264, training accuracy 1
# step 1265, training accuracy 0.98
# step 1266, training accuracy 0.98
# step 1267, training accuracy 0.9
# step 1268, training accuracy 0.98
# step 1269, training accuracy 0.96
# step 1270, training accuracy 0.98
# step 1271, training accuracy 0.94
# step 1272, training accuracy 0.98
# step 1273, training accuracy 0.96
# step 1274, training accuracy 0.92
# step 1275, training accuracy 0.98
# step 1276, training accuracy 0.94
# step 1277, training accuracy 1
# step 1278, training accuracy 0.98
# step 1279, training accuracy 1
# step 1280, training accuracy 0.92
# step 1281, training accuracy 0.94
# step 1282, training accuracy 1
# step 1283, training accuracy 1
# step 1284, training accuracy 0.98
# step 1285, training accuracy 1
# step 1286, training accuracy 0.96
# step 1287, training accuracy 0.98
# step 1288, training accuracy 0.96
# step 1289, training accuracy 0.98
# step 1290, training accuracy 0.94
# step 1291, training accuracy 1
# step 1292, training accuracy 1
# step 1293, training accuracy 0.98
# step 1294, training accuracy 1
# step 1295, training accuracy 0.98
# step 1296, training accuracy 0.98
# step 1297, training accuracy 1
# step 1298, training accuracy 0.98
# step 1299, training accuracy 0.96
# step 1300, training accuracy 0.98
# step 1301, training accuracy 0.96
# step 1302, training accuracy 0.94
# step 1303, training accuracy 0.96
# step 1304, training accuracy 0.96
# step 1305, training accuracy 0.98
# step 1306, training accuracy 0.98
# step 1307, training accuracy 0.96
# step 1308, training accuracy 1
# step 1309, training accuracy 0.98
# step 1310, training accuracy 1
# step 1311, training accuracy 1
# step 1312, training accuracy 0.94
# step 1313, training accuracy 0.96
# step 1314, training accuracy 0.98
# step 1315, training accuracy 0.96
# step 1316, training accuracy 0.98
# step 1317, training accuracy 0.98
# step 1318, training accuracy 0.96
# step 1319, training accuracy 0.92
# step 1320, training accuracy 0.96
# step 1321, training accuracy 0.98
# step 1322, training accuracy 0.98
# step 1323, training accuracy 0.98
# step 1324, training accuracy 0.94
# step 1325, training accuracy 0.96
# step 1326, training accuracy 0.96
# step 1327, training accuracy 0.98
# step 1328, training accuracy 0.96
# step 1329, training accuracy 0.94
# step 1330, training accuracy 0.98
# step 1331, training accuracy 1
# step 1332, training accuracy 0.96
# step 1333, training accuracy 0.98
# step 1334, training accuracy 1
# step 1335, training accuracy 0.98
# step 1336, training accuracy 1
# step 1337, training accuracy 0.98
# step 1338, training accuracy 0.98
# step 1339, training accuracy 0.98
# step 1340, training accuracy 0.96
# step 1341, training accuracy 1
# step 1342, training accuracy 0.96
# step 1343, training accuracy 0.94
# step 1344, training accuracy 1
# step 1345, training accuracy 0.98
# step 1346, training accuracy 0.98
# step 1347, training accuracy 0.94
# step 1348, training accuracy 1
# step 1349, training accuracy 0.98
# step 1350, training accuracy 1
# step 1351, training accuracy 1
# step 1352, training accuracy 1
# step 1353, training accuracy 0.96
# step 1354, training accuracy 0.98
# step 1355, training accuracy 0.96
# step 1356, training accuracy 0.98
# step 1357, training accuracy 1
# step 1358, training accuracy 0.96
# step 1359, training accuracy 1
# step 1360, training accuracy 0.96
# step 1361, training accuracy 0.98
# step 1362, training accuracy 0.96
# step 1363, training accuracy 0.98
# step 1364, training accuracy 1
# step 1365, training accuracy 0.98
# step 1366, training accuracy 0.96
# step 1367, training accuracy 1
# step 1368, training accuracy 0.9
# step 1369, training accuracy 1
# step 1370, training accuracy 1
# step 1371, training accuracy 0.96
# step 1372, training accuracy 0.94
# step 1373, training accuracy 0.96
# step 1374, training accuracy 0.98
# step 1375, training accuracy 0.94
# step 1376, training accuracy 1
# step 1377, training accuracy 0.96
# step 1378, training accuracy 0.96
# step 1379, training accuracy 1
# step 1380, training accuracy 0.96
# step 1381, training accuracy 0.98
# step 1382, training accuracy 0.98
# step 1383, training accuracy 0.96
# ...
# step 4506, training accuracy 1
# step 4507, training accuracy 0.98
# step 4508, training accuracy 0.98
# step 4509, training accuracy 0.98
# step 4510, training accuracy 0.98
# step 4511, training accuracy 1
# step 4512, training accuracy 0.98
# step 4513, training accuracy 0.98
# step 4514, training accuracy 0.98
# step 4515, training accuracy 1
# step 4516, training accuracy 0.98
# step 4517, training accuracy 1
# step 4518, training accuracy 1
# step 4519, training accuracy 1
# step 4520, training accuracy 1
# step 4521, training accuracy 1
# step 4522, training accuracy 0.98
# step 4523, training accuracy 1
# step 4524, training accuracy 0.98
# step 4525, training accuracy 1
# step 4526, training accuracy 1
# step 4527, training accuracy 1
# step 4528, training accuracy 0.98
# step 4529, training accuracy 0.96
# step 4530, training accuracy 1
# step 4531, training accuracy 1
# step 4532, training accuracy 1
# step 4533, training accuracy 0.96
# step 4534, training accuracy 1
# step 4535, training accuracy 1
# step 4536, training accuracy 1
# step 4537, training accuracy 1
# step 4538, training accuracy 1
# step 4539, training accuracy 0.98
# step 4540, training accuracy 0.98
# step 4541, training accuracy 1
# step 4542, training accuracy 1
# step 4543, training accuracy 0.98
# step 4544, training accuracy 0.96
# step 4545, training accuracy 0.98
# step 4546, training accuracy 1
# step 4547, training accuracy 1
# step 4548, training accuracy 1
# step 4549, training accuracy 1
# step 4550, training accuracy 1
# step 4551, training accuracy 1
# step 4552, training accuracy 0.96
# step 4553, training accuracy 1
# step 4554, training accuracy 1
# step 4555, training accuracy 1
# step 4556, training accuracy 1
# step 4557, training accuracy 1
# step 4558, training accuracy 1
# step 4559, training accuracy 1
# step 4560, training accuracy 1
# step 4561, training accuracy 1
# step 4562, training accuracy 0.98
# step 4563, training accuracy 1
# step 4564, training accuracy 1
# step 4565, training accuracy 0.98
# step 4566, training accuracy 1
# step 4567, training accuracy 1
# step 4568, training accuracy 1
# step 4569, training accuracy 1
# step 4570, training accuracy 1
# step 4571, training accuracy 0.98
# step 4572, training accuracy 1
# step 4573, training accuracy 1
# step 4574, training accuracy 1
# step 4575, training accuracy 1
# step 4576, training accuracy 0.96
# step 4577, training accuracy 0.96
# step 4578, training accuracy 0.96
# step 4579, training accuracy 1
# step 4580, training accuracy 1
# step 4581, training accuracy 0.96
# step 4582, training accuracy 0.98
# step 4583, training accuracy 0.98
# step 4584, training accuracy 0.98
# step 4585, training accuracy 0.98
# step 4586, training accuracy 1
# step 4587, training accuracy 1
# step 4588, training accuracy 1
# step 4589, training accuracy 1
# step 4590, training accuracy 1
# step 4591, training accuracy 1
# step 4592, training accuracy 1
# step 4593, training accuracy 0.92
# step 4594, training accuracy 0.98
# step 4595, training accuracy 1
# step 4596, training accuracy 0.98
# step 4597, training accuracy 1
# step 4598, training accuracy 1
# step 4599, training accuracy 1
# step 4600, training accuracy 0.94
# step 4601, training accuracy 0.98
# step 4602, training accuracy 1
# step 4603, training accuracy 1
# step 4604, training accuracy 0.96
# step 4605, training accuracy 0.98
# step 4606, training accuracy 0.96
# step 4607, training accuracy 1
# step 4608, training accuracy 1
# step 4609, training accuracy 1
# step 4610, training accuracy 1
# step 4611, training accuracy 1
# step 4612, training accuracy 0.98
# step 4613, training accuracy 0.96
# step 4614, training accuracy 1
# step 4615, training accuracy 1
# step 4616, training accuracy 0.96
# step 4617, training accuracy 0.96
# step 4618, training accuracy 1
# step 4619, training accuracy 1
# step 4620, training accuracy 0.98
# step 4621, training accuracy 0.98
# step 4622, training accuracy 1
# step 4623, training accuracy 1
# step 4624, training accuracy 0.98
# step 4625, training accuracy 0.96
# step 4626, training accuracy 0.98
# step 4627, training accuracy 1
# step 4628, training accuracy 0.98
# step 4629, training accuracy 0.98
# step 4630, training accuracy 1
# step 4631, training accuracy 1
# step 4632, training accuracy 0.98
# step 4633, training accuracy 0.98
# step 4634, training accuracy 0.98
# step 4635, training accuracy 1
# step 4636, training accuracy 1
# step 4637, training accuracy 1
# step 4638, training accuracy 0.96
# step 4639, training accuracy 1
# step 4640, training accuracy 0.98
# step 4641, training accuracy 0.98
# step 4642, training accuracy 0.98
# step 4643, training accuracy 0.98
# step 4644, training accuracy 1
# step 4645, training accuracy 0.98
# step 4646, training accuracy 0.98
# step 4647, training accuracy 1
# step 4648, training accuracy 1
# step 4649, training accuracy 1
# step 4650, training accuracy 1
# step 4651, training accuracy 0.94
# step 4652, training accuracy 1
# step 4653, training accuracy 1
# step 4654, training accuracy 1
# step 4655, training accuracy 0.98
# step 4656, training accuracy 0.98
# step 4657, training accuracy 1
# step 4658, training accuracy 1
# step 4659, training accuracy 1
# step 4660, training accuracy 1
# step 4661, training accuracy 0.96
# step 4662, training accuracy 1
# step 4663, training accuracy 1
# step 4664, training accuracy 1
# step 4665, training accuracy 1
# step 4666, training accuracy 0.98
# step 4667, training accuracy 1
# step 4668, training accuracy 1
# step 4669, training accuracy 0.98
# step 4670, training accuracy 0.98
# step 4671, training accuracy 1
# step 4672, training accuracy 0.98
# step 4673, training accuracy 1
# step 4674, training accuracy 1
# step 4675, training accuracy 0.98
# step 4676, training accuracy 1
# step 4677, training accuracy 1
# step 4678, training accuracy 0.98
# step 4679, training accuracy 1
# step 4680, training accuracy 0.98
# step 4681, training accuracy 1
# step 4682, training accuracy 1
# step 4683, training accuracy 1
# step 4684, training accuracy 1
# step 4685, training accuracy 0.98
# step 4686, training accuracy 0.98
# step 4687, training accuracy 1
# step 4688, training accuracy 1
# step 4689, training accuracy 0.98
# step 4690, training accuracy 0.98
# step 4691, training accuracy 0.96
# step 4692, training accuracy 1
# step 4693, training accuracy 1
# step 4694, training accuracy 1
# step 4695, training accuracy 0.98
# step 4696, training accuracy 1
# step 4697, training accuracy 0.96
# step 4698, training accuracy 1
# step 4699, training accuracy 1
# step 4700, training accuracy 1
# step 4701, training accuracy 1
# step 4702, training accuracy 1
# step 4703, training accuracy 1
# step 4704, training accuracy 0.96
# step 4705, training accuracy 1
# step 4706, training accuracy 1
# step 4707, training accuracy 0.96
# step 4708, training accuracy 0.96
# step 4709, training accuracy 0.94
# step 4710, training accuracy 0.94
# step 4711, training accuracy 1
# step 4712, training accuracy 0.94
# step 4713, training accuracy 0.98
# step 4714, training accuracy 0.98
# step 4715, training accuracy 1
# step 4716, training accuracy 0.96
# step 4717, training accuracy 0.96
# step 4718, training accuracy 0.94
# step 4719, training accuracy 1
# step 4720, training accuracy 1
# step 4721, training accuracy 1
# step 4722, training accuracy 0.98
# step 4723, training accuracy 0.98
# step 4724, training accuracy 1
# step 4725, training accuracy 1
# step 4726, training accuracy 1
# step 4727, training accuracy 1
# step 4728, training accuracy 0.98
# step 4729, training accuracy 0.98
# step 4730, training accuracy 0.98
# step 4731, training accuracy 1
# step 4732, training accuracy 1
# step 4733, training accuracy 0.98
# step 4734, training accuracy 1
# step 4735, training accuracy 0.96
# step 4736, training accuracy 1
# step 4737, training accuracy 1
# step 4738, training accuracy 0.98
# step 4739, training accuracy 1
# step 4740, training accuracy 1
# step 4741, training accuracy 1
# step 4742, training accuracy 0.98
# step 4743, training accuracy 1
# step 4744, training accuracy 1
# step 4745, training accuracy 1
# step 4746, training accuracy 1
# step 4747, training accuracy 0.98
# step 4748, training accuracy 0.98
# step 4749, training accuracy 0.98
# step 4750, training accuracy 1
# step 4751, training accuracy 1
# step 4752, training accuracy 1
# step 4753, training accuracy 1
# step 4754, training accuracy 1
# step 4755, training accuracy 0.96
# step 4756, training accuracy 1
# step 4757, training accuracy 1
# step 4758, training accuracy 1
# step 4759, training accuracy 0.98
# step 4760, training accuracy 1
# step 4761, training accuracy 0.98
# step 4762, training accuracy 1
# step 4763, training accuracy 0.98
# step 4764, training accuracy 0.98
# step 4765, training accuracy 1
# step 4766, training accuracy 1
# step 4767, training accuracy 1
# step 4768, training accuracy 1
# step 4769, training accuracy 1
# step 4770, training accuracy 1
# step 4771, training accuracy 0.98
# step 4772, training accuracy 1
# step 4773, training accuracy 1
# step 4774, training accuracy 1
# step 4775, training accuracy 1
# step 4776, training accuracy 0.98
# step 4777, training accuracy 1
# step 4778, training accuracy 0.98
# step 4779, training accuracy 1
# step 4780, training accuracy 0.98
# step 4781, training accuracy 1
# step 4782, training accuracy 1
# step 4783, training accuracy 1
# step 4784, training accuracy 0.98
# step 4785, training accuracy 0.98
# step 4786, training accuracy 1
# step 4787, training accuracy 1
# step 4788, training accuracy 1
# step 4789, training accuracy 1
# step 4790, training accuracy 0.98
# step 4791, training accuracy 1
# step 4792, training accuracy 0.98
# step 4793, training accuracy 0.98
# step 4794, training accuracy 1
# step 4795, training accuracy 1
# step 4796, training accuracy 1
# step 4797, training accuracy 1
# step 4798, training accuracy 1
# step 4799, training accuracy 0.98
# step 4800, training accuracy 0.98
# step 4801, training accuracy 1
# step 4802, training accuracy 0.98
# step 4803, training accuracy 1
# step 4804, training accuracy 1
# step 4805, training accuracy 1
# step 4806, training accuracy 1
# step 4807, training accuracy 1
# step 4808, training accuracy 0.98
# step 4809, training accuracy 0.98
# step 4810, training accuracy 1
# step 4811, training accuracy 1
# step 4812, training accuracy 0.98
# step 4813, training accuracy 1
# step 4814, training accuracy 1
# step 4815, training accuracy 0.98
# step 4816, training accuracy 1
# step 4817, training accuracy 1
# step 4818, training accuracy 1
# step 4819, training accuracy 1
# step 4820, training accuracy 1
# step 4821, training accuracy 1
# step 4822, training accuracy 0.96
# step 4823, training accuracy 0.98
# step 4824, training accuracy 1
# step 4825, training accuracy 0.98
# step 4826, training accuracy 1
# step 4827, training accuracy 1
# step 4828, training accuracy 1
# step 4829, training accuracy 0.98
# step 4830, training accuracy 0.98
# step 4831, training accuracy 1
# step 4832, training accuracy 0.98
# step 4833, training accuracy 1
# step 4834, training accuracy 0.98
# step 4835, training accuracy 1
# step 4836, training accuracy 0.98
# step 4837, training accuracy 1
# step 4838, training accuracy 0.98
# step 4839, training accuracy 0.96
# step 4840, training accuracy 1
# step 4841, training accuracy 0.98
# step 4842, training accuracy 0.98
# step 4843, training accuracy 1
# step 4844, training accuracy 1
# step 4845, training accuracy 1
# step 4846, training accuracy 0.96
# step 4847, training accuracy 1
# step 4848, training accuracy 1
# step 4849, training accuracy 1
# step 4850, training accuracy 1
# step 4851, training accuracy 0.98
# step 4852, training accuracy 1
# step 4853, training accuracy 1
# step 4854, training accuracy 1
# step 4855, training accuracy 0.98
# step 4856, training accuracy 1
# step 4857, training accuracy 0.98
# step 4858, training accuracy 1
# step 4859, training accuracy 0.98
# step 4860, training accuracy 0.98
# step 4861, training accuracy 0.98
# step 4862, training accuracy 0.98
# step 4863, training accuracy 1
# step 4864, training accuracy 1
# step 4865, training accuracy 0.98
# step 4866, training accuracy 0.94
# step 4867, training accuracy 1
# step 4868, training accuracy 1
# step 4869, training accuracy 1
# step 4870, training accuracy 0.98
# step 4871, training accuracy 1
# step 4872, training accuracy 0.98
# step 4873, training accuracy 1
# step 4874, training accuracy 1
# step 4875, training accuracy 0.96
# step 4876, training accuracy 1
# step 4877, training accuracy 0.98
# step 4878, training accuracy 1
# step 4879, training accuracy 1
# step 4880, training accuracy 0.98
# step 4881, training accuracy 1
# step 4882, training accuracy 0.98
# step 4883, training accuracy 1
# step 4884, training accuracy 0.96
# step 4885, training accuracy 1
# step 4886, training accuracy 0.98
# step 4887, training accuracy 0.98
# step 4888, training accuracy 0.98
# step 4889, training accuracy 1
# step 4890, training accuracy 0.98
# step 4891, training accuracy 0.96
# step 4892, training accuracy 0.96
# step 4893, training accuracy 1
# step 4894, training accuracy 1
# step 4895, training accuracy 1
# step 4896, training accuracy 1
# step 4897, training accuracy 1
# step 4898, training accuracy 1
# step 4899, training accuracy 1
# step 4900, training accuracy 0.98
# step 4901, training accuracy 1
# step 4902, training accuracy 1
# step 4903, training accuracy 0.98
# step 4904, training accuracy 1
# step 4905, training accuracy 0.98
# step 4906, training accuracy 0.94
# step 4907, training accuracy 0.98
# step 4908, training accuracy 1
# step 4909, training accuracy 1
# step 4910, training accuracy 0.98
# step 4911, training accuracy 1
# step 4912, training accuracy 1
# step 4913, training accuracy 0.98
# step 4914, training accuracy 0.98
# step 4915, training accuracy 1
# step 4916, training accuracy 0.94
# step 4917, training accuracy 1
# step 4918, training accuracy 0.98
# step 4919, training accuracy 1
# step 4920, training accuracy 1
# step 4921, training accuracy 1
# step 4922, training accuracy 0.98
# step 4923, training accuracy 1
# step 4924, training accuracy 1
# step 4925, training accuracy 1
# step 4926, training accuracy 0.98
# step 4927, training accuracy 1
# step 4928, training accuracy 0.98
# step 4929, training accuracy 0.98
# step 4930, training accuracy 1
# step 4931, training accuracy 1
# step 4932, training accuracy 1
# step 4933, training accuracy 0.98
# step 4934, training accuracy 0.98
# step 4935, training accuracy 0.98
# step 4936, training accuracy 0.94
# step 4937, training accuracy 1
# step 4938, training accuracy 0.98
# step 4939, training accuracy 1
# step 4940, training accuracy 1
# step 4941, training accuracy 0.96
# step 4942, training accuracy 0.98
# step 4943, training accuracy 1
# step 4944, training accuracy 1
# step 4945, training accuracy 1
# step 4946, training accuracy 0.98
# step 4947, training accuracy 1
# step 4948, training accuracy 1
# step 4949, training accuracy 1
# step 4950, training accuracy 0.98
# step 4951, training accuracy 1
# step 4952, training accuracy 1
# step 4953, training accuracy 1
# step 4954, training accuracy 1
# step 4955, training accuracy 1
# step 4956, training accuracy 1
# step 4957, training accuracy 0.98
# step 4958, training accuracy 1
# step 4959, training accuracy 0.96
# step 4960, training accuracy 1
# step 4961, training accuracy 0.92
# step 4962, training accuracy 0.94
# step 4963, training accuracy 0.98
# step 4964, training accuracy 1
# step 4965, training accuracy 1
# step 4966, training accuracy 1
# step 4967, training accuracy 1
# step 4968, training accuracy 1
# step 4969, training accuracy 0.96
# step 4970, training accuracy 0.98
# step 4971, training accuracy 1
# step 4972, training accuracy 1
# step 4973, training accuracy 0.98
# step 4974, training accuracy 0.96
# step 4975, training accuracy 1
# step 4976, training accuracy 1
# step 4977, training accuracy 0.98
# step 4978, training accuracy 1
# step 4979, training accuracy 1
# step 4980, training accuracy 1
# step 4981, training accuracy 0.96
# step 4982, training accuracy 1
# step 4983, training accuracy 1
# step 4984, training accuracy 0.98
# step 4985, training accuracy 0.96
# step 4986, training accuracy 1
# step 4987, training accuracy 0.98
# step 4988, training accuracy 1
# step 4989, training accuracy 1
# step 4990, training accuracy 1
# step 4991, training accuracy 0.98
# step 4992, training accuracy 0.98
# step 4993, training accuracy 1
# step 4994, training accuracy 1
# step 4995, training accuracy 0.98
# step 4996, training accuracy 1
# step 4997, training accuracy 0.98
# step 4998, training accuracy 1
# step 4999, training accuracy 0.98
# step 5000, training accuracy 1
# 训练5000步总时长为 506.824365 秒
# test accuracy 0.9858

# %% [markdown]
# proch 1.0 不丢
# ITER30,Testing accuracy0.9723
# ITER30,training accuracy0.9958182
