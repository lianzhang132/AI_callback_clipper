# %%
from tensorflow.examples.tutorials.mnist import input_data

import tensorflow as tf
from datetime import datetime
mnist = input_data.read_data_sets('/root/code/MNIST_data/', one_hot=True) 
#MNIST数据集所在路径

x = tf.placeholder(tf.float32, [None, 784])

y_ = tf.placeholder(tf.float32, [None, 10])
lr = tf.Variable(0.001,dtype=tf.float32)

def weight_variable(shape):
    initial = tf.truncated_normal(shape,stddev = 0.1)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0.1,shape = shape)
    return tf.Variable(initial)

def conv2d(x,W):
    return tf.nn.conv2d(x, W, strides = [1,1,1,1], padding = 'SAME')

def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME')

W_conv1 = weight_variable([5, 5, 1, 32])
b_conv1 = bias_variable([32])

x_image = tf.reshape(x,[-1,28,28,1])

h_conv1 = tf.nn.relu(conv2d(x_image,W_conv1) + b_conv1)
h_pool1 = max_pool_2x2(h_conv1)

W_conv2 = weight_variable([5, 5, 32, 64])
b_conv2 = bias_variable([64])

h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2) + b_conv2)
h_pool2 = max_pool_2x2(h_conv2)

W_fc1 = weight_variable([7 * 7 * 64, 1024])
b_fc1 = bias_variable([1024])

h_pool2_flat = tf.reshape(h_pool2, [-1, 7*7*64])
h_fc1 = tf.nn.relu(tf.matmul(h_pool2_flat, W_fc1) + b_fc1)

keep_prob = tf.placeholder("float")
h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)

W_fc2 = weight_variable([1024, 10])
b_fc2 = bias_variable([10])

y_conv=tf.nn.softmax(tf.matmul(h_fc1_drop, W_fc2) + b_fc2)

cross_entropy = -tf.reduce_sum(y_*tf.log(y_conv))
train_step = tf.train.AdamOptimizer(1e-4).minimize(cross_entropy)
correct_prediction = tf.equal(tf.argmax(y_conv,1), tf.argmax(y_,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))

saver = tf.train.Saver() #定义saver

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    start = datetime.now()
    for i in range(5001):
        
        batch = mnist.train.next_batch(50)


#         train_step.run(feed_dict={x: batch[0], y_: batch[1], keep_prob: 0.5})
        sess.run(train_step, 
                     feed_dict={x: batch[0], y_: batch[1],keep_prob: 0.5})
        train_accuracy = accuracy.eval(feed_dict={
                    x: batch[0], y_: batch[1], keep_prob: 1.0})
        print('step %d, training accuracy %g' % (i, train_accuracy))
    end = datetime.now()
    latency = (end - start).total_seconds()
    print('训练5000步总时长为 '+str(latency)+' 秒 ')
    saver.save(sess, '/tmp/tf_cnn2_100/model.ckpt') #模型储存位置

    print('test accuracy %g' % accuracy.eval(feed_dict={
        x: mnist.test.images, y_: mnist.test.labels, keep_prob: 1.0}))
# Out:
# /usr/local/lib/python3.6/site-packages/pandas/compat/__init__.py:117: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# WARNING:tensorflow:From <ipython-input-1-0a1f807c2b87>:5: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting /root/code/MNIST_data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting /root/code/MNIST_data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting /root/code/MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting /root/code/MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From <ipython-input-1-0a1f807c2b87>:48: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# step 0, training accuracy 0.08
# step 1, training accuracy 0.24
# step 2, training accuracy 0.22
# step 3, training accuracy 0.26
# step 4, training accuracy 0.3
# step 5, training accuracy 0.14
# step 6, training accuracy 0.24
# step 7, training accuracy 0.24
# step 8, training accuracy 0.32
# step 9, training accuracy 0.38
# step 10, training accuracy 0.3
# step 11, training accuracy 0.3
# step 12, training accuracy 0.34
# step 13, training accuracy 0.46
# step 14, training accuracy 0.4
# step 15, training accuracy 0.38
# step 16, training accuracy 0.4
# step 17, training accuracy 0.52
# step 18, training accuracy 0.52
# step 19, training accuracy 0.42
# step 20, training accuracy 0.52
# step 21, training accuracy 0.34
# step 22, training accuracy 0.4
# step 23, training accuracy 0.32
# step 24, training accuracy 0.36
# step 25, training accuracy 0.46
# step 26, training accuracy 0.54
# step 27, training accuracy 0.4
# step 28, training accuracy 0.46
# step 29, training accuracy 0.6
# step 30, training accuracy 0.78
# step 31, training accuracy 0.52
# step 32, training accuracy 0.52
# step 33, training accuracy 0.64
# step 34, training accuracy 0.58
# step 35, training accuracy 0.6
# step 36, training accuracy 0.6
# step 37, training accuracy 0.64
# step 38, training accuracy 0.64
# step 39, training accuracy 0.78
# step 40, training accuracy 0.72
# step 41, training accuracy 0.72
# step 42, training accuracy 0.8
# step 43, training accuracy 0.8
# step 44, training accuracy 0.72
# step 45, training accuracy 0.7
# step 46, training accuracy 0.56
# step 47, training accuracy 0.74
# step 48, training accuracy 0.74
# step 49, training accuracy 0.82
# step 50, training accuracy 0.72
# step 51, training accuracy 0.76
# step 52, training accuracy 0.66
# step 53, training accuracy 0.68
# step 54, training accuracy 0.68
# step 55, training accuracy 0.78
# step 56, training accuracy 0.72
# step 57, training accuracy 0.68
# step 58, training accuracy 0.72
# step 59, training accuracy 0.78
# step 60, training accuracy 0.74
# step 61, training accuracy 0.86
# step 62, training accuracy 0.74
# step 63, training accuracy 0.86
# step 64, training accuracy 0.66
# step 65, training accuracy 0.8
# step 66, training accuracy 0.72
# step 67, training accuracy 0.84
# step 68, training accuracy 0.8
# step 69, training accuracy 0.82
# step 70, training accuracy 0.8
# step 71, training accuracy 0.84
# step 72, training accuracy 0.76
# step 73, training accuracy 0.74
# step 74, training accuracy 0.8
# step 75, training accuracy 0.82
# step 76, training accuracy 0.76
# step 77, training accuracy 0.78
# step 78, training accuracy 0.8
# step 79, training accuracy 0.88
# step 80, training accuracy 0.72
# step 81, training accuracy 0.8
# step 82, training accuracy 0.92
# step 83, training accuracy 0.92
# step 84, training accuracy 0.82
# step 85, training accuracy 0.88
# step 86, training accuracy 0.86
# step 87, training accuracy 0.84
# step 88, training accuracy 0.86
# step 89, training accuracy 0.8
# step 90, training accuracy 0.82
# step 91, training accuracy 0.76
# step 92, training accuracy 0.82
# step 93, training accuracy 0.92
# step 94, training accuracy 0.76
# step 95, training accuracy 0.92
# step 96, training accuracy 0.82
# step 97, training accuracy 0.86
# step 98, training accuracy 0.78
# step 99, training accuracy 0.84
# step 100, training accuracy 0.88
# step 101, training accuracy 0.86
# step 102, training accuracy 0.8
# step 103, training accuracy 0.82
# step 104, training accuracy 0.78
# step 105, training accuracy 0.82
# step 106, training accuracy 0.82
# step 107, training accuracy 0.86
# step 108, training accuracy 0.88
# step 109, training accuracy 0.88
# step 110, training accuracy 0.86
# step 111, training accuracy 0.88
# step 112, training accuracy 0.9
# step 113, training accuracy 0.9
# step 114, training accuracy 0.86
# step 115, training accuracy 0.86
# step 116, training accuracy 0.9
# step 117, training accuracy 0.88
# step 118, training accuracy 0.78
# step 119, training accuracy 0.92
# step 120, training accuracy 0.84
# step 121, training accuracy 0.84
# step 122, training accuracy 0.88
# step 123, training accuracy 0.88
# step 124, training accuracy 0.9
# step 125, training accuracy 0.86
# step 126, training accuracy 0.86
# step 127, training accuracy 0.84
# step 128, training accuracy 0.84
# step 129, training accuracy 0.84
# step 130, training accuracy 0.82
# step 131, training accuracy 0.72
# step 132, training accuracy 0.82
# step 133, training accuracy 0.92
# step 134, training accuracy 0.86
# step 135, training accuracy 0.9
# step 136, training accuracy 0.92
# step 137, training accuracy 0.94
# step 138, training accuracy 0.84
# step 139, training accuracy 0.9
# step 140, training accuracy 0.86
# step 141, training accuracy 0.92
# step 142, training accuracy 0.82
# step 143, training accuracy 0.78
# step 144, training accuracy 0.9
# step 145, training accuracy 0.96
# step 146, training accuracy 0.8
# step 147, training accuracy 0.86
# step 148, training accuracy 0.9
# step 149, training accuracy 0.92
# step 150, training accuracy 0.92
# step 151, training accuracy 0.82
# step 152, training accuracy 0.9
# step 153, training accuracy 0.84
# step 154, training accuracy 0.88
# step 155, training accuracy 0.92
# step 156, training accuracy 0.96
# step 157, training accuracy 0.96
# step 158, training accuracy 0.86
# step 159, training accuracy 0.94
# step 160, training accuracy 0.86
# step 161, training accuracy 0.92
# step 162, training accuracy 0.88
# step 163, training accuracy 0.82
# step 164, training accuracy 0.94
# step 165, training accuracy 0.92
# step 166, training accuracy 0.88
# step 167, training accuracy 0.92
# step 168, training accuracy 0.9
# step 169, training accuracy 0.96
# step 170, training accuracy 0.82
# step 171, training accuracy 0.88
# step 172, training accuracy 0.86
# step 173, training accuracy 0.82
# step 174, training accuracy 0.94
# step 175, training accuracy 0.92
# step 176, training accuracy 0.9
# step 177, training accuracy 0.92
# step 178, training accuracy 0.88
# step 179, training accuracy 0.94
# step 180, training accuracy 0.9
# step 181, training accuracy 0.98
# step 182, training accuracy 0.92
# step 183, training accuracy 0.88
# step 184, training accuracy 0.9
# step 185, training accuracy 0.94
# step 186, training accuracy 0.84
# step 187, training accuracy 0.9
# step 188, training accuracy 0.8
# step 189, training accuracy 0.84
# step 190, training accuracy 0.86
# step 191, training accuracy 0.84
# step 192, training accuracy 0.96
# step 193, training accuracy 0.92
# step 194, training accuracy 0.94
# step 195, training accuracy 0.92
# step 196, training accuracy 0.88
# step 197, training accuracy 0.84
# step 198, training accuracy 0.88
# step 199, training accuracy 0.96
# step 200, training accuracy 0.84
# step 201, training accuracy 0.96
# step 202, training accuracy 0.9
# step 203, training accuracy 0.9
# step 204, training accuracy 0.9
# step 205, training accuracy 0.9
# step 206, training accuracy 0.96
# step 207, training accuracy 0.94
# step 208, training accuracy 0.96
# step 209, training accuracy 0.98
# step 210, training accuracy 0.86
# step 211, training accuracy 0.88
# step 212, training accuracy 0.88
# step 213, training accuracy 0.96
# step 214, training accuracy 0.9
# step 215, training accuracy 0.94
# step 216, training accuracy 0.88
# step 217, training accuracy 0.98
# step 218, training accuracy 0.96
# step 219, training accuracy 0.88
# step 220, training accuracy 0.9
# step 221, training accuracy 0.94
# step 222, training accuracy 0.86
# step 223, training accuracy 0.86
# step 224, training accuracy 0.9
# step 225, training accuracy 0.92
# step 226, training accuracy 0.86
# step 227, training accuracy 0.92
# step 228, training accuracy 0.88
# step 229, training accuracy 0.98
# step 230, training accuracy 0.98
# step 231, training accuracy 0.92
# step 232, training accuracy 0.84
# step 233, training accuracy 0.96
# step 234, training accuracy 0.92
# step 235, training accuracy 0.94
# step 236, training accuracy 0.9
# step 237, training accuracy 0.9
# step 238, training accuracy 0.88
# step 239, training accuracy 0.92
# step 240, training accuracy 0.96
# step 241, training accuracy 0.94
# step 242, training accuracy 0.9
# step 243, training accuracy 0.94
# step 244, training accuracy 0.9
# step 245, training accuracy 0.92
# step 246, training accuracy 0.96
# step 247, training accuracy 0.9
# step 248, training accuracy 0.9
# step 249, training accuracy 0.88
# step 250, training accuracy 0.92
# step 251, training accuracy 0.96
# step 252, training accuracy 0.92
# step 253, training accuracy 0.84
# step 254, training accuracy 0.94
# step 255, training accuracy 0.9
# step 256, training accuracy 0.88
# step 257, training accuracy 0.98
# step 258, training accuracy 0.84
# step 259, training accuracy 0.86
# step 260, training accuracy 0.96
# step 261, training accuracy 0.94
# step 262, training accuracy 0.9
# step 263, training accuracy 0.94
# step 264, training accuracy 0.9
# step 265, training accuracy 0.9
# step 266, training accuracy 0.86
# step 267, training accuracy 1
# step 268, training accuracy 0.92
# step 269, training accuracy 0.9
# step 270, training accuracy 0.92
# step 271, training accuracy 0.92
# step 272, training accuracy 0.92
# step 273, training accuracy 0.92
# step 274, training accuracy 0.92
# step 275, training accuracy 0.92
# step 276, training accuracy 0.88
# step 277, training accuracy 0.98
# step 278, training accuracy 0.88
# step 279, training accuracy 0.96
# step 280, training accuracy 0.98
# step 281, training accuracy 0.94
# step 282, training accuracy 0.94
# step 283, training accuracy 0.96
# step 284, training accuracy 0.94
# step 285, training accuracy 0.92
# step 286, training accuracy 0.92
# step 287, training accuracy 0.92
# step 288, training accuracy 0.94
# step 289, training accuracy 0.88
# step 290, training accuracy 0.94
# step 291, training accuracy 0.94
# step 292, training accuracy 0.9
# step 293, training accuracy 0.94
# step 294, training accuracy 0.88
# step 295, training accuracy 0.9
# step 296, training accuracy 0.96
# step 297, training accuracy 0.92
# step 298, training accuracy 0.96
# step 299, training accuracy 0.84
# step 300, training accuracy 0.96
# step 301, training accuracy 0.96
# step 302, training accuracy 0.94
# step 303, training accuracy 0.9
# step 304, training accuracy 0.94
# step 305, training accuracy 0.94
# step 306, training accuracy 0.98
# step 307, training accuracy 0.9
# step 308, training accuracy 0.96
# step 309, training accuracy 0.86
# step 310, training accuracy 0.98
# step 311, training accuracy 0.9
# step 312, training accuracy 0.92
# step 313, training accuracy 0.92
# step 314, training accuracy 0.9
# step 315, training accuracy 0.96
# step 316, training accuracy 0.98
# step 317, training accuracy 0.9
# step 318, training accuracy 0.92
# step 319, training accuracy 0.92
# step 320, training accuracy 0.92
# step 321, training accuracy 0.98
# step 322, training accuracy 0.9
# step 323, training accuracy 0.94
# step 324, training accuracy 0.92
# step 325, training accuracy 0.96
# step 326, training accuracy 0.92
# step 327, training accuracy 0.86
# step 328, training accuracy 0.96
# step 329, training accuracy 0.9
# step 330, training accuracy 0.88
# step 331, training accuracy 0.86
# step 332, training accuracy 0.92
# step 333, training accuracy 0.96
# step 334, training accuracy 0.96
# step 335, training accuracy 0.94
# step 336, training accuracy 0.9
# step 337, training accuracy 0.96
# step 338, training accuracy 0.94
# step 339, training accuracy 0.96
# step 340, training accuracy 0.96
# step 341, training accuracy 0.82
# step 342, training accuracy 0.88
# step 343, training accuracy 0.94
# step 344, training accuracy 0.96
# step 345, training accuracy 0.96
# step 346, training accuracy 0.98
# step 347, training accuracy 0.98
# step 348, training accuracy 0.96
# step 349, training accuracy 0.94
# step 350, training accuracy 0.98
# step 351, training accuracy 0.94
# step 352, training accuracy 0.94
# step 353, training accuracy 0.96
# step 354, training accuracy 0.94
# step 355, training accuracy 0.94
# step 356, training accuracy 0.92
# step 357, training accuracy 0.98
# step 358, training accuracy 0.94
# step 359, training accuracy 0.9
# step 360, training accuracy 0.92
# step 361, training accuracy 0.92
# step 362, training accuracy 0.86
# step 363, training accuracy 0.92
# step 364, training accuracy 0.92
# step 365, training accuracy 0.92
# step 366, training accuracy 0.9
# step 367, training accuracy 0.96
# step 368, training accuracy 0.98
# step 369, training accuracy 0.9
# step 370, training accuracy 0.94
# step 371, training accuracy 0.92
# step 372, training accuracy 0.9
# step 373, training accuracy 0.94
# step 374, training accuracy 0.96
# step 375, training accuracy 0.98
# step 376, training accuracy 0.96
# step 377, training accuracy 0.94
# step 378, training accuracy 0.92
# step 379, training accuracy 0.88
# step 380, training accuracy 0.94
# step 381, training accuracy 0.98
# step 382, training accuracy 0.96
# step 383, training accuracy 0.96
# step 384, training accuracy 0.92
# step 385, training accuracy 0.94
# step 386, training accuracy 0.96
# step 387, training accuracy 0.98
# step 388, training accuracy 0.96
# step 389, training accuracy 0.92
# step 390, training accuracy 0.94
# step 391, training accuracy 0.94
# step 392, training accuracy 0.92
# step 393, training accuracy 0.94
# step 394, training accuracy 0.94
# step 395, training accuracy 0.96
# step 396, training accuracy 0.92
# step 397, training accuracy 1
# step 398, training accuracy 0.94
# step 399, training accuracy 0.92
# step 400, training accuracy 0.96
# step 401, training accuracy 0.96
# step 402, training accuracy 0.96
# step 403, training accuracy 0.92
# step 404, training accuracy 0.86
# step 405, training accuracy 0.86
# step 406, training accuracy 0.92
# step 407, training accuracy 0.94
# step 408, training accuracy 0.88
# step 409, training accuracy 0.94
# step 410, training accuracy 0.94
# step 411, training accuracy 0.92
# step 412, training accuracy 0.96
# step 413, training accuracy 0.92
# step 414, training accuracy 0.94
# step 415, training accuracy 0.96
# step 416, training accuracy 0.96
# step 417, training accuracy 0.98
# step 418, training accuracy 0.94
# step 419, training accuracy 0.98
# step 420, training accuracy 1
# step 421, training accuracy 0.94
# step 422, training accuracy 0.86
# step 423, training accuracy 0.86
# step 424, training accuracy 0.98
# step 425, training accuracy 0.94
# step 426, training accuracy 0.96
# step 427, training accuracy 0.94
# step 428, training accuracy 0.92
# step 429, training accuracy 0.96
# step 430, training accuracy 0.94
# step 431, training accuracy 0.94
# step 432, training accuracy 0.94
# step 433, training accuracy 0.92
# step 434, training accuracy 0.92
# step 435, training accuracy 0.94
# step 436, training accuracy 0.96
# step 437, training accuracy 0.98
# step 438, training accuracy 0.94
# step 439, training accuracy 0.92
# step 440, training accuracy 0.94
# step 441, training accuracy 0.96
# step 442, training accuracy 0.92
# step 443, training accuracy 0.98
# step 444, training accuracy 0.92
# step 445, training accuracy 0.92
# step 446, training accuracy 0.94
# step 447, training accuracy 0.96
# step 448, training accuracy 0.92
# step 449, training accuracy 0.92
# step 450, training accuracy 1
# step 451, training accuracy 1
# step 452, training accuracy 0.98
# step 453, training accuracy 1
# step 454, training accuracy 0.92
# step 455, training accuracy 0.96
# step 456, training accuracy 0.88
# step 457, training accuracy 0.94
# step 458, training accuracy 0.98
# step 459, training accuracy 0.98
# step 460, training accuracy 0.98
# step 461, training accuracy 0.94
# step 462, training accuracy 0.96
# step 463, training accuracy 0.92
# step 464, training accuracy 0.94
# step 465, training accuracy 0.94
# step 466, training accuracy 0.94
# step 467, training accuracy 0.96
# step 468, training accuracy 0.92
# step 469, training accuracy 0.92
# step 470, training accuracy 0.92
# step 471, training accuracy 0.98
# step 472, training accuracy 0.96
# step 473, training accuracy 0.94
# step 474, training accuracy 0.96
# step 475, training accuracy 0.92
# step 476, training accuracy 0.94
# step 477, training accuracy 1
# step 478, training accuracy 0.94
# step 479, training accuracy 0.98
# step 480, training accuracy 0.96
# step 481, training accuracy 0.9
# step 482, training accuracy 0.9
# step 483, training accuracy 0.92
# step 484, training accuracy 0.98
# step 485, training accuracy 0.94
# step 486, training accuracy 0.96
# step 487, training accuracy 0.92
# step 488, training accuracy 0.92
# step 489, training accuracy 0.9
# step 490, training accuracy 0.94
# step 491, training accuracy 0.96
# step 492, training accuracy 0.96
# step 493, training accuracy 1
# step 494, training accuracy 0.9
# step 495, training accuracy 0.98
# step 496, training accuracy 0.96
# step 497, training accuracy 0.98
# step 498, training accuracy 0.94
# step 499, training accuracy 0.86
# step 500, training accuracy 0.96
# step 501, training accuracy 0.94
# step 502, training accuracy 0.92
# step 503, training accuracy 0.96
# step 504, training accuracy 1
# step 505, training accuracy 0.96
# step 506, training accuracy 0.92
# step 507, training accuracy 0.98
# step 508, training accuracy 0.96
# step 509, training accuracy 0.92
# step 510, training accuracy 0.92
# step 511, training accuracy 0.96
# step 512, training accuracy 0.96
# step 513, training accuracy 0.94
# step 514, training accuracy 0.94
# step 515, training accuracy 0.96
# step 516, training accuracy 0.96
# step 517, training accuracy 0.96
# step 518, training accuracy 0.98
# step 519, training accuracy 0.98
# step 520, training accuracy 0.96
# step 521, training accuracy 0.94
# step 522, training accuracy 0.86
# step 523, training accuracy 0.92
# step 524, training accuracy 0.94
# step 525, training accuracy 0.96
# step 526, training accuracy 0.96
# step 527, training accuracy 0.88
# step 528, training accuracy 0.92
# step 529, training accuracy 0.88
# step 530, training accuracy 0.92
# step 531, training accuracy 0.94
# step 532, training accuracy 1
# step 533, training accuracy 0.96
# step 534, training accuracy 0.94
# step 535, training accuracy 0.92
# step 536, training accuracy 0.98
# step 537, training accuracy 0.98
# step 538, training accuracy 0.96
# step 539, training accuracy 0.98
# step 540, training accuracy 0.98
# step 541, training accuracy 0.98
# step 542, training accuracy 0.98
# step 543, training accuracy 0.98
# step 544, training accuracy 0.98
# step 545, training accuracy 0.96
# step 546, training accuracy 0.92
# step 547, training accuracy 0.98
# step 548, training accuracy 0.92
# step 549, training accuracy 0.96
# step 550, training accuracy 0.88
# step 551, training accuracy 0.96
# step 552, training accuracy 0.98
# step 553, training accuracy 0.98
# step 554, training accuracy 0.96
# step 555, training accuracy 0.96
# step 556, training accuracy 0.96
# step 557, training accuracy 0.96
# step 558, training accuracy 0.96
# step 559, training accuracy 0.98
# step 560, training accuracy 0.96
# step 561, training accuracy 0.96
# step 562, training accuracy 0.94
# step 563, training accuracy 0.98
# step 564, training accuracy 0.96
# step 565, training accuracy 0.96
# step 566, training accuracy 0.96
# step 567, training accuracy 0.94
# step 568, training accuracy 0.92
# step 569, training accuracy 0.98
# step 570, training accuracy 0.98
# step 571, training accuracy 0.92
# step 572, training accuracy 0.86
# step 573, training accuracy 0.96
# step 574, training accuracy 0.98
# step 575, training accuracy 0.98
# step 576, training accuracy 0.98
# step 577, training accuracy 1
# step 578, training accuracy 0.96
# step 579, training accuracy 1
# step 580, training accuracy 0.96
# step 581, training accuracy 0.9
# step 582, training accuracy 0.94
# step 583, training accuracy 0.94
# step 584, training accuracy 0.96
# step 585, training accuracy 0.96
# step 586, training accuracy 0.94
# step 587, training accuracy 1
# step 588, training accuracy 0.92
# step 589, training accuracy 0.98
# step 590, training accuracy 0.94
# step 591, training accuracy 0.96
# step 592, training accuracy 0.92
# step 593, training accuracy 0.96
# step 594, training accuracy 0.96
# step 595, training accuracy 0.94
# step 596, training accuracy 0.9
# step 597, training accuracy 0.94
# step 598, training accuracy 0.98
# step 599, training accuracy 0.92
# step 600, training accuracy 0.98
# step 601, training accuracy 0.96
# step 602, training accuracy 0.96
# step 603, training accuracy 0.98
# step 604, training accuracy 0.94
# step 605, training accuracy 1
# step 606, training accuracy 0.9
# step 607, training accuracy 0.86
# step 608, training accuracy 0.92
# step 609, training accuracy 0.96
# step 610, training accuracy 0.96
# step 611, training accuracy 0.98
# step 612, training accuracy 0.9
# step 613, training accuracy 0.96
# step 614, training accuracy 0.96
# step 615, training accuracy 0.94
# step 616, training accuracy 0.92
# step 617, training accuracy 0.94
# step 618, training accuracy 0.94
# step 619, training accuracy 0.98
# step 620, training accuracy 0.94
# step 621, training accuracy 0.96
# step 622, training accuracy 0.94
# step 623, training accuracy 0.98
# step 624, training accuracy 0.9
# step 625, training accuracy 0.94
# step 626, training accuracy 0.96
# step 627, training accuracy 0.92
# step 628, training accuracy 0.96
# step 629, training accuracy 0.98
# step 630, training accuracy 0.96
# step 631, training accuracy 0.98
# step 632, training accuracy 1
# step 633, training accuracy 0.96
# step 634, training accuracy 0.9
# step 635, training accuracy 0.9
# step 636, training accuracy 0.98
# step 637, training accuracy 0.94
# step 638, training accuracy 0.96
# step 639, training accuracy 0.94
# step 640, training accuracy 0.88
# step 641, training accuracy 0.96
# step 642, training accuracy 0.94
# step 643, training accuracy 0.98
# step 644, training accuracy 0.94
# step 645, training accuracy 0.92
# step 646, training accuracy 0.92
# step 647, training accuracy 0.96
# step 648, training accuracy 0.96
# step 649, training accuracy 0.9
# step 650, training accuracy 0.92
# step 651, training accuracy 0.86
# step 652, training accuracy 0.94
# step 653, training accuracy 0.98
# step 654, training accuracy 0.96
# step 655, training accuracy 1
# step 656, training accuracy 0.94
# step 657, training accuracy 0.9
# step 658, training accuracy 1
# step 659, training accuracy 0.92
# step 660, training accuracy 0.98
# step 661, training accuracy 0.92
# step 662, training accuracy 0.94
# step 663, training accuracy 0.92
# step 664, training accuracy 0.94
# step 665, training accuracy 0.94
# step 666, training accuracy 0.94
# step 667, training accuracy 1
# step 668, training accuracy 0.96
# step 669, training accuracy 0.98
# step 670, training accuracy 0.94
# step 671, training accuracy 0.94
# step 672, training accuracy 0.96
# step 673, training accuracy 0.96
# step 674, training accuracy 0.96
# step 675, training accuracy 0.98
# step 676, training accuracy 0.96
# step 677, training accuracy 0.92
# step 678, training accuracy 0.98
# step 679, training accuracy 0.98
# step 680, training accuracy 0.96
# step 681, training accuracy 0.92
# step 682, training accuracy 0.98
# step 683, training accuracy 0.96
# step 684, training accuracy 0.96
# step 685, training accuracy 0.96
# step 686, training accuracy 0.96
# step 687, training accuracy 0.96
# step 688, training accuracy 0.94
# step 689, training accuracy 0.96
# step 690, training accuracy 0.92
# step 691, training accuracy 1
# step 692, training accuracy 0.98
# step 693, training accuracy 0.96
# step 694, training accuracy 0.9
# step 695, training accuracy 1
# step 696, training accuracy 0.98
# step 697, training accuracy 0.94
# step 698, training accuracy 0.92
# step 699, training accuracy 0.98
# step 700, training accuracy 0.98
# step 701, training accuracy 0.92
# step 702, training accuracy 0.94
# step 703, training accuracy 0.92
# step 704, training accuracy 0.94
# step 705, training accuracy 0.98
# step 706, training accuracy 0.94
# step 707, training accuracy 0.94
# step 708, training accuracy 0.94
# step 709, training accuracy 0.96
# step 710, training accuracy 0.92
# step 711, training accuracy 0.94
# step 712, training accuracy 0.96
# step 713, training accuracy 1
# step 714, training accuracy 1
# step 715, training accuracy 0.96
# step 716, training accuracy 0.96
# step 717, training accuracy 0.9
# step 718, training accuracy 0.92
# step 719, training accuracy 0.94
# step 720, training accuracy 0.9
# step 721, training accuracy 0.98
# step 722, training accuracy 0.94
# step 723, training accuracy 0.94
# step 724, training accuracy 0.98
# step 725, training accuracy 0.94
# step 726, training accuracy 0.94
# step 727, training accuracy 0.94
# step 728, training accuracy 0.98
# step 729, training accuracy 1
# step 730, training accuracy 0.92
# step 731, training accuracy 0.98
# step 732, training accuracy 0.84
# step 733, training accuracy 1
# step 734, training accuracy 0.96
# step 735, training accuracy 0.98
# step 736, training accuracy 0.94
# step 737, training accuracy 0.94
# step 738, training accuracy 0.96
# step 739, training accuracy 0.96
# step 740, training accuracy 0.96
# step 741, training accuracy 0.88
# step 742, training accuracy 0.96
# step 743, training accuracy 0.92
# step 744, training accuracy 0.94
# step 745, training accuracy 1
# step 746, training accuracy 1
# step 747, training accuracy 0.94
# step 748, training accuracy 0.98
# step 749, training accuracy 1
# step 750, training accuracy 0.88
# step 751, training accuracy 0.98
# step 752, training accuracy 0.96
# step 753, training accuracy 1
# step 754, training accuracy 0.98
# step 755, training accuracy 0.98
# step 756, training accuracy 0.96
# step 757, training accuracy 0.98
# step 758, training accuracy 0.94
# step 759, training accuracy 0.96
# step 760, training accuracy 0.96
# step 761, training accuracy 0.98
# step 762, training accuracy 0.92
# step 763, training accuracy 0.96
# step 764, training accuracy 0.98
# step 765, training accuracy 0.96
# step 766, training accuracy 0.94
# step 767, training accuracy 1
# step 768, training accuracy 1
# step 769, training accuracy 0.94
# step 770, training accuracy 0.94
# step 771, training accuracy 0.92
# step 772, training accuracy 0.98
# step 773, training accuracy 1
# step 774, training accuracy 0.96
# step 775, training accuracy 0.98
# step 776, training accuracy 1
# step 777, training accuracy 0.98
# step 778, training accuracy 0.96
# step 779, training accuracy 0.9
# step 780, training accuracy 0.92
# step 781, training accuracy 1
# step 782, training accuracy 0.9
# step 783, training accuracy 0.94
# step 784, training accuracy 0.96
# step 785, training accuracy 1
# step 786, training accuracy 0.94
# step 787, training accuracy 0.9
# step 788, training accuracy 0.98
# step 789, training accuracy 0.98
# step 790, training accuracy 0.94
# step 791, training accuracy 0.9
# step 792, training accuracy 0.96
# step 793, training accuracy 0.84
# step 794, training accuracy 1
# step 795, training accuracy 0.92
# step 796, training accuracy 1
# step 797, training accuracy 0.96
# step 798, training accuracy 0.92
# step 799, training accuracy 0.96
# step 800, training accuracy 0.92
# step 801, training accuracy 0.96
# step 802, training accuracy 0.94
# step 803, training accuracy 0.98
# step 804, training accuracy 0.98
# step 805, training accuracy 0.84
# step 806, training accuracy 0.96
# step 807, training accuracy 0.92
# step 808, training accuracy 0.94
# step 809, training accuracy 0.94
# step 810, training accuracy 0.96
# step 811, training accuracy 1
# step 812, training accuracy 0.96
# step 813, training accuracy 0.96
# step 814, training accuracy 1
# step 815, training accuracy 0.94
# step 816, training accuracy 0.94
# step 817, training accuracy 1
# step 818, training accuracy 0.92
# step 819, training accuracy 0.9
# step 820, training accuracy 0.98
# step 821, training accuracy 0.98
# step 822, training accuracy 1
# step 823, training accuracy 0.9
# step 824, training accuracy 1
# step 825, training accuracy 0.98
# step 826, training accuracy 0.94
# step 827, training accuracy 1
# step 828, training accuracy 0.98
# step 829, training accuracy 0.9
# step 830, training accuracy 0.98
# step 831, training accuracy 0.98
# step 832, training accuracy 1
# step 833, training accuracy 0.94
# step 834, training accuracy 0.98
# step 835, training accuracy 1
# step 836, training accuracy 0.96
# step 837, training accuracy 0.98
# step 838, training accuracy 0.88
# step 839, training accuracy 0.94
# step 840, training accuracy 0.86
# step 841, training accuracy 1
# step 842, training accuracy 0.98
# step 843, training accuracy 0.96
# step 844, training accuracy 0.96
# step 845, training accuracy 0.98
# step 846, training accuracy 0.92
# step 847, training accuracy 0.92
# step 848, training accuracy 0.96
# step 849, training accuracy 0.96
# step 850, training accuracy 0.96
# step 851, training accuracy 1
# step 852, training accuracy 0.94
# step 853, training accuracy 0.98
# step 854, training accuracy 0.96
# step 855, training accuracy 0.98
# step 856, training accuracy 0.92
# step 857, training accuracy 0.9
# step 858, training accuracy 0.94
# step 859, training accuracy 1
# step 860, training accuracy 0.98
# step 861, training accuracy 0.94
# step 862, training accuracy 0.98
# step 863, training accuracy 0.9
# step 864, training accuracy 0.94
# step 865, training accuracy 0.92
# step 866, training accuracy 0.98
# step 867, training accuracy 0.9
# step 868, training accuracy 1
# step 869, training accuracy 0.92
# step 870, training accuracy 0.96
# step 871, training accuracy 0.94
# step 872, training accuracy 0.9
# step 873, training accuracy 0.96
# step 874, training accuracy 0.94
# step 875, training accuracy 0.96
# step 876, training accuracy 1
# step 877, training accuracy 0.96
# step 878, training accuracy 1
# step 879, training accuracy 0.9
# step 880, training accuracy 0.96
# step 881, training accuracy 1
# step 882, training accuracy 0.92
# step 883, training accuracy 1
# step 884, training accuracy 0.92
# step 885, training accuracy 0.98
# step 886, training accuracy 0.96
# step 887, training accuracy 0.96
# step 888, training accuracy 0.94
# step 889, training accuracy 0.94
# step 890, training accuracy 0.92
# step 891, training accuracy 0.9
# step 892, training accuracy 0.94
# step 893, training accuracy 0.96
# step 894, training accuracy 0.92
# step 895, training accuracy 0.98
# step 896, training accuracy 0.92
# step 897, training accuracy 0.9
# step 898, training accuracy 0.98
# step 899, training accuracy 0.9
# step 900, training accuracy 0.96
# step 901, training accuracy 0.98
# step 902, training accuracy 0.96
# step 903, training accuracy 0.88
# step 904, training accuracy 0.94
# step 905, training accuracy 0.96
# step 906, training accuracy 1
# step 907, training accuracy 0.92
# step 908, training accuracy 1
# step 909, training accuracy 0.9
# step 910, training accuracy 0.96
# step 911, training accuracy 0.98
# step 912, training accuracy 0.96
# step 913, training accuracy 0.94
# step 914, training accuracy 0.98
# step 915, training accuracy 0.94
# step 916, training accuracy 0.94
# step 917, training accuracy 0.92
# step 918, training accuracy 1
# step 919, training accuracy 0.92
# step 920, training accuracy 0.96
# step 921, training accuracy 0.92
# step 922, training accuracy 0.94
# step 923, training accuracy 0.98
# step 924, training accuracy 0.96
# step 925, training accuracy 0.96
# step 926, training accuracy 0.98
# step 927, training accuracy 0.9
# step 928, training accuracy 0.92
# step 929, training accuracy 0.92
# step 930, training accuracy 0.98
# step 931, training accuracy 0.98
# step 932, training accuracy 0.96
# step 933, training accuracy 0.92
# step 934, training accuracy 0.94
# step 935, training accuracy 0.96
# step 936, training accuracy 0.94
# step 937, training accuracy 1
# step 938, training accuracy 0.96
# step 939, training accuracy 0.98
# step 940, training accuracy 0.98
# step 941, training accuracy 0.98
# step 942, training accuracy 0.96
# step 943, training accuracy 0.96
# step 944, training accuracy 0.96
# step 945, training accuracy 0.96
# step 946, training accuracy 0.94
# step 947, training accuracy 0.94
# step 948, training accuracy 0.98
# step 949, training accuracy 1
# step 950, training accuracy 0.92
# step 951, training accuracy 0.92
# step 952, training accuracy 0.96
# step 953, training accuracy 0.94
# step 954, training accuracy 0.98
# step 955, training accuracy 0.98
# step 956, training accuracy 0.98
# step 957, training accuracy 0.98
# step 958, training accuracy 0.94
# step 959, training accuracy 0.98
# step 960, training accuracy 0.96
# step 961, training accuracy 1
# step 962, training accuracy 0.98
# step 963, training accuracy 0.94
# step 964, training accuracy 0.98
# step 965, training accuracy 0.94
# step 966, training accuracy 0.98
# step 967, training accuracy 0.98
# step 968, training accuracy 0.96
# step 969, training accuracy 0.92
# step 970, training accuracy 1
# step 971, training accuracy 0.96
# step 972, training accuracy 1
# step 973, training accuracy 0.98
# step 974, training accuracy 0.94
# step 975, training accuracy 0.98
# step 976, training accuracy 0.92
# step 977, training accuracy 0.98
# step 978, training accuracy 0.96
# step 979, training accuracy 0.98
# step 980, training accuracy 0.96
# step 981, training accuracy 0.98
# step 982, training accuracy 0.96
# step 983, training accuracy 0.98
# step 984, training accuracy 0.98
# step 985, training accuracy 0.98
# step 986, training accuracy 0.9
# step 987, training accuracy 0.98
# step 988, training accuracy 0.94
# step 989, training accuracy 0.92
# step 990, training accuracy 1
# step 991, training accuracy 0.96
# step 992, training accuracy 0.96
# step 993, training accuracy 0.98
# step 994, training accuracy 0.96
# step 995, training accuracy 1
# step 996, training accuracy 0.92
# step 997, training accuracy 0.98
# step 998, training accuracy 0.96
# step 999, training accuracy 0.98
# step 1000, training accuracy 1
# step 1001, training accuracy 0.94
# step 1002, training accuracy 0.98
# step 1003, training accuracy 0.94
# step 1004, training accuracy 0.98
# step 1005, training accuracy 0.98
# step 1006, training accuracy 0.98
# step 1007, training accuracy 0.98
# step 1008, training accuracy 0.98
# step 1009, training accuracy 0.94
# step 1010, training accuracy 1
# step 1011, training accuracy 0.98
# step 1012, training accuracy 0.92
# step 1013, training accuracy 1
# step 1014, training accuracy 0.98
# step 1015, training accuracy 0.94
# step 1016, training accuracy 0.98
# step 1017, training accuracy 1
# step 1018, training accuracy 0.94
# step 1019, training accuracy 0.98
# step 1020, training accuracy 0.94
# step 1021, training accuracy 1
# step 1022, training accuracy 0.96
# step 1023, training accuracy 0.96
# step 1024, training accuracy 0.92
# step 1025, training accuracy 0.96
# step 1026, training accuracy 0.94
# step 1027, training accuracy 0.96
# step 1028, training accuracy 1
# step 1029, training accuracy 1
# step 1030, training accuracy 0.96
# step 1031, training accuracy 0.98
# step 1032, training accuracy 1
# step 1033, training accuracy 0.94
# step 1034, training accuracy 0.9
# step 1035, training accuracy 0.94
# step 1036, training accuracy 0.96
# step 1037, training accuracy 0.94
# step 1038, training accuracy 1
# step 1039, training accuracy 0.9
# step 1040, training accuracy 0.98
# step 1041, training accuracy 0.98
# step 1042, training accuracy 1
# step 1043, training accuracy 0.92
# step 1044, training accuracy 0.96
# step 1045, training accuracy 1
# step 1046, training accuracy 0.96
# step 1047, training accuracy 0.98
# step 1048, training accuracy 0.96
# step 1049, training accuracy 0.98
# step 1050, training accuracy 0.96
# step 1051, training accuracy 0.96
# step 1052, training accuracy 0.98
# step 1053, training accuracy 0.98
# step 1054, training accuracy 0.98
# step 1055, training accuracy 0.96
# step 1056, training accuracy 0.94
# step 1057, training accuracy 0.98
# step 1058, training accuracy 0.94
# step 1059, training accuracy 0.96
# step 1060, training accuracy 0.96
# step 1061, training accuracy 1
# step 1062, training accuracy 0.94
# step 1063, training accuracy 0.96
# step 1064, training accuracy 0.98
# step 1065, training accuracy 0.96
# step 1066, training accuracy 0.92
# step 1067, training accuracy 1
# step 1068, training accuracy 1
# step 1069, training accuracy 0.96
# step 1070, training accuracy 0.98
# step 1071, training accuracy 0.96
# step 1072, training accuracy 0.98
# step 1073, training accuracy 0.94
# step 1074, training accuracy 1
# step 1075, training accuracy 0.96
# step 1076, training accuracy 0.94
# step 1077, training accuracy 0.94
# step 1078, training accuracy 0.98
# step 1079, training accuracy 0.96
# step 1080, training accuracy 0.98
# step 1081, training accuracy 0.96
# step 1082, training accuracy 0.96
# step 1083, training accuracy 0.96
# step 1084, training accuracy 0.96
# step 1085, training accuracy 1
# step 1086, training accuracy 0.98
# step 1087, training accuracy 0.98
# step 1088, training accuracy 0.96
# step 1089, training accuracy 0.92
# step 1090, training accuracy 0.98
# step 1091, training accuracy 0.98
# step 1092, training accuracy 0.94
# step 1093, training accuracy 0.94
# step 1094, training accuracy 0.94
# step 1095, training accuracy 1
# step 1096, training accuracy 0.92
# step 1097, training accuracy 1
# step 1098, training accuracy 0.94
# step 1099, training accuracy 1
# step 1100, training accuracy 0.98
# step 1101, training accuracy 0.98
# step 1102, training accuracy 0.96
# step 1103, training accuracy 0.98
# step 1104, training accuracy 0.94
# step 1105, training accuracy 0.94
# step 1106, training accuracy 0.98
# step 1107, training accuracy 1
# step 1108, training accuracy 0.98
# step 1109, training accuracy 0.96
# step 1110, training accuracy 0.98
# step 1111, training accuracy 1
# step 1112, training accuracy 1
# step 1113, training accuracy 0.98
# step 1114, training accuracy 0.94
# step 1115, training accuracy 0.92
# step 1116, training accuracy 0.98
# step 1117, training accuracy 1
# step 1118, training accuracy 0.98
# step 1119, training accuracy 0.96
# step 1120, training accuracy 1
# step 1121, training accuracy 0.92
# step 1122, training accuracy 1
# step 1123, training accuracy 0.98
# step 1124, training accuracy 0.96
# step 1125, training accuracy 0.94
# step 1126, training accuracy 0.96
# step 1127, training accuracy 0.96
# step 1128, training accuracy 0.96
# step 1129, training accuracy 0.98
# step 1130, training accuracy 0.98
# step 1131, training accuracy 0.96
# step 1132, training accuracy 1
# step 1133, training accuracy 1
# step 1134, training accuracy 1
# step 1135, training accuracy 1
# step 1136, training accuracy 1
# step 1137, training accuracy 0.96
# step 1138, training accuracy 0.98
# step 1139, training accuracy 0.98
# step 1140, training accuracy 0.92
# step 1141, training accuracy 0.96
# step 1142, training accuracy 0.98
# step 1143, training accuracy 0.94
# step 1144, training accuracy 1
# step 1145, training accuracy 0.98
# step 1146, training accuracy 0.94
# step 1147, training accuracy 0.98
# step 1148, training accuracy 0.96
# step 1149, training accuracy 0.98
# step 1150, training accuracy 0.98
# step 1151, training accuracy 0.98
# step 1152, training accuracy 0.98
# step 1153, training accuracy 0.98
# step 1154, training accuracy 0.96
# step 1155, training accuracy 0.98
# step 1156, training accuracy 0.92
# step 1157, training accuracy 1
# step 1158, training accuracy 0.94
# step 1159, training accuracy 0.98
# step 1160, training accuracy 0.98
# step 1161, training accuracy 0.98
# step 1162, training accuracy 1
# step 1163, training accuracy 1
# step 1164, training accuracy 0.96
# step 1165, training accuracy 0.96
# step 1166, training accuracy 0.94
# step 1167, training accuracy 0.98
# step 1168, training accuracy 0.96
# step 1169, training accuracy 0.98
# step 1170, training accuracy 0.98
# step 1171, training accuracy 0.94
# step 1172, training accuracy 1
# step 1173, training accuracy 0.96
# step 1174, training accuracy 0.98
# step 1175, training accuracy 1
# step 1176, training accuracy 0.94
# step 1177, training accuracy 0.9
# step 1178, training accuracy 0.94
# step 1179, training accuracy 0.96
# step 1180, training accuracy 1
# step 1181, training accuracy 0.98
# step 1182, training accuracy 0.98
# step 1183, training accuracy 1
# step 1184, training accuracy 0.98
# step 1185, training accuracy 0.98
# step 1186, training accuracy 0.98
# step 1187, training accuracy 1
# step 1188, training accuracy 0.96
# step 1189, training accuracy 0.94
# step 1190, training accuracy 0.94
# step 1191, training accuracy 1
# step 1192, training accuracy 0.94
# step 1193, training accuracy 0.96
# step 1194, training accuracy 1
# step 1195, training accuracy 0.98
# step 1196, training accuracy 0.96
# step 1197, training accuracy 1
# step 1198, training accuracy 0.98
# step 1199, training accuracy 0.96
# step 1200, training accuracy 1
# step 1201, training accuracy 0.92
# step 1202, training accuracy 0.98
# step 1203, training accuracy 1
# step 1204, training accuracy 0.96
# step 1205, training accuracy 0.92
# step 1206, training accuracy 0.98
# step 1207, training accuracy 0.96
# step 1208, training accuracy 0.94
# step 1209, training accuracy 0.96
# step 1210, training accuracy 1
# step 1211, training accuracy 0.86
# step 1212, training accuracy 0.94
# step 1213, training accuracy 0.98
# step 1214, training accuracy 0.98
# step 1215, training accuracy 0.98
# step 1216, training accuracy 1
# step 1217, training accuracy 0.96
# step 1218, training accuracy 0.98
# step 1219, training accuracy 0.94
# step 1220, training accuracy 0.98
# step 1221, training accuracy 0.92
# step 1222, training accuracy 0.96
# step 1223, training accuracy 0.98
# step 1224, training accuracy 0.98
# step 1225, training accuracy 1
# step 1226, training accuracy 0.96
# step 1227, training accuracy 0.98
# step 1228, training accuracy 0.96
# step 1229, training accuracy 0.98
# step 1230, training accuracy 0.94
# step 1231, training accuracy 0.98
# step 1232, training accuracy 0.98
# step 1233, training accuracy 0.94
# step 1234, training accuracy 0.98
# step 1235, training accuracy 0.98
# step 1236, training accuracy 0.96
# step 1237, training accuracy 1
# step 1238, training accuracy 0.94
# step 1239, training accuracy 1
# step 1240, training accuracy 0.98
# step 1241, training accuracy 0.98
# step 1242, training accuracy 0.92
# step 1243, training accuracy 0.96
# step 1244, training accuracy 0.96
# step 1245, training accuracy 1
# step 1246, training accuracy 0.96
# step 1247, training accuracy 1
# step 1248, training accuracy 0.98
# step 1249, training accuracy 0.98
# step 1250, training accuracy 1
# step 1251, training accuracy 1
# step 1252, training accuracy 0.98
# step 1253, training accuracy 0.96
# step 1254, training accuracy 0.98
# step 1255, training accuracy 0.98
# step 1256, training accuracy 1
# step 1257, training accuracy 0.98
# step 1258, training accuracy 0.98
# step 1259, training accuracy 0.92
# step 1260, training accuracy 0.96
# step 1261, training accuracy 0.98
# step 1262, training accuracy 0.96
# step 1263, training accuracy 0.98
# step 1264, training accuracy 0.92
# step 1265, training accuracy 0.94
# step 1266, training accuracy 0.94
# step 1267, training accuracy 1
# step 1268, training accuracy 0.98
# step 1269, training accuracy 1
# step 1270, training accuracy 0.98
# step 1271, training accuracy 0.94
# step 1272, training accuracy 0.98
# step 1273, training accuracy 0.98
# step 1274, training accuracy 1
# step 1275, training accuracy 0.98
# step 1276, training accuracy 0.94
# step 1277, training accuracy 1
# step 1278, training accuracy 0.98
# step 1279, training accuracy 0.96
# step 1280, training accuracy 0.96
# step 1281, training accuracy 1
# step 1282, training accuracy 1
# step 1283, training accuracy 0.96
# step 1284, training accuracy 0.96
# step 1285, training accuracy 0.96
# step 1286, training accuracy 0.96
# step 1287, training accuracy 1
# step 1288, training accuracy 0.98
# step 1289, training accuracy 0.98
# step 1290, training accuracy 0.98
# step 1291, training accuracy 0.96
# step 1292, training accuracy 0.96
# step 1293, training accuracy 0.98
# step 1294, training accuracy 0.96
# step 1295, training accuracy 1
# step 1296, training accuracy 0.96
# step 1297, training accuracy 0.98
# step 1298, training accuracy 0.98
# step 1299, training accuracy 0.96
# step 1300, training accuracy 0.98
# step 1301, training accuracy 1
# step 1302, training accuracy 1
# step 1303, training accuracy 0.98
# step 1304, training accuracy 0.98
# step 1305, training accuracy 1
# step 1306, training accuracy 1
# step 1307, training accuracy 1
# step 1308, training accuracy 1
# step 1309, training accuracy 1
# step 1310, training accuracy 0.94
# step 1311, training accuracy 0.98
# step 1312, training accuracy 0.98
# step 1313, training accuracy 1
# step 1314, training accuracy 0.96
# step 1315, training accuracy 0.96
# step 1316, training accuracy 1
# step 1317, training accuracy 0.96
# step 1318, training accuracy 0.98
# step 1319, training accuracy 0.96
# step 1320, training accuracy 0.98
# step 1321, training accuracy 0.98
# step 1322, training accuracy 0.98
# step 1323, training accuracy 0.94
# step 1324, training accuracy 0.98
# step 1325, training accuracy 0.96
# step 1326, training accuracy 0.94
# step 1327, training accuracy 1
# step 1328, training accuracy 0.98
# step 1329, training accuracy 1
# step 1330, training accuracy 0.96
# step 1331, training accuracy 0.98
# step 1332, training accuracy 0.92
# step 1333, training accuracy 1
# step 1334, training accuracy 0.96
# step 1335, training accuracy 0.98
# step 1336, training accuracy 1
# step 1337, training accuracy 0.98
# step 1338, training accuracy 0.96
# step 1339, training accuracy 0.96
# step 1340, training accuracy 0.96
# step 1341, training accuracy 0.98
# step 1342, training accuracy 0.96
# step 1343, training accuracy 0.98
# step 1344, training accuracy 0.96
# step 1345, training accuracy 0.96
# step 1346, training accuracy 0.96
# step 1347, training accuracy 1
# step 1348, training accuracy 1
# step 1349, training accuracy 1
# step 1350, training accuracy 0.96
# step 1351, training accuracy 0.98
# step 1352, training accuracy 0.98
# step 1353, training accuracy 0.98
# step 1354, training accuracy 0.98
# step 1355, training accuracy 0.9
# step 1356, training accuracy 0.94
# step 1357, training accuracy 0.98
# step 1358, training accuracy 0.96
# step 1359, training accuracy 0.98
# step 1360, training accuracy 0.9
# step 1361, training accuracy 0.92
# step 1362, training accuracy 0.98
# step 1363, training accuracy 0.96
# step 1364, training accuracy 0.98
# step 1365, training accuracy 1
# step 1366, training accuracy 1
# step 1367, training accuracy 1
# step 1368, training accuracy 0.98
# step 1369, training accuracy 0.94
# step 1370, training accuracy 0.96
# step 1371, training accuracy 0.96
# step 1372, training accuracy 0.98
# step 1373, training accuracy 0.98
# step 1374, training accuracy 1
# step 1375, training accuracy 0.98
# step 1376, training accuracy 0.96
# step 1377, training accuracy 0.98
# ...
# step 3176, training accuracy 0.98
# step 3177, training accuracy 1
# step 3178, training accuracy 0.96
# step 3179, training accuracy 0.98
# step 3180, training accuracy 0.98
# step 3181, training accuracy 0.98
# step 3182, training accuracy 1
# step 3183, training accuracy 1
# step 3184, training accuracy 0.96
# step 3185, training accuracy 0.98
# step 3186, training accuracy 0.98
# step 3187, training accuracy 0.98
# step 3188, training accuracy 0.96
# step 3189, training accuracy 1
# step 3190, training accuracy 1
# step 3191, training accuracy 0.96
# step 3192, training accuracy 1
# step 3193, training accuracy 1
# step 3194, training accuracy 0.98
# step 3195, training accuracy 0.98
# step 3196, training accuracy 0.96
# step 3197, training accuracy 1
# step 3198, training accuracy 0.98
# step 3199, training accuracy 1
# step 3200, training accuracy 1
# step 3201, training accuracy 1
# step 3202, training accuracy 1
# step 3203, training accuracy 0.98
# step 3204, training accuracy 0.94
# step 3205, training accuracy 1
# step 3206, training accuracy 0.96
# step 3207, training accuracy 0.98
# step 3208, training accuracy 0.92
# step 3209, training accuracy 1
# step 3210, training accuracy 1
# step 3211, training accuracy 0.98
# step 3212, training accuracy 1
# step 3213, training accuracy 0.98
# step 3214, training accuracy 0.98
# step 3215, training accuracy 1
# step 3216, training accuracy 0.96
# step 3217, training accuracy 0.98
# step 3218, training accuracy 1
# step 3219, training accuracy 0.98
# step 3220, training accuracy 1
# step 3221, training accuracy 1
# step 3222, training accuracy 0.98
# step 3223, training accuracy 1
# step 3224, training accuracy 0.98
# step 3225, training accuracy 0.98
# step 3226, training accuracy 0.98
# step 3227, training accuracy 0.94
# step 3228, training accuracy 1
# step 3229, training accuracy 0.98
# step 3230, training accuracy 0.96
# step 3231, training accuracy 1
# step 3232, training accuracy 0.98
# step 3233, training accuracy 1
# step 3234, training accuracy 0.98
# step 3235, training accuracy 0.98
# step 3236, training accuracy 0.98
# step 3237, training accuracy 0.96
# step 3238, training accuracy 0.98
# step 3239, training accuracy 1
# step 3240, training accuracy 0.98
# step 3241, training accuracy 0.98
# step 3242, training accuracy 1
# step 3243, training accuracy 1
# step 3244, training accuracy 0.94
# step 3245, training accuracy 0.98
# step 3246, training accuracy 1
# step 3247, training accuracy 1
# step 3248, training accuracy 1
# step 3249, training accuracy 1
# step 3250, training accuracy 0.98
# step 3251, training accuracy 0.96
# step 3252, training accuracy 1
# step 3253, training accuracy 1
# step 3254, training accuracy 0.98
# step 3255, training accuracy 0.98
# step 3256, training accuracy 1
# step 3257, training accuracy 1
# step 3258, training accuracy 0.96
# step 3259, training accuracy 0.98
# step 3260, training accuracy 0.98
# step 3261, training accuracy 0.98
# step 3262, training accuracy 0.94
# step 3263, training accuracy 0.96
# step 3264, training accuracy 1
# step 3265, training accuracy 1
# step 3266, training accuracy 1
# step 3267, training accuracy 0.98
# step 3268, training accuracy 1
# step 3269, training accuracy 0.96
# step 3270, training accuracy 1
# step 3271, training accuracy 1
# step 3272, training accuracy 0.98
# step 3273, training accuracy 0.96
# step 3274, training accuracy 1
# step 3275, training accuracy 0.98
# step 3276, training accuracy 1
# step 3277, training accuracy 0.98
# step 3278, training accuracy 0.98
# step 3279, training accuracy 0.98
# step 3280, training accuracy 0.96
# step 3281, training accuracy 1
# step 3282, training accuracy 0.98
# step 3283, training accuracy 1
# step 3284, training accuracy 0.98
# step 3285, training accuracy 0.98
# step 3286, training accuracy 1
# step 3287, training accuracy 0.96
# step 3288, training accuracy 1
# step 3289, training accuracy 0.98
# step 3290, training accuracy 1
# step 3291, training accuracy 0.96
# step 3292, training accuracy 0.98
# step 3293, training accuracy 1
# step 3294, training accuracy 0.92
# step 3295, training accuracy 0.96
# step 3296, training accuracy 1
# step 3297, training accuracy 1
# step 3298, training accuracy 1
# step 3299, training accuracy 0.96
# step 3300, training accuracy 0.98
# step 3301, training accuracy 0.96
# step 3302, training accuracy 1
# step 3303, training accuracy 1
# step 3304, training accuracy 0.96
# step 3305, training accuracy 1
# step 3306, training accuracy 0.98
# step 3307, training accuracy 0.98
# step 3308, training accuracy 1
# step 3309, training accuracy 0.98
# step 3310, training accuracy 0.98
# step 3311, training accuracy 0.98
# step 3312, training accuracy 0.96
# step 3313, training accuracy 1
# step 3314, training accuracy 0.96
# step 3315, training accuracy 1
# step 3316, training accuracy 0.96
# step 3317, training accuracy 0.98
# step 3318, training accuracy 1
# step 3319, training accuracy 1
# step 3320, training accuracy 1
# step 3321, training accuracy 0.94
# step 3322, training accuracy 1
# step 3323, training accuracy 1
# step 3324, training accuracy 1
# step 3325, training accuracy 0.96
# step 3326, training accuracy 1
# step 3327, training accuracy 0.96
# step 3328, training accuracy 1
# step 3329, training accuracy 0.98
# step 3330, training accuracy 0.98
# step 3331, training accuracy 0.98
# step 3332, training accuracy 1
# step 3333, training accuracy 0.98
# step 3334, training accuracy 1
# step 3335, training accuracy 1
# step 3336, training accuracy 0.96
# step 3337, training accuracy 0.98
# step 3338, training accuracy 1
# step 3339, training accuracy 0.98
# step 3340, training accuracy 1
# step 3341, training accuracy 0.98
# step 3342, training accuracy 0.98
# step 3343, training accuracy 0.96
# step 3344, training accuracy 1
# step 3345, training accuracy 0.94
# step 3346, training accuracy 0.98
# step 3347, training accuracy 0.98
# step 3348, training accuracy 0.98
# step 3349, training accuracy 0.98
# step 3350, training accuracy 0.98
# step 3351, training accuracy 1
# step 3352, training accuracy 1
# step 3353, training accuracy 0.98
# step 3354, training accuracy 1
# step 3355, training accuracy 1
# step 3356, training accuracy 1
# step 3357, training accuracy 0.98
# step 3358, training accuracy 0.96
# step 3359, training accuracy 1
# step 3360, training accuracy 0.98
# step 3361, training accuracy 1
# step 3362, training accuracy 1
# step 3363, training accuracy 1
# step 3364, training accuracy 1
# step 3365, training accuracy 1
# step 3366, training accuracy 1
# step 3367, training accuracy 1
# step 3368, training accuracy 0.98
# step 3369, training accuracy 1
# step 3370, training accuracy 1
# step 3371, training accuracy 1
# step 3372, training accuracy 1
# step 3373, training accuracy 0.98
# step 3374, training accuracy 1
# step 3375, training accuracy 1
# step 3376, training accuracy 1
# step 3377, training accuracy 1
# step 3378, training accuracy 1
# step 3379, training accuracy 1
# step 3380, training accuracy 0.96
# step 3381, training accuracy 0.98
# step 3382, training accuracy 0.96
# step 3383, training accuracy 1
# step 3384, training accuracy 0.98
# step 3385, training accuracy 1
# step 3386, training accuracy 0.98
# step 3387, training accuracy 1
# step 3388, training accuracy 1
# step 3389, training accuracy 0.98
# step 3390, training accuracy 0.96
# step 3391, training accuracy 1
# step 3392, training accuracy 1
# step 3393, training accuracy 1
# step 3394, training accuracy 1
# step 3395, training accuracy 1
# step 3396, training accuracy 1
# step 3397, training accuracy 0.98
# step 3398, training accuracy 0.96
# step 3399, training accuracy 1
# step 3400, training accuracy 0.98
# step 3401, training accuracy 1
# step 3402, training accuracy 1
# step 3403, training accuracy 1
# step 3404, training accuracy 1
# step 3405, training accuracy 1
# step 3406, training accuracy 1
# step 3407, training accuracy 0.98
# step 3408, training accuracy 0.98
# step 3409, training accuracy 1
# step 3410, training accuracy 1
# step 3411, training accuracy 1
# step 3412, training accuracy 0.98
# step 3413, training accuracy 0.98
# step 3414, training accuracy 1
# step 3415, training accuracy 1
# step 3416, training accuracy 1
# step 3417, training accuracy 0.98
# step 3418, training accuracy 0.96
# step 3419, training accuracy 0.98
# step 3420, training accuracy 0.98
# step 3421, training accuracy 1
# step 3422, training accuracy 0.98
# step 3423, training accuracy 1
# step 3424, training accuracy 1
# step 3425, training accuracy 0.96
# step 3426, training accuracy 0.98
# step 3427, training accuracy 1
# step 3428, training accuracy 1
# step 3429, training accuracy 1
# step 3430, training accuracy 0.96
# step 3431, training accuracy 0.98
# step 3432, training accuracy 0.98
# step 3433, training accuracy 1
# step 3434, training accuracy 1
# step 3435, training accuracy 0.94
# step 3436, training accuracy 1
# step 3437, training accuracy 0.96
# step 3438, training accuracy 1
# step 3439, training accuracy 0.98
# step 3440, training accuracy 0.98
# step 3441, training accuracy 1
# step 3442, training accuracy 1
# step 3443, training accuracy 1
# step 3444, training accuracy 1
# step 3445, training accuracy 1
# step 3446, training accuracy 1
# step 3447, training accuracy 0.94
# step 3448, training accuracy 1
# step 3449, training accuracy 1
# step 3450, training accuracy 1
# step 3451, training accuracy 1
# step 3452, training accuracy 1
# step 3453, training accuracy 1
# step 3454, training accuracy 0.96
# step 3455, training accuracy 1
# step 3456, training accuracy 1
# step 3457, training accuracy 0.96
# step 3458, training accuracy 1
# step 3459, training accuracy 0.98
# step 3460, training accuracy 0.98
# step 3461, training accuracy 1
# step 3462, training accuracy 1
# step 3463, training accuracy 1
# step 3464, training accuracy 0.98
# step 3465, training accuracy 1
# step 3466, training accuracy 1
# step 3467, training accuracy 0.98
# step 3468, training accuracy 0.98
# step 3469, training accuracy 1
# step 3470, training accuracy 1
# step 3471, training accuracy 0.98
# step 3472, training accuracy 1
# step 3473, training accuracy 1
# step 3474, training accuracy 0.94
# step 3475, training accuracy 1
# step 3476, training accuracy 0.96
# step 3477, training accuracy 1
# step 3478, training accuracy 1
# step 3479, training accuracy 1
# step 3480, training accuracy 0.96
# step 3481, training accuracy 1
# step 3482, training accuracy 0.98
# step 3483, training accuracy 1
# step 3484, training accuracy 1
# step 3485, training accuracy 1
# step 3486, training accuracy 1
# step 3487, training accuracy 0.98
# step 3488, training accuracy 0.98
# step 3489, training accuracy 0.96
# step 3490, training accuracy 1
# step 3491, training accuracy 1
# step 3492, training accuracy 0.98
# step 3493, training accuracy 0.98
# step 3494, training accuracy 1
# step 3495, training accuracy 1
# step 3496, training accuracy 0.98
# step 3497, training accuracy 0.98
# step 3498, training accuracy 0.98
# step 3499, training accuracy 1
# step 3500, training accuracy 0.96
# step 3501, training accuracy 0.98
# step 3502, training accuracy 1
# step 3503, training accuracy 1
# step 3504, training accuracy 1
# step 3505, training accuracy 0.96
# step 3506, training accuracy 1
# step 3507, training accuracy 0.98
# step 3508, training accuracy 0.98
# step 3509, training accuracy 1
# step 4842, training accuracy 0.98
# step 4843, training accuracy 1
# step 4844, training accuracy 1
# step 4845, training accuracy 1
# step 4846, training accuracy 0.98
# step 4847, training accuracy 1
# step 4848, training accuracy 0.98
# step 4849, training accuracy 1
# step 4850, training accuracy 0.98
# step 4851, training accuracy 1
# step 4852, training accuracy 1
# step 4853, training accuracy 1
# step 4854, training accuracy 1
# step 4855, training accuracy 0.96
# step 4856, training accuracy 1
# step 4857, training accuracy 1
# step 4858, training accuracy 1
# step 4859, training accuracy 1
# step 4860, training accuracy 0.98
# step 4861, training accuracy 1
# step 4862, training accuracy 1
# step 4863, training accuracy 1
# step 4864, training accuracy 1
# step 4865, training accuracy 0.98
# step 4866, training accuracy 1
# step 4867, training accuracy 1
# step 4868, training accuracy 1
# step 4869, training accuracy 0.98
# step 4870, training accuracy 1
# step 4871, training accuracy 0.98
# step 4872, training accuracy 0.98
# step 4873, training accuracy 1
# step 4874, training accuracy 1
# step 4875, training accuracy 1
# step 4876, training accuracy 1
# step 4877, training accuracy 0.98
# step 4878, training accuracy 1
# step 4879, training accuracy 0.96
# step 4880, training accuracy 1
# step 4881, training accuracy 1
# step 4882, training accuracy 1
# step 4883, training accuracy 1
# step 4884, training accuracy 1
# step 4885, training accuracy 1
# step 4886, training accuracy 1
# step 4887, training accuracy 0.98
# step 4888, training accuracy 1
# step 4889, training accuracy 1
# step 4890, training accuracy 1
# step 4891, training accuracy 0.98
# step 4892, training accuracy 1
# step 4893, training accuracy 1
# step 4894, training accuracy 1
# step 4895, training accuracy 1
# step 4896, training accuracy 1
# step 4897, training accuracy 0.98
# step 4898, training accuracy 0.98
# step 4899, training accuracy 1
# step 4900, training accuracy 1
# step 4901, training accuracy 1
# step 4902, training accuracy 0.98
# step 4903, training accuracy 1
# step 4904, training accuracy 1
# step 4905, training accuracy 1
# step 4906, training accuracy 1
# step 4907, training accuracy 1
# step 4908, training accuracy 0.98
# step 4909, training accuracy 1
# step 4910, training accuracy 1
# step 4911, training accuracy 0.98
# step 4912, training accuracy 1
# step 4913, training accuracy 1
# step 4914, training accuracy 1
# step 4915, training accuracy 0.98
# step 4916, training accuracy 0.98
# step 4917, training accuracy 1
# step 4918, training accuracy 0.98
# step 4919, training accuracy 1
# step 4920, training accuracy 1
# step 4921, training accuracy 0.98
# step 4922, training accuracy 0.98
# step 4923, training accuracy 0.98
# step 4924, training accuracy 1
# step 4925, training accuracy 1
# step 4926, training accuracy 1
# step 4927, training accuracy 1
# step 4928, training accuracy 1
# step 4929, training accuracy 1
# step 4930, training accuracy 0.94
# step 4931, training accuracy 0.98
# step 4932, training accuracy 0.98
# step 4933, training accuracy 1
# step 4934, training accuracy 1
# step 4935, training accuracy 1
# step 4936, training accuracy 0.98
# step 4937, training accuracy 1
# step 4938, training accuracy 1
# step 4939, training accuracy 1
# step 4940, training accuracy 0.96
# step 4941, training accuracy 0.98
# step 4942, training accuracy 0.98
# step 4943, training accuracy 1
# step 4944, training accuracy 0.98
# step 4945, training accuracy 1
# step 4946, training accuracy 1
# step 4947, training accuracy 0.98
# step 4948, training accuracy 0.98
# step 4949, training accuracy 0.98
# step 4950, training accuracy 0.98
# step 4951, training accuracy 1
# step 4952, training accuracy 0.98
# step 4953, training accuracy 0.98
# step 4954, training accuracy 1
# step 4955, training accuracy 1
# step 4956, training accuracy 1
# step 4957, training accuracy 0.98
# step 4958, training accuracy 0.98
# step 4959, training accuracy 0.98
# step 4960, training accuracy 1
# step 4961, training accuracy 1
# step 4962, training accuracy 1
# step 4963, training accuracy 0.98
# step 4964, training accuracy 1
# step 4965, training accuracy 0.98
# step 4966, training accuracy 0.96
# step 4967, training accuracy 0.98
# step 4968, training accuracy 0.98
# step 4969, training accuracy 0.98
# step 4970, training accuracy 1
# step 4971, training accuracy 0.98
# step 4972, training accuracy 0.96
# step 4973, training accuracy 1
# step 4974, training accuracy 1
# step 4975, training accuracy 1
# step 4976, training accuracy 1
# step 4977, training accuracy 1
# step 4978, training accuracy 1
# step 4979, training accuracy 0.98
# step 4980, training accuracy 1
# step 4981, training accuracy 1
# step 4982, training accuracy 0.98
# step 4983, training accuracy 0.98
# step 4984, training accuracy 1
# step 4985, training accuracy 1
# step 4986, training accuracy 0.98
# step 4987, training accuracy 1
# step 4988, training accuracy 1
# step 4989, training accuracy 0.98
# step 4990, training accuracy 1
# step 4991, training accuracy 0.96
# step 4992, training accuracy 1
# step 4993, training accuracy 1
# step 4994, training accuracy 0.96
# step 4995, training accuracy 1
# step 4996, training accuracy 0.98
# step 4997, training accuracy 0.98
# step 4998, training accuracy 0.98
# step 4999, training accuracy 1
# step 5000, training accuracy 1
# 训练5000步总时长为 401.407144 秒
# test accuracy 0.9882

# %% [markdown]
# proch 1.0 不丢
# ITER30,Testing accuracy0.9723
# ITER30,training accuracy0.9958182
